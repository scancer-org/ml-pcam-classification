# %% [markdown]
# <a href="https://colab.research.google.com/github/scancer-org/data-prep-and-model-train/blob/main/PCAM_Code_Documentation_Data_Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [PCAM Classification](https://github.com/basveeling/pcam) Project
# ## FSDL Online Course - Spring 2021
# ## Daniel Hen, Harish Narayanan

# %%
### TODO:
# 1. Test on test dataloader (final results)
# 2. Insert transformations to data - done, just validate by printing and showing some images
# 4. Study how to save after training in torch-serve-archiver file (.mar file)
# 5. Clean + Document code and have a train for at least 50 epochs

# %% [markdown]
# ### Installing Required Packages

# %%
# !pip install -qqq wandb

# %% [markdown]
# ### Libraries + Functions import

# %%
# Test labels (from original, which I'll split for train / test)
import h5py
import numpy as np
import torch
import wandb
import os
import pandas as pd
import PIL.Image
import matplotlib.pyplot as plt
import shutil
import time
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from google.colab import drive
from torch.utils import data
from os import listdir
from pathlib import Path
from PIL import Image
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms, datasets

# %% [markdown]
# ### Weights & Biases parameters

# %%
wandb.login()
wandb.init(project="pcam-pytorch-training")
wandb.run.name = "pcam-pytorch-experiment#-" + wandb.run.id
print("Staring experiment: ", wandb.run.name)
# Out:
# wandb: Currently logged in as: daniel8hen (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.25<br/>
#                 Syncing run <strong style="color:#cdcd00">lemon-sound-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training</a><br/>
#                 Run page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/3hp52ocs" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/3hp52ocs</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210410_144520-3hp52ocs</code><br/><br/>
# Staring experiment:  pcam-pytorch-experiment#-3hp52ocs

# %% [markdown]
# ### Google Drive Mounting - for being able to easily read the data

# %%
drive.mount('/content/gdrive/')
# !ls gdrive/MyDrive/pcamv1
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# camelyonpatch_level_2_split_test_meta.csv
# camelyonpatch_level_2_split_test_x.h5
# camelyonpatch_level_2_split_test_y.h5
# camelyonpatch_level_2_split_train_mask.h5
# camelyonpatch_level_2_split_train_meta.csv
# camelyonpatch_level_2_split_train_x.h5
# camelyonpatch_level_2_split_train_y.h5
# camelyonpatch_level_2_split_valid_meta.csv
# camelyonpatch_level_2_split_valid_x.h5
# camelyonpatch_level_2_split_valid_y.h5

# %% [markdown]
# ### Class H5Dataset:
# Defines our dataset class in which we will load data from.
# <br>
# Also, deals with hdfs file format, which requires a customized reference in PyTorch

# %%
class H5Dataset(Dataset):
    def __init__(self, path, transform=None):
        self.file_path = path
        self.dataset_x = None
        self.dataset_y = None
        self.transform = transform
        ### Going to read the X part of the dataset - it's a different file
        with h5py.File(self.file_path + '_x.h5', 'r') as filex:
            self.dataset_x_len = len(filex['x'])

        ### Going to read the y part of the dataset - it's a different file
        with h5py.File(self.file_path + '_y.h5', 'r') as filey:
            self.dataset_y_len = len(filey['y'])

    def __len__(self):
        assert self.dataset_x_len == self.dataset_y_len # Since we are reading from different sources, validating we are good in terms of size both X, Y
        return self.dataset_x_len

    def __getitem__(self, index):
        imgs_path = self.file_path + '_x.h5'
        labels_path = self.file_path + '_y.h5'

        if self.dataset_x is None:
            self.dataset_x = h5py.File(imgs_path, 'r')['x']
        if self.dataset_y is None:
            self.dataset_y = h5py.File(labels_path, 'r')['y']

        # get one pair of X, Y and return them, transform if needed
        image = self.dataset_x[index]
        label = self.dataset_y[index]

        if self.transform:
            image = self.transform(image)

        return (image, label)

# %% [markdown]
# ### Configurations params, Dataset + Dataloader Instantiation

# %%
CHECKPOINT_DIR = 'checkpoint'
drive_base_path = 'gdrive/MyDrive/pcamv1/'
BATCH_SIZE = 16
dataloader_params = {'batch_size': BATCH_SIZE, 'shuffle': True, 'num_workers': 2}

train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_path = drive_base_path + 'camelyonpatch_level_2_split_train'
val_path = drive_base_path + 'camelyonpatch_level_2_split_valid'
test_path = drive_base_path + 'camelyonpatch_level_2_split_test'

test_dataset = H5Dataset(test_path, transform=test_transforms)
test_loader = DataLoader(test_dataset, **dataloader_params)

val_dataset = H5Dataset(val_path, transform=test_transforms)
dev_loader = DataLoader(val_dataset, **dataloader_params)

train_dataset = H5Dataset(train_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, **dataloader_params)

# %% [markdown]
# ### Model Architecture Class Definition

# %%
class CNN_V2(nn.Module):
    """Implemented by paper: http://cs230.stanford.edu/projects_winter_2019/posters/15813053.pdf"""
    def __init__(self, p = 0.5):
        # log dropout parameter
        wandb.config.dropout = p
        """Init method for initializaing the CNN model"""
        super(CNN_V2, self).__init__()
        # 1. Convolutional layers
        # Single image is in shape: 3x96x96 (CxHxW, H==W), RGB images
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 16, kernel_size = 3, stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, stride = 1, padding = 1)
        self.bn4 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 0)
        
        self.dropout = nn.Dropout(p = p)
        
        # 2. FC layers to final output
        self.fc1 = nn.Linear(in_features = 128*6*6, out_features = 512)
        self.fc_bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(in_features = 512, out_features = 256)
        self.fc_bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(in_features = 256, out_features = 128)
        self.fc_bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(in_features = 128, out_features = 1)

    def forward(self, x):
        # Convolution Layers, followed by Batch Normalizations, Maxpool, and ReLU
        x = self.bn1(self.conv1(x))                      # batch_size x 96 x 96 x 16
        x = self.pool(F.relu(x))                         # batch_size x 48 x 48 x 16
        x = self.bn2(self.conv2(x))                      # batch_size x 48 x 48 x 32
        x = self.pool(F.relu(x))                         # batch_size x 24 x 24 x 32
        x = self.bn3(self.conv3(x))                      # batch_size x 24 x 24 x 64
        x = self.pool(F.relu(x))                         # batch_size x 12 x 12 x 64
        x = self.bn4(self.conv4(x))                      # batch_size x 12 x 12 x 128
        x = self.pool(F.relu(x))                         # batch_size x  6 x  6 x 128
        # Flatten the output for each image
        x = x.reshape(-1, self.num_flat_features(x))        # batch_size x 6*6*128
        
        # Apply 4 FC Layers
        x = self.fc1(x)
        x = self.fc_bn1(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc2(x)
        x = self.fc_bn2(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc3(x)
        x = self.fc_bn3(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc4(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %% [markdown]
# ### Helper Functions

# %%
def sigmoid(x):
    """This method calculates the sigmoid function"""
    return 1.0/(1.0 + np.exp(-x))

def training_accuracy(predicted, true, i, acc, tpr, tnr):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu() # Taking the predictions, why cpu and not device?
    true = true.cpu() # Taking the labels, why cpu and not device?
    
    predicted = (sigmoid(predicted.data.numpy()) > 0.5) # Using sigmoid above, if prediction > 0.5 it is 1
    true = true.data.numpy() # Numpy - can't combine above?
    accuracy = np.sum(predicted == true) / true.shape[0] # Accuracy is: (TP + TN)/(TP + TN + FN + FP)
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1) # TPR: TP / (TP + FN) aka Recall
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0) # TNR: TN / (FP + TN)
    acc = acc * (i) / (i + 1) + accuracy / (i + 1)
    tpr = tpr * (i) / (i + 1) + true_positive_rate / (i + 1)
    tnr = tnr * (i) / (i + 1) + true_negative_rate / (i + 1)
    return acc, tpr, tnr

def dev_accuracy(predicted, target):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu()
    target = target.cpu()
    predicted = (sigmoid(predicted.data.numpy()) > 0.5)
    true = target.data.numpy()
    accuracy = np.sum(predicted == true) / true.shape[0]
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1)
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0)
    return accuracy, true_positive_rate, true_negative_rate

# def train_dev_test_split_indices(dataset_size, train_split=0.8, dev_split=0.1, seed=30):
#     """Given a dataset size, returns the train/dev/test split indices"""
#     indices = list(range(dataset_size))
#     train_split_end = int(np.floor(train_split * dataset_size))
#     dev_split_end = int(np.floor(dev_split * dataset_size)) + train_split_end
#     np.random.seed(seed)
#     np.random.shuffle(indices)
#     train_indices = indices[:train_split_end]
#     dev_indices = indices[train_split_end:dev_split_end]
#     test_indices = indices[dev_split_end:]
#     return train_indices, dev_indices, test_indices

# def train_dev_test_split_indices_from_dataset(dataset, train_split=0.8, dev_split=0.1, seed=30):
#     """Given a dataset, returns the train/dev/test split indices"""
#     dataset_size = len(dataset)
#     indices = list(range(dataset_size))
#     train_split_end = int(np.floor(train_split * dataset_size))
#     dev_split_end = int(np.floor(dev_split * dataset_size)) + train_split_end
#     np.random.seed(seed)
#     np.random.shuffle(indices)
#     train_indices = indices[:train_split_end]
#     dev_indices = indices[train_split_end:dev_split_end]
#     test_indices = indices[dev_split_end:]
#     return train_indices, dev_indices, test_indices

def fetch_state(epoch, model, optimizer, dev_loss_min, dev_acc_max):
    """Returns the state dictionary for a model and optimizer"""
    state = {
        'epoch': epoch,
        'dev_loss_min': dev_loss_min,
        'dev_acc_max': dev_acc_max,
        'state_dict': model.state_dict(),
        'optim_dict': optimizer.state_dict()
    }
    return state

def save_checkpoint(state, is_best = False, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Saves model and training parameters at checkpoint + 'last.pth.tar'. If is_best==True, also saves
    checkpoint + 'best.pth.tar'

    Args:
        state: (dict) contains model's state_dict, may contain other keys such as epoch, optimizer state_dict
        is_best: (bool) True if it is the best model seen till now
        checkpoint: (string) folder where parameters are to be saved
    """
    filepath = os.path.join(checkpoint, 'last_v2.pth.tar')
    if (not os.path.exists(checkpoint)):
        print("Checkpoint Directory does not exist! Making directory {}".format(checkpoint))
        os.mkdir(checkpoint)
    else:
        print("Checkpoint Directory exists! ")
    torch.save(state, filepath)
    if (is_best):
        shutil.copyfile(filepath, os.path.join(checkpoint, 'best_v2.pth.tar'))
        
def load_checkpoint(model, optimizer = None, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Loads model parameters (state_dict) from file_path. If optimizer is provided, loads state_dict of
    optimizer assuming it is present in checkpoint.

    Args:
        checkpoint: (string) filename which needs to be loaded
        model: (torch.nn.Module) model for which the parameters are loaded
        optimizer: (torch.optim) optional: resume optimizer from checkpoint
    """
    if not os.path.exists(checkpoint):
        print("File doesn't exist {}".format(checkpoint))
        checkpoint = None
        return
    checkpoint = torch.load(checkpoint)
    model.load_state_dict(checkpoint['state_dict'])

    if optimizer:
        optimizer.load_state_dict(checkpoint['optim_dict'])

    return checkpoint

# %%
# Load model
USE_GPU = torch.cuda.is_available()

model = CNN_V2()
if (USE_GPU):
    model.cuda()

# Hyperparameters
lr = 5e-4
wandb.config.learning_rate = lr

# Parameters
num_workers = 0
total_epochs = 0
num_epochs = 10
early_stop_limit = 10
bad_epoch_count = 0
stop = False
train_loss_min = np.Inf
dev_loss_min = np.Inf
dev_acc_max = 0

# %%
# Optimizer + Loss Function
#optimizer = optim.Adam(model.parameters(), lr = lr)
optimizer = optim.SGD(model.parameters(), lr = lr)   # SWATS
criterion = nn.BCEWithLogitsLoss() # Binary Cross Entropy for binary classification - malignant / benign

# Load best checkpoint
best_checkpoint = os.path.join(CHECKPOINT_DIR, 'best_v2.pth.tar');
#checkpoint = load_checkpoint(model = model, optimizer = optimizer, checkpoint = best_checkpoint)
# checkpoint = load_checkpoint(model = model, optimizer = None, checkpoint = best_checkpoint) # SWATS
# total_epochs = None if checkpoint is None else checkpoint['epoch']
total_epochs = 0

# Initialize arrays for plot
train_loss_arr = []
train_acc_arr = []
train_tpr_arr = []
train_tnr_arr = []

dev_loss_arr = []
dev_acc_arr = []
dev_tpr_arr = []
dev_tnr_arr = []

# %%
# Loop over the dataset multiple times
total_num_epochs = total_epochs + num_epochs
for epoch in range(num_epochs):
    curr_epoch = total_epochs + epoch + 1
    # Keep track of training loss
    train_loss = []
    # Keep track of dev loss
    dev_loss = []
    # Keep track of accuracy measurements
    acc, tpr, tnr = 0.0, 0.0, 0.0

    # Train the model
    start_time = time.time()
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        if USE_GPU:
            data, target = image.cuda(), label.cuda()
        else:
            data, target = image, label
        # Zero the parameter gradients
        optimizer.zero_grad()
        # Forward pass
        output = model(data)
        # Update target to be the same dimensions as output
        target = target.view(output.shape[0], 1).float()
        # Get accuracy measurements
        acc, tpr, tnr = training_accuracy(output, target, batch_idx, acc, tpr, tnr)
        # Calculate the batch's loss
        curr_train_loss = criterion(output, target)
        # Update the training loss
        train_loss.append(curr_train_loss.item())
        # Backward pass
        curr_train_loss.backward()
        # Perform a single optimization step to update parameters
        optimizer.step()
        # Print debug info every 64 batches
        if (batch_idx) % 64 == 0:
            print('Epoch {}/{}; Iter {}/{}; Loss: {:.4f}; Acc: {:.3f}; True Pos: {:.3f}; True Neg: {:.3f}'
                   .format(curr_epoch, total_num_epochs, batch_idx + 1, len(train_loader), curr_train_loss.item(), acc, tpr, tnr))
            
    end_time = time.time()
    
    # Evaluate the model
    model.eval()
    with torch.no_grad():
        for batch_idx, (image, label) in enumerate(dev_loader):
            if USE_GPU:
                data, target = image.cuda(), label.cuda()
            else:
                data, target = image, label
            # Get predicted output
            output = model(data)
            # Update target to be the same dimensions as output
            target = target.view(output.shape[0], 1).float()
            # Get accuracy measurements
            dev_acc, dev_tpr, dev_tnr = dev_accuracy(output, target)
            # Calculate the batch's loss
            curr_dev_loss = criterion(output, target)
            # Update the dev loss
            dev_loss.append(curr_dev_loss.item())
    
    # Calculate average loss
    avg_train_loss = np.mean(np.array(train_loss))
    avg_dev_loss = np.mean(np.array(dev_loss))
    
    # Update dev loss arrays
    dev_loss_arr.append(avg_dev_loss)
    dev_acc_arr.append(dev_acc)
    dev_tpr_arr.append(dev_tpr)
    dev_tnr_arr.append(dev_tnr)

    # Update training loss arrays
    train_loss_arr.append(avg_train_loss)
    train_acc_arr.append(acc)
    train_tpr_arr.append(tpr)
    train_tnr_arr.append(tnr)

    print('Epoch {}/{}; Avg. Train Loss: {:.4f}; Train Acc: {:.3f}; Train TPR: {:.3f}; Train TNR: {:.3f}; Epoch Time: {} mins; \nAvg. Dev Loss: {:.4f}; Dev Acc: {:.3f}; Dev TPR: {:.3f}; Dev TNR: {:.3f}\n'
        .format(curr_epoch, total_num_epochs, avg_train_loss, acc, tpr, tnr, round((end_time - start_time)/ 60., 2), avg_dev_loss, dev_acc, dev_tpr, dev_tnr))
    
    wandb.log({'epoch': curr_epoch, 'loss': avg_train_loss, 'accuracy': acc, 'tpr': tpr, 'time_per_epoch_min': round((end_time - start_time)/ 60., 2)})

    if avg_dev_loss < dev_loss_min:
        print('Dev loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
              .format(dev_loss_min, avg_dev_loss))
        dev_loss_min = avg_dev_loss
        is_best = False
        if (dev_acc >= dev_acc_max):
            is_best = True
            dev_acc_max = dev_acc
        state = fetch_state(epoch = curr_epoch, model = model, optimizer = optimizer, 
                            dev_loss_min = dev_loss_min, 
                            dev_acc_max = dev_acc_max)
        save_checkpoint(state = state, is_best = is_best)
        bad_epoch_count = 0
    # If dev loss didn't improve, increase bad_epoch_count and stop if
    # bad_epoch_count >= early_stop_limit
    else:
        bad_epoch_count += 1
        print('{} epochs of increasing dev loss ({:.6f} --> {:.6f}).'
              .format(bad_epoch_count, dev_loss_min, avg_dev_loss))
        if (bad_epoch_count >= early_stop_limit):
            print('Stopping training')
            stop = True

    if (stop):
        break
# Out:
# Epoch 1/10; Iter 1/16384; Loss: 0.7781; Acc: 0.500; True Pos: 0.444; True Neg: 0.571
# Epoch 1/10; Iter 65/16384; Loss: 0.7331; Acc: 0.541; True Pos: 0.576; True Neg: 0.503
# Epoch 1/10; Iter 129/16384; Loss: 0.6368; Acc: 0.541; True Pos: 0.569; True Neg: 0.510
# Epoch 1/10; Iter 193/16384; Loss: 0.6694; Acc: 0.554; True Pos: 0.580; True Neg: 0.529
# Epoch 1/10; Iter 257/16384; Loss: 0.7559; Acc: 0.562; True Pos: 0.587; True Neg: 0.540
# Epoch 1/10; Iter 321/16384; Loss: 0.8336; Acc: 0.570; True Pos: 0.597; True Neg: 0.553
# Epoch 1/10; Iter 385/16384; Loss: 0.6174; Acc: 0.581; True Pos: 0.608; True Neg: 0.566
# Epoch 1/10; Iter 449/16384; Loss: 0.7336; Acc: 0.586; True Pos: 0.611; True Neg: 0.574
# Epoch 1/10; Iter 513/16384; Loss: 0.6169; Acc: 0.595; True Pos: 0.619; True Neg: 0.583
# Epoch 1/10; Iter 577/16384; Loss: 0.5558; Acc: 0.601; True Pos: 0.625; True Neg: 0.592
# Epoch 1/10; Iter 641/16384; Loss: 0.5327; Acc: 0.609; True Pos: 0.632; True Neg: 0.602
# Epoch 1/10; Iter 705/16384; Loss: 0.6256; Acc: 0.617; True Pos: 0.640; True Neg: 0.612
# Epoch 1/10; Iter 769/16384; Loss: 0.5938; Acc: 0.625; True Pos: 0.645; True Neg: 0.623
# Epoch 1/10; Iter 833/16384; Loss: 0.5022; Acc: 0.631; True Pos: 0.651; True Neg: 0.630
# Epoch 1/10; Iter 897/16384; Loss: 0.5450; Acc: 0.635; True Pos: 0.652; True Neg: 0.636
# Epoch 1/10; Iter 961/16384; Loss: 0.6191; Acc: 0.640; True Pos: 0.656; True Neg: 0.642
# Epoch 1/10; Iter 1025/16384; Loss: 0.5154; Acc: 0.646; True Pos: 0.661; True Neg: 0.648
# Epoch 1/10; Iter 1089/16384; Loss: 0.6674; Acc: 0.651; True Pos: 0.667; True Neg: 0.654
# Epoch 1/10; Iter 1153/16384; Loss: 0.5089; Acc: 0.655; True Pos: 0.671; True Neg: 0.658
# Epoch 1/10; Iter 1217/16384; Loss: 0.5031; Acc: 0.659; True Pos: 0.673; True Neg: 0.664
# Epoch 1/10; Iter 1281/16384; Loss: 0.7829; Acc: 0.662; True Pos: 0.676; True Neg: 0.668
# Epoch 1/10; Iter 1345/16384; Loss: 0.9541; Acc: 0.665; True Pos: 0.678; True Neg: 0.671
# Epoch 1/10; Iter 1409/16384; Loss: 0.6510; Acc: 0.666; True Pos: 0.679; True Neg: 0.674
# Epoch 1/10; Iter 1473/16384; Loss: 0.4489; Acc: 0.668; True Pos: 0.680; True Neg: 0.677
# Epoch 1/10; Iter 1537/16384; Loss: 0.3924; Acc: 0.670; True Pos: 0.682; True Neg: 0.679
# Epoch 1/10; Iter 1601/16384; Loss: 0.7242; Acc: 0.672; True Pos: 0.684; True Neg: 0.681
# Epoch 1/10; Iter 1665/16384; Loss: 0.6566; Acc: 0.675; True Pos: 0.686; True Neg: 0.685
# Epoch 1/10; Iter 1729/16384; Loss: 0.5646; Acc: 0.678; True Pos: 0.689; True Neg: 0.689
# Epoch 1/10; Iter 1793/16384; Loss: 0.5499; Acc: 0.681; True Pos: 0.691; True Neg: 0.693
# Epoch 1/10; Iter 1857/16384; Loss: 0.4754; Acc: 0.683; True Pos: 0.692; True Neg: 0.696
# Epoch 1/10; Iter 1921/16384; Loss: 0.5809; Acc: 0.685; True Pos: 0.694; True Neg: 0.699
# Epoch 1/10; Iter 1985/16384; Loss: 0.6569; Acc: 0.687; True Pos: 0.696; True Neg: 0.701
# Epoch 1/10; Iter 2049/16384; Loss: 0.6873; Acc: 0.689; True Pos: 0.698; True Neg: 0.702
# Epoch 1/10; Iter 2113/16384; Loss: 0.3918; Acc: 0.691; True Pos: 0.700; True Neg: 0.705
# Epoch 1/10; Iter 2177/16384; Loss: 0.4125; Acc: 0.694; True Pos: 0.702; True Neg: 0.708
# Epoch 1/10; Iter 2241/16384; Loss: 0.5901; Acc: 0.696; True Pos: 0.704; True Neg: 0.710
# Epoch 1/10; Iter 2305/16384; Loss: 0.4544; Acc: 0.697; True Pos: 0.705; True Neg: 0.711
# Epoch 1/10; Iter 2369/16384; Loss: 0.4349; Acc: 0.698; True Pos: 0.706; True Neg: 0.713
# Epoch 1/10; Iter 2433/16384; Loss: 0.4626; Acc: 0.700; True Pos: 0.707; True Neg: 0.715
# Epoch 1/10; Iter 2497/16384; Loss: 0.7108; Acc: 0.701; True Pos: 0.708; True Neg: 0.716
# Epoch 1/10; Iter 2561/16384; Loss: 0.6376; Acc: 0.702; True Pos: 0.709; True Neg: 0.717
# Epoch 1/10; Iter 2625/16384; Loss: 0.3313; Acc: 0.703; True Pos: 0.710; True Neg: 0.718
# Epoch 1/10; Iter 2689/16384; Loss: 0.4397; Acc: 0.704; True Pos: 0.711; True Neg: 0.719
# Epoch 1/10; Iter 2753/16384; Loss: 0.7147; Acc: 0.705; True Pos: 0.713; True Neg: 0.720
# Epoch 1/10; Iter 2817/16384; Loss: 0.5096; Acc: 0.706; True Pos: 0.714; True Neg: 0.722
# Epoch 1/10; Iter 2881/16384; Loss: 0.5029; Acc: 0.707; True Pos: 0.715; True Neg: 0.722
# Epoch 1/10; Iter 2945/16384; Loss: 0.4048; Acc: 0.708; True Pos: 0.717; True Neg: 0.723
# Epoch 1/10; Iter 3009/16384; Loss: 0.3043; Acc: 0.709; True Pos: 0.718; True Neg: 0.724
# Epoch 1/10; Iter 3073/16384; Loss: 0.4593; Acc: 0.710; True Pos: 0.719; True Neg: 0.725
# Epoch 1/10; Iter 3137/16384; Loss: 0.4733; Acc: 0.711; True Pos: 0.720; True Neg: 0.726
# Epoch 1/10; Iter 3201/16384; Loss: 0.4731; Acc: 0.712; True Pos: 0.721; True Neg: 0.727
# Epoch 1/10; Iter 3265/16384; Loss: 0.6905; Acc: 0.713; True Pos: 0.721; True Neg: 0.728
# Epoch 1/10; Iter 3329/16384; Loss: 0.4692; Acc: 0.714; True Pos: 0.722; True Neg: 0.729
# Epoch 1/10; Iter 3393/16384; Loss: 0.5005; Acc: 0.714; True Pos: 0.723; True Neg: 0.730
# Epoch 1/10; Iter 3457/16384; Loss: 0.4223; Acc: 0.715; True Pos: 0.723; True Neg: 0.731
# Epoch 1/10; Iter 3521/16384; Loss: 0.6253; Acc: 0.716; True Pos: 0.725; True Neg: 0.732
# Epoch 1/10; Iter 3585/16384; Loss: 0.4351; Acc: 0.717; True Pos: 0.726; True Neg: 0.732
# Epoch 1/10; Iter 3649/16384; Loss: 0.3168; Acc: 0.718; True Pos: 0.727; True Neg: 0.733
# Epoch 1/10; Iter 3713/16384; Loss: 0.6240; Acc: 0.718; True Pos: 0.727; True Neg: 0.733
# Epoch 1/10; Iter 3777/16384; Loss: 0.4690; Acc: 0.719; True Pos: 0.729; True Neg: 0.734
# Epoch 1/10; Iter 3841/16384; Loss: 0.4159; Acc: 0.720; True Pos: 0.729; True Neg: 0.735
# Epoch 1/10; Iter 3905/16384; Loss: 0.7332; Acc: 0.720; True Pos: 0.730; True Neg: 0.735
# Epoch 1/10; Iter 3969/16384; Loss: 0.5947; Acc: 0.721; True Pos: 0.731; True Neg: 0.736
# Epoch 1/10; Iter 4033/16384; Loss: 0.6688; Acc: 0.722; True Pos: 0.732; True Neg: 0.737
# Epoch 1/10; Iter 4097/16384; Loss: 0.6304; Acc: 0.723; True Pos: 0.733; True Neg: 0.737
# Epoch 1/10; Iter 4161/16384; Loss: 0.5058; Acc: 0.724; True Pos: 0.734; True Neg: 0.738
# Epoch 1/10; Iter 4225/16384; Loss: 0.2997; Acc: 0.724; True Pos: 0.734; True Neg: 0.739
# Epoch 1/10; Iter 4289/16384; Loss: 0.3970; Acc: 0.725; True Pos: 0.735; True Neg: 0.739
# Epoch 1/10; Iter 4353/16384; Loss: 0.5213; Acc: 0.725; True Pos: 0.736; True Neg: 0.740
# Epoch 1/10; Iter 4417/16384; Loss: 0.4545; Acc: 0.726; True Pos: 0.736; True Neg: 0.740
# Epoch 1/10; Iter 4481/16384; Loss: 0.3977; Acc: 0.727; True Pos: 0.737; True Neg: 0.741
# Epoch 1/10; Iter 4545/16384; Loss: 0.4399; Acc: 0.727; True Pos: 0.737; True Neg: 0.741
# Epoch 1/10; Iter 4609/16384; Loss: 0.4303; Acc: 0.727; True Pos: 0.738; True Neg: 0.742
# Epoch 1/10; Iter 4673/16384; Loss: 0.4767; Acc: 0.728; True Pos: 0.739; True Neg: 0.742
# Epoch 1/10; Iter 4737/16384; Loss: 0.7201; Acc: 0.729; True Pos: 0.740; True Neg: 0.743
# Epoch 1/10; Iter 4801/16384; Loss: 0.5721; Acc: 0.730; True Pos: 0.740; True Neg: 0.744
# Epoch 1/10; Iter 4865/16384; Loss: 0.6281; Acc: 0.730; True Pos: 0.741; True Neg: 0.744
# Epoch 1/10; Iter 4929/16384; Loss: 0.3852; Acc: 0.730; True Pos: 0.741; True Neg: 0.745
# Epoch 1/10; Iter 4993/16384; Loss: 0.4415; Acc: 0.731; True Pos: 0.742; True Neg: 0.746
# Epoch 1/10; Iter 5057/16384; Loss: 0.4329; Acc: 0.732; True Pos: 0.742; True Neg: 0.746
# Epoch 1/10; Iter 5121/16384; Loss: 0.4959; Acc: 0.732; True Pos: 0.743; True Neg: 0.747
# Epoch 1/10; Iter 5185/16384; Loss: 0.4850; Acc: 0.733; True Pos: 0.743; True Neg: 0.748
# Epoch 1/10; Iter 5249/16384; Loss: 0.3623; Acc: 0.733; True Pos: 0.743; True Neg: 0.748
# Epoch 1/10; Iter 5313/16384; Loss: 0.4423; Acc: 0.734; True Pos: 0.744; True Neg: 0.749
# Epoch 1/10; Iter 5377/16384; Loss: 0.4933; Acc: 0.734; True Pos: 0.744; True Neg: 0.749
# Epoch 1/10; Iter 5441/16384; Loss: 0.3830; Acc: 0.734; True Pos: 0.744; True Neg: 0.750
# Epoch 1/10; Iter 5505/16384; Loss: 0.3844; Acc: 0.735; True Pos: 0.745; True Neg: 0.750
# Epoch 1/10; Iter 5569/16384; Loss: 0.4772; Acc: 0.735; True Pos: 0.745; True Neg: 0.751
# Epoch 1/10; Iter 5633/16384; Loss: 0.5382; Acc: 0.736; True Pos: 0.746; True Neg: 0.751
# Epoch 1/10; Iter 5697/16384; Loss: 0.3718; Acc: 0.736; True Pos: 0.746; True Neg: 0.751
# Epoch 1/10; Iter 5761/16384; Loss: 0.3397; Acc: 0.736; True Pos: 0.747; True Neg: 0.751
# Epoch 1/10; Iter 5825/16384; Loss: 0.4339; Acc: 0.737; True Pos: 0.748; True Neg: 0.752
# Epoch 1/10; Iter 5889/16384; Loss: 0.4342; Acc: 0.737; True Pos: 0.748; True Neg: 0.752
# Epoch 1/10; Iter 5953/16384; Loss: 0.6265; Acc: 0.738; True Pos: 0.748; True Neg: 0.753
# Epoch 1/10; Iter 6017/16384; Loss: 0.4204; Acc: 0.738; True Pos: 0.749; True Neg: 0.753
# Epoch 1/10; Iter 6081/16384; Loss: 0.4281; Acc: 0.739; True Pos: 0.749; True Neg: 0.754
# Epoch 1/10; Iter 6145/16384; Loss: 0.5198; Acc: 0.739; True Pos: 0.750; True Neg: 0.754
# Epoch 1/10; Iter 6209/16384; Loss: 0.3940; Acc: 0.740; True Pos: 0.750; True Neg: 0.755
# Epoch 1/10; Iter 6273/16384; Loss: 0.4035; Acc: 0.740; True Pos: 0.750; True Neg: 0.755
# Epoch 1/10; Iter 6337/16384; Loss: 0.2613; Acc: 0.740; True Pos: 0.750; True Neg: 0.755
# Epoch 1/10; Iter 6401/16384; Loss: 0.5545; Acc: 0.740; True Pos: 0.750; True Neg: 0.756
# Epoch 1/10; Iter 6465/16384; Loss: 0.5979; Acc: 0.741; True Pos: 0.751; True Neg: 0.756
# Epoch 1/10; Iter 6529/16384; Loss: 0.8199; Acc: 0.741; True Pos: 0.751; True Neg: 0.756
# Epoch 1/10; Iter 6593/16384; Loss: 0.6185; Acc: 0.741; True Pos: 0.752; True Neg: 0.757
# Epoch 1/10; Iter 6657/16384; Loss: 0.5213; Acc: 0.742; True Pos: 0.752; True Neg: 0.757
# Epoch 1/10; Iter 6721/16384; Loss: 0.4667; Acc: 0.742; True Pos: 0.752; True Neg: 0.758
# Epoch 1/10; Iter 6785/16384; Loss: 0.2573; Acc: 0.743; True Pos: 0.753; True Neg: 0.758
# Epoch 1/10; Iter 6849/16384; Loss: 0.2276; Acc: 0.743; True Pos: 0.753; True Neg: 0.759
# Epoch 1/10; Iter 6913/16384; Loss: 0.4082; Acc: 0.744; True Pos: 0.754; True Neg: 0.759
# Epoch 1/10; Iter 6977/16384; Loss: 0.7085; Acc: 0.744; True Pos: 0.754; True Neg: 0.759
# Epoch 1/10; Iter 7041/16384; Loss: 0.5929; Acc: 0.744; True Pos: 0.754; True Neg: 0.760
# Epoch 1/10; Iter 7105/16384; Loss: 0.8339; Acc: 0.745; True Pos: 0.755; True Neg: 0.760
# Epoch 1/10; Iter 7169/16384; Loss: 0.6221; Acc: 0.745; True Pos: 0.755; True Neg: 0.760
# Epoch 1/10; Iter 7233/16384; Loss: 0.4945; Acc: 0.745; True Pos: 0.755; True Neg: 0.761
# Epoch 1/10; Iter 7297/16384; Loss: 0.5093; Acc: 0.745; True Pos: 0.755; True Neg: 0.761
# Epoch 1/10; Iter 7361/16384; Loss: 0.4412; Acc: 0.746; True Pos: 0.756; True Neg: 0.761
# Epoch 1/10; Iter 7425/16384; Loss: 0.3532; Acc: 0.746; True Pos: 0.756; True Neg: 0.762
# Epoch 1/10; Iter 7489/16384; Loss: 0.4594; Acc: 0.746; True Pos: 0.757; True Neg: 0.762
# Epoch 1/10; Iter 7553/16384; Loss: 0.3673; Acc: 0.747; True Pos: 0.757; True Neg: 0.762
# Epoch 1/10; Iter 7617/16384; Loss: 0.5268; Acc: 0.747; True Pos: 0.757; True Neg: 0.762
# Epoch 1/10; Iter 7681/16384; Loss: 0.3865; Acc: 0.747; True Pos: 0.758; True Neg: 0.763
# Epoch 1/10; Iter 7745/16384; Loss: 0.5269; Acc: 0.747; True Pos: 0.758; True Neg: 0.763
# Epoch 1/10; Iter 7809/16384; Loss: 0.4608; Acc: 0.747; True Pos: 0.758; True Neg: 0.763
# Epoch 1/10; Iter 7873/16384; Loss: 0.3326; Acc: 0.748; True Pos: 0.758; True Neg: 0.764
# Epoch 1/10; Iter 7937/16384; Loss: 0.2447; Acc: 0.748; True Pos: 0.758; True Neg: 0.765
# Epoch 1/10; Iter 8001/16384; Loss: 0.4732; Acc: 0.749; True Pos: 0.759; True Neg: 0.765
# Epoch 1/10; Iter 8065/16384; Loss: 0.3237; Acc: 0.749; True Pos: 0.759; True Neg: 0.765
# Epoch 1/10; Iter 8129/16384; Loss: 0.3237; Acc: 0.749; True Pos: 0.759; True Neg: 0.766
# Epoch 1/10; Iter 8193/16384; Loss: 0.3358; Acc: 0.750; True Pos: 0.760; True Neg: 0.766
# Epoch 1/10; Iter 8257/16384; Loss: 0.2800; Acc: 0.750; True Pos: 0.760; True Neg: 0.766
# Epoch 1/10; Iter 8321/16384; Loss: 0.1981; Acc: 0.750; True Pos: 0.761; True Neg: 0.767
# Epoch 1/10; Iter 8385/16384; Loss: 0.3254; Acc: 0.751; True Pos: 0.761; True Neg: 0.767
# Epoch 1/10; Iter 8449/16384; Loss: 0.5002; Acc: 0.751; True Pos: 0.761; True Neg: 0.767
# Epoch 1/10; Iter 8513/16384; Loss: 0.3192; Acc: 0.751; True Pos: 0.761; True Neg: 0.768
# Epoch 1/10; Iter 8577/16384; Loss: 0.7324; Acc: 0.752; True Pos: 0.762; True Neg: 0.768
# Epoch 1/10; Iter 8641/16384; Loss: 0.5432; Acc: 0.752; True Pos: 0.762; True Neg: 0.769
# Epoch 1/10; Iter 8705/16384; Loss: 0.4920; Acc: 0.752; True Pos: 0.762; True Neg: 0.769
# Epoch 1/10; Iter 8769/16384; Loss: 0.3019; Acc: 0.753; True Pos: 0.763; True Neg: 0.769
# Epoch 1/10; Iter 8833/16384; Loss: 0.3035; Acc: 0.753; True Pos: 0.763; True Neg: 0.769
# Epoch 1/10; Iter 8897/16384; Loss: 0.3892; Acc: 0.753; True Pos: 0.763; True Neg: 0.770
# Epoch 1/10; Iter 8961/16384; Loss: 0.7882; Acc: 0.753; True Pos: 0.763; True Neg: 0.770
# Epoch 1/10; Iter 9025/16384; Loss: 0.5164; Acc: 0.754; True Pos: 0.763; True Neg: 0.770
# Epoch 1/10; Iter 9089/16384; Loss: 0.7484; Acc: 0.754; True Pos: 0.764; True Neg: 0.771
# Epoch 1/10; Iter 9153/16384; Loss: 0.3426; Acc: 0.754; True Pos: 0.764; True Neg: 0.771
# Epoch 1/10; Iter 9217/16384; Loss: 0.7229; Acc: 0.754; True Pos: 0.764; True Neg: 0.771
# Epoch 1/10; Iter 9281/16384; Loss: 0.6088; Acc: 0.755; True Pos: 0.765; True Neg: 0.771
# Epoch 1/10; Iter 9345/16384; Loss: 0.5115; Acc: 0.755; True Pos: 0.765; True Neg: 0.772
# Epoch 1/10; Iter 9409/16384; Loss: 0.2799; Acc: 0.755; True Pos: 0.765; True Neg: 0.772
# Epoch 1/10; Iter 9473/16384; Loss: 0.7723; Acc: 0.756; True Pos: 0.765; True Neg: 0.772
# Epoch 1/10; Iter 9537/16384; Loss: 0.4916; Acc: 0.756; True Pos: 0.766; True Neg: 0.773
# Epoch 1/10; Iter 9601/16384; Loss: 0.4652; Acc: 0.756; True Pos: 0.766; True Neg: 0.773
# Epoch 1/10; Iter 9665/16384; Loss: 0.2191; Acc: 0.756; True Pos: 0.766; True Neg: 0.773
# Epoch 1/10; Iter 9729/16384; Loss: 0.2674; Acc: 0.756; True Pos: 0.766; True Neg: 0.773
# Epoch 1/10; Iter 9793/16384; Loss: 0.3487; Acc: 0.757; True Pos: 0.766; True Neg: 0.774
# Epoch 1/10; Iter 9857/16384; Loss: 0.6209; Acc: 0.757; True Pos: 0.767; True Neg: 0.774
# Epoch 1/10; Iter 9921/16384; Loss: 0.5115; Acc: 0.757; True Pos: 0.767; True Neg: 0.775
# Epoch 1/10; Iter 9985/16384; Loss: 0.4796; Acc: 0.758; True Pos: 0.767; True Neg: 0.775
# Epoch 1/10; Iter 10049/16384; Loss: 0.4408; Acc: 0.758; True Pos: 0.767; True Neg: 0.775
# Epoch 1/10; Iter 10113/16384; Loss: 0.2294; Acc: 0.758; True Pos: 0.768; True Neg: 0.775
# Epoch 1/10; Iter 10177/16384; Loss: 0.3051; Acc: 0.758; True Pos: 0.768; True Neg: 0.775
# Epoch 1/10; Iter 10241/16384; Loss: 0.5960; Acc: 0.759; True Pos: 0.768; True Neg: 0.776
# Epoch 1/10; Iter 10305/16384; Loss: 0.4439; Acc: 0.759; True Pos: 0.768; True Neg: 0.776
# Epoch 1/10; Iter 10369/16384; Loss: 0.2351; Acc: 0.759; True Pos: 0.768; True Neg: 0.776
# Epoch 1/10; Iter 10433/16384; Loss: 0.3121; Acc: 0.759; True Pos: 0.769; True Neg: 0.776
# Epoch 1/10; Iter 10497/16384; Loss: 0.3988; Acc: 0.760; True Pos: 0.769; True Neg: 0.777
# Epoch 1/10; Iter 10561/16384; Loss: 0.4041; Acc: 0.760; True Pos: 0.769; True Neg: 0.777
# Epoch 1/10; Iter 10625/16384; Loss: 0.3280; Acc: 0.760; True Pos: 0.770; True Neg: 0.777
# Epoch 1/10; Iter 10689/16384; Loss: 0.6885; Acc: 0.760; True Pos: 0.770; True Neg: 0.778
# Epoch 1/10; Iter 10753/16384; Loss: 0.5656; Acc: 0.761; True Pos: 0.770; True Neg: 0.778
# Epoch 1/10; Iter 10817/16384; Loss: 0.6357; Acc: 0.761; True Pos: 0.770; True Neg: 0.778
# Epoch 1/10; Iter 10881/16384; Loss: 0.3597; Acc: 0.761; True Pos: 0.770; True Neg: 0.778
# Epoch 1/10; Iter 10945/16384; Loss: 0.3672; Acc: 0.761; True Pos: 0.770; True Neg: 0.778
# Epoch 1/10; Iter 11009/16384; Loss: 0.4747; Acc: 0.761; True Pos: 0.770; True Neg: 0.779
# Epoch 1/10; Iter 11073/16384; Loss: 0.4222; Acc: 0.761; True Pos: 0.771; True Neg: 0.779
# Epoch 1/10; Iter 11137/16384; Loss: 0.5422; Acc: 0.762; True Pos: 0.771; True Neg: 0.779
# Epoch 1/10; Iter 11201/16384; Loss: 0.5495; Acc: 0.762; True Pos: 0.771; True Neg: 0.779
# Epoch 1/10; Iter 11265/16384; Loss: 0.3385; Acc: 0.762; True Pos: 0.771; True Neg: 0.779
# Epoch 1/10; Iter 11329/16384; Loss: 0.3556; Acc: 0.762; True Pos: 0.772; True Neg: 0.780
# Epoch 1/10; Iter 11393/16384; Loss: 0.3634; Acc: 0.762; True Pos: 0.772; True Neg: 0.780
# Epoch 1/10; Iter 11457/16384; Loss: 0.5942; Acc: 0.763; True Pos: 0.772; True Neg: 0.780
# Epoch 1/10; Iter 11521/16384; Loss: 0.3922; Acc: 0.763; True Pos: 0.772; True Neg: 0.780
# Epoch 1/10; Iter 11585/16384; Loss: 0.2674; Acc: 0.763; True Pos: 0.772; True Neg: 0.780
# Epoch 1/10; Iter 11649/16384; Loss: 0.3694; Acc: 0.763; True Pos: 0.773; True Neg: 0.781
# Epoch 1/10; Iter 11713/16384; Loss: 0.2436; Acc: 0.763; True Pos: 0.773; True Neg: 0.781
# Epoch 1/10; Iter 11777/16384; Loss: 0.2786; Acc: 0.764; True Pos: 0.773; True Neg: 0.781
# Epoch 1/10; Iter 11841/16384; Loss: 0.2763; Acc: 0.764; True Pos: 0.773; True Neg: 0.781
# Epoch 1/10; Iter 11905/16384; Loss: 0.7898; Acc: 0.764; True Pos: 0.773; True Neg: 0.782
# Epoch 1/10; Iter 11969/16384; Loss: 0.4951; Acc: 0.764; True Pos: 0.773; True Neg: 0.782
# Epoch 1/10; Iter 12033/16384; Loss: 0.2558; Acc: 0.764; True Pos: 0.774; True Neg: 0.782
# Epoch 1/10; Iter 12097/16384; Loss: 0.5170; Acc: 0.765; True Pos: 0.774; True Neg: 0.782
# Epoch 1/10; Iter 12161/16384; Loss: 0.3429; Acc: 0.765; True Pos: 0.774; True Neg: 0.782
# Epoch 1/10; Iter 12225/16384; Loss: 0.4650; Acc: 0.765; True Pos: 0.774; True Neg: 0.782
# Epoch 1/10; Iter 12289/16384; Loss: 0.4814; Acc: 0.765; True Pos: 0.774; True Neg: 0.782
# Epoch 1/10; Iter 12353/16384; Loss: 0.2570; Acc: 0.765; True Pos: 0.775; True Neg: 0.783
# Epoch 1/10; Iter 12417/16384; Loss: 0.3354; Acc: 0.765; True Pos: 0.775; True Neg: 0.783
# Epoch 1/10; Iter 12481/16384; Loss: 0.3180; Acc: 0.766; True Pos: 0.775; True Neg: 0.783
# Epoch 1/10; Iter 12545/16384; Loss: 0.3735; Acc: 0.766; True Pos: 0.775; True Neg: 0.783
# Epoch 1/10; Iter 12609/16384; Loss: 0.5345; Acc: 0.766; True Pos: 0.776; True Neg: 0.784
# Epoch 1/10; Iter 12673/16384; Loss: 0.3655; Acc: 0.766; True Pos: 0.776; True Neg: 0.784
# Epoch 1/10; Iter 12737/16384; Loss: 0.3303; Acc: 0.766; True Pos: 0.776; True Neg: 0.784
# Epoch 1/10; Iter 12801/16384; Loss: 0.8619; Acc: 0.767; True Pos: 0.776; True Neg: 0.784
# Epoch 1/10; Iter 12865/16384; Loss: 0.6126; Acc: 0.767; True Pos: 0.776; True Neg: 0.784
# Epoch 1/10; Iter 12929/16384; Loss: 0.4650; Acc: 0.767; True Pos: 0.777; True Neg: 0.785
# Epoch 1/10; Iter 12993/16384; Loss: 0.3620; Acc: 0.767; True Pos: 0.777; True Neg: 0.785
# Epoch 1/10; Iter 13057/16384; Loss: 0.2671; Acc: 0.767; True Pos: 0.777; True Neg: 0.785
# Epoch 1/10; Iter 13121/16384; Loss: 0.3392; Acc: 0.768; True Pos: 0.777; True Neg: 0.785
# Epoch 1/10; Iter 13185/16384; Loss: 0.4368; Acc: 0.768; True Pos: 0.777; True Neg: 0.785
# Epoch 1/10; Iter 13249/16384; Loss: 0.2536; Acc: 0.768; True Pos: 0.777; True Neg: 0.786
# Epoch 1/10; Iter 13313/16384; Loss: 0.4533; Acc: 0.768; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13377/16384; Loss: 0.3208; Acc: 0.768; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13441/16384; Loss: 0.6648; Acc: 0.768; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13505/16384; Loss: 0.4955; Acc: 0.768; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13569/16384; Loss: 0.6570; Acc: 0.769; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13633/16384; Loss: 0.5147; Acc: 0.769; True Pos: 0.778; True Neg: 0.786
# Epoch 1/10; Iter 13697/16384; Loss: 0.4201; Acc: 0.769; True Pos: 0.778; True Neg: 0.787
# Epoch 1/10; Iter 13761/16384; Loss: 0.4496; Acc: 0.769; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 13825/16384; Loss: 0.3320; Acc: 0.769; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 13889/16384; Loss: 0.5217; Acc: 0.769; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 13953/16384; Loss: 0.4065; Acc: 0.769; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 14017/16384; Loss: 0.2870; Acc: 0.770; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 14081/16384; Loss: 0.5433; Acc: 0.770; True Pos: 0.779; True Neg: 0.787
# Epoch 1/10; Iter 14145/16384; Loss: 0.6145; Acc: 0.770; True Pos: 0.780; True Neg: 0.788
# Epoch 1/10; Iter 14209/16384; Loss: 0.5176; Acc: 0.770; True Pos: 0.780; True Neg: 0.788
# Epoch 1/10; Iter 14273/16384; Loss: 0.2633; Acc: 0.770; True Pos: 0.780; True Neg: 0.788
# Epoch 1/10; Iter 14337/16384; Loss: 0.3576; Acc: 0.770; True Pos: 0.780; True Neg: 0.788
# Epoch 1/10; Iter 14401/16384; Loss: 0.3372; Acc: 0.771; True Pos: 0.780; True Neg: 0.788
# Epoch 1/10; Iter 14465/16384; Loss: 0.2435; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14529/16384; Loss: 0.3590; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14593/16384; Loss: 0.4155; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14657/16384; Loss: 0.4201; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14721/16384; Loss: 0.3085; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14785/16384; Loss: 0.4040; Acc: 0.771; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14849/16384; Loss: 0.4451; Acc: 0.772; True Pos: 0.781; True Neg: 0.789
# Epoch 1/10; Iter 14913/16384; Loss: 0.7242; Acc: 0.772; True Pos: 0.782; True Neg: 0.789
# Epoch 1/10; Iter 14977/16384; Loss: 0.3401; Acc: 0.772; True Pos: 0.782; True Neg: 0.790
# Epoch 1/10; Iter 15041/16384; Loss: 0.3766; Acc: 0.772; True Pos: 0.782; True Neg: 0.790
# Epoch 1/10; Iter 15105/16384; Loss: 0.5928; Acc: 0.772; True Pos: 0.782; True Neg: 0.790
# Epoch 1/10; Iter 15169/16384; Loss: 0.2990; Acc: 0.772; True Pos: 0.782; True Neg: 0.790
# Epoch 1/10; Iter 15233/16384; Loss: 0.2563; Acc: 0.773; True Pos: 0.783; True Neg: 0.790
# Epoch 1/10; Iter 15297/16384; Loss: 0.5670; Acc: 0.773; True Pos: 0.783; True Neg: 0.791
# Epoch 1/10; Iter 15361/16384; Loss: 0.3840; Acc: 0.773; True Pos: 0.783; True Neg: 0.791
# Epoch 1/10; Iter 15425/16384; Loss: 0.2910; Acc: 0.773; True Pos: 0.783; True Neg: 0.791
# Epoch 1/10; Iter 15489/16384; Loss: 0.8577; Acc: 0.773; True Pos: 0.783; True Neg: 0.791
# Epoch 1/10; Iter 15553/16384; Loss: 0.5295; Acc: 0.773; True Pos: 0.784; True Neg: 0.791
# Epoch 1/10; Iter 15617/16384; Loss: 0.3600; Acc: 0.773; True Pos: 0.784; True Neg: 0.791
# Epoch 1/10; Iter 15681/16384; Loss: 0.3531; Acc: 0.774; True Pos: 0.784; True Neg: 0.791
# Epoch 1/10; Iter 15745/16384; Loss: 0.3299; Acc: 0.774; True Pos: 0.784; True Neg: 0.791
# Epoch 1/10; Iter 15809/16384; Loss: 0.3399; Acc: 0.774; True Pos: 0.784; True Neg: 0.791
# Epoch 1/10; Iter 15873/16384; Loss: 0.3002; Acc: 0.774; True Pos: 0.785; True Neg: 0.791
# Epoch 1/10; Iter 15937/16384; Loss: 0.3316; Acc: 0.774; True Pos: 0.785; True Neg: 0.792
# Epoch 1/10; Iter 16001/16384; Loss: 0.2607; Acc: 0.774; True Pos: 0.785; True Neg: 0.792
# Epoch 1/10; Iter 16065/16384; Loss: 0.3744; Acc: 0.774; True Pos: 0.785; True Neg: 0.792
# Epoch 1/10; Iter 16129/16384; Loss: 0.3521; Acc: 0.775; True Pos: 0.785; True Neg: 0.792
# Epoch 1/10; Iter 16193/16384; Loss: 0.4351; Acc: 0.775; True Pos: 0.785; True Neg: 0.792
# Epoch 1/10; Iter 16257/16384; Loss: 0.2115; Acc: 0.775; True Pos: 0.786; True Neg: 0.792
# Epoch 1/10; Iter 16321/16384; Loss: 0.5921; Acc: 0.775; True Pos: 0.786; True Neg: 0.793
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# ...
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Before re-shape torch.Size([16, 3, 96, 96])
# Epoch 1/10; Avg. Train Loss: 0.4787; Train Acc: 0.775; Train TPR: 0.786; Train TNR: 0.793; Epoch Time: 24.01 mins;
# Avg. Dev Loss: 0.4247; Dev Acc: 0.875; Dev TPR: 0.667; Dev TNR: 1.000
#
# Dev loss decreased (inf --> 0.424658).  Saving model ...
# Checkpoint Directory exists!
# Epoch 2/10; Iter 1/16384; Loss: 0.3136; Acc: 0.875; True Pos: 1.000; True Neg: 0.800
# Epoch 2/10; Iter 65/16384; Loss: 0.3010; Acc: 0.826; True Pos: 0.844; True Neg: 0.846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6df645990153> in <module>()
#      13     start_time = time.time()
#      14     model.train()
# ---> 15     for batch_idx, (image, label) in enumerate(train_loader):
#      16         if USE_GPU:
#      17             data, target = image.cuda(), label.cuda()
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1180
#    1181             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1182             idx, data = self._get_data()
#    1183             self._tasks_outstanding -= 1
#    1184             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1146         else:
#    1147             while True:
# -> 1148                 success, data = self._try_get_data()
#    1149                 if success:
#    1150                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     984         #   (bool: whether successfully get data, any: data if successful else None)
#     985         try:
# --> 986             data = self._data_queue.get(timeout=timeout)
#     987             return (True, data)
#     988         except Exception as e:
#
# /usr/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# /usr/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /usr/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919
#     920             while True:
# --> 921                 ready = selector.select(timeout)
#     922                 if ready:
#     923                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
model.state_dict
# Out:
# <bound method Module.parameters of CNN_V2(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=4608, out_features=512, bias=True)
#   (fc_bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc_bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc_bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=128, out_features=1, bias=True)
# )>
