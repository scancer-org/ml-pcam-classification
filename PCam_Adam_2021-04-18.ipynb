# %% [markdown]
# <a href="https://colab.research.google.com/github/scancer-org/ml-pcam-classification/blob/main/PCam_Adam_2021-04-18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [PCAM Classification](https://github.com/basveeling/pcam) Project
# ## FSDL Online Course - Spring 2021
# ## Daniel Hen, Harish Narayanan

# %%
### TODO:
# 1. Test on test dataloader (final results)

# %% [markdown]
# ### Installing Required Packages

# %%
# %%capture
# !pip install -qqq wandb

# %% [markdown]
# ### Libraries + Functions import

# %%
import h5py
import numpy as np
import torch
import wandb
import os
import pandas as pd
import PIL.Image
import matplotlib.pyplot as plt
import shutil
import time
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from google.colab import drive
from torch.utils import data
from os import listdir
from pathlib import Path
from PIL import Image
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms, datasets

# %% [markdown]
# ### Weights & Biases parameters

# %%
wandb.login()
wandb.init(project="pcam-pytorch-training")
wandb.run.name = "pcam-pytorch-experiment#-" + wandb.run.id
print("Staring experiment: ", wandb.run.name)
# Out:
# wandb: Currently logged in as: daniel8hen (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.26<br/>
#                 Syncing run <strong style="color:#cdcd00">decent-monkey-19</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training</a><br/>
#                 Run page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/115nje19" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/115nje19</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210417_084317-115nje19</code><br/><br/>
# Staring experiment:  pcam-pytorch-experiment#-115nje19

# %% [markdown]
# ### Google Drive Mounting - for being able to easily read the data

# %%
drive.mount('/content/gdrive/')
# !ls gdrive/MyDrive/pcamv1
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# camelyonpatch_level_2_split_test_meta.csv
# camelyonpatch_level_2_split_test_x.h5
# camelyonpatch_level_2_split_test_y.h5
# camelyonpatch_level_2_split_train_mask.h5
# camelyonpatch_level_2_split_train_meta.csv
# camelyonpatch_level_2_split_train_x.h5
# camelyonpatch_level_2_split_train_y.h5
# camelyonpatch_level_2_split_valid_meta.csv
# camelyonpatch_level_2_split_valid_x.h5
# camelyonpatch_level_2_split_valid_y.h5

# %% [markdown]
# ### Class H5Dataset:
# Defines our dataset class in which we will load data from.
# <br>
# Also, deals with hdfs file format, which requires a customized reference in PyTorch

# %%
class H5Dataset(Dataset):
    def __init__(self, path, transform=None):
        self.file_path = path
        self.dataset_x = None
        self.dataset_y = None
        self.transform = transform
        ### Reading X part of HDF5
        with h5py.File(self.file_path + '_x.h5', 'r') as filex:
            self.dataset_x_len = len(filex['x'])

        ### Reading Y part of HDF5
        with h5py.File(self.file_path + '_y.h5', 'r') as filey:
            self.dataset_y_len = len(filey['y'])

    def __len__(self):
        assert self.dataset_x_len == self.dataset_y_len # Since we are reading from different sources, validating we are good in terms of size both X, Y
        return self.dataset_x_len

    def __getitem__(self, index):
        imgs_path = self.file_path + '_x.h5'
        labels_path = self.file_path + '_y.h5'

        if self.dataset_x is None:
            self.dataset_x = h5py.File(imgs_path, 'r')['x']
        if self.dataset_y is None:
            self.dataset_y = h5py.File(labels_path, 'r')['y']

        # get one pair of X, Y and return them, transform if needed
        image = self.dataset_x[index]
        label = self.dataset_y[index]

        if self.transform:
            image = self.transform(image)

        return (image, label)

# %% [markdown]
# ### Configurations params, Dataset + Dataloader Instantiation

# %%
CHECKPOINT_DIR = 'checkpoint'
drive_base_path = 'gdrive/MyDrive/pcamv1/'
BATCH_SIZE = 16
dataloader_params = {'batch_size': BATCH_SIZE, 'num_workers': 2}

train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


### For now, I'm using the train_dataset + train_loader only, splitting it to train and validation by 80% - 20%, accordingly
train_path = drive_base_path + 'camelyonpatch_level_2_split_train'
# val_path = drive_base_path + 'camelyonpatch_level_2_split_valid'
# test_path = drive_base_path + 'camelyonpatch_level_2_split_test'

# test_dataset = H5Dataset(test_path, transform=test_transforms)
# test_loader = DataLoader(test_dataset, **dataloader_params)

# val_dataset = H5Dataset(val_path, transform=test_transforms)
# dev_loader = DataLoader(val_dataset, **dataloader_params)

train_dataset = H5Dataset(train_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, **dataloader_params)

# %%
from torch.utils.data import SubsetRandomSampler

validation_split = 0.8
dataset_size = len(train_dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
# print(split)
# print(dataset_size)

train_indices, valid_indices = indices[:split], indices[split:]
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

# train dataset + loader
train_dataset = H5Dataset(train_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, **dataloader_params, sampler=train_sampler)
# val dataset + loader
val_dataset = H5Dataset(train_path, transform=test_transforms)
dev_loader = DataLoader(val_dataset, **dataloader_params, sampler=valid_sampler)

# %%
# Code that generates examples and saves on disk. Change if label > 0 to get one sample of class=0 if needed
# import matplotlib.pyplot as plt
# from PIL import Image
# from torchvision import transforms

# harish_data = H5Dataset(test_path)
# harish_loader = DataLoader(harish_data)
# for batch_x, batch_y in harish_loader:
#   label = batch_y[i].numpy()[0][0][0]
#   if label > 0:
#     print("label:", label)
#     # plt.imshow(x[i])
#     t = batch_x[i].permute(2, 0, 1)
#     print(t.shape)
#     print("t is: ", t.size())
#     im = transforms.ToPILImage()(t).convert("RGB")
#     display(im)
#     im.save('{0}.png'.format(label))
#     break

# %% [markdown]
# ### Model Architecture Class Definition

# %%
class ModelCNN(nn.Module):
    """Implemented by paper: http://cs230.stanford.edu/projects_winter_2019/posters/15813053.pdf"""
    def __init__(self, p = 0.5):
        # log dropout parameter
        wandb.config.dropout = p
        """Init method for initializaing the CNN model"""
        super(ModelCNN, self).__init__()
        # 1. Convolutional layers
        # Single image is in shape: 3x96x96 (CxHxW, H==W), RGB images
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 16, kernel_size = 3, stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, stride = 1, padding = 1)
        self.bn4 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 0)
        
        self.dropout = nn.Dropout(p = p)
        
        # 2. FC layers to final output
        self.fc1 = nn.Linear(in_features = 128*6*6, out_features = 512)
        self.fc_bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(in_features = 512, out_features = 256)
        self.fc_bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(in_features = 256, out_features = 128)
        self.fc_bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(in_features = 128, out_features = 1)

    def forward(self, x):
        # Convolution Layers, followed by Batch Normalizations, Maxpool, and ReLU
        x = self.bn1(self.conv1(x))                      # batch_size x 96 x 96 x 16
        x = self.pool(F.relu(x))                         # batch_size x 48 x 48 x 16
        x = self.bn2(self.conv2(x))                      # batch_size x 48 x 48 x 32
        x = self.pool(F.relu(x))                         # batch_size x 24 x 24 x 32
        x = self.bn3(self.conv3(x))                      # batch_size x 24 x 24 x 64
        x = self.pool(F.relu(x))                         # batch_size x 12 x 12 x 64
        x = self.bn4(self.conv4(x))                      # batch_size x 12 x 12 x 128
        x = self.pool(F.relu(x))                         # batch_size x  6 x  6 x 128
        # Flatten the output for each image
        x = x.reshape(-1, self.num_flat_features(x))        # batch_size x 6*6*128
        
        # Apply 4 FC Layers
        x = self.fc1(x)
        x = self.fc_bn1(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc2(x)
        x = self.fc_bn2(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc3(x)
        x = self.fc_bn3(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc4(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %% [markdown]
# ### Helper Functions

# %%
def sigmoid(x):
    """This method calculates the sigmoid function"""
    return 1.0/(1.0 + np.exp(-x))

def training_accuracy(predicted, true, i, acc, tpr, tnr):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu() # Taking the predictions, why cpu and not device?
    true = true.cpu() # Taking the labels, why cpu and not device?
    
    predicted = (sigmoid(predicted.data.numpy()) > 0.5) # Using sigmoid above, if prediction > 0.5 it is 1
    true = true.data.numpy()
    accuracy = np.sum(predicted == true) / true.shape[0] # Accuracy is: (TP + TN)/(TP + TN + FN + FP)
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1) # TPR: TP / (TP + FN) aka Recall
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0) # TNR: TN / (FP + TN)
    acc = acc * (i) / (i + 1) + accuracy / (i + 1)
    tpr = tpr * (i) / (i + 1) + true_positive_rate / (i + 1)
    tnr = tnr * (i) / (i + 1) + true_negative_rate / (i + 1)
    return acc, tpr, tnr

def dev_accuracy(predicted, target):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu()
    target = target.cpu()
    predicted = (sigmoid(predicted.data.numpy()) > 0.5)
    true = target.data.numpy()
    accuracy = np.sum(predicted == true) / true.shape[0]
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1)
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0)
    return accuracy, true_positive_rate, true_negative_rate

def fetch_state(epoch, model, optimizer, dev_loss_min, dev_acc_max):
    """Returns the state dictionary for a model and optimizer"""
    state = {
        'epoch': epoch,
        'dev_loss_min': dev_loss_min,
        'dev_acc_max': dev_acc_max,
        'state_dict': model.state_dict(),
        'optim_dict': optimizer.state_dict()
    }
    return state

def save_checkpoint(state, is_best = False, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Saves model and training parameters at checkpoint + 'last.pth.tar'. If is_best==True, also saves
    checkpoint + 'best.pth.tar'

    Args:
        state: (dict) contains model's state_dict, may contain other keys such as epoch, optimizer state_dict
        is_best: (bool) True if it is the best model seen till now
        checkpoint: (string) folder where parameters are to be saved
    """
    filepath = os.path.join(checkpoint, 'last_v2.pth.tar')
    if (not os.path.exists(checkpoint)):
        print("Checkpoint Directory does not exist! Making directory {}".format(checkpoint))
        os.mkdir(checkpoint)
    else:
        print("Checkpoint Directory exists! ")
    torch.save(state, filepath)
    if (is_best):
        shutil.copyfile(filepath, os.path.join(checkpoint, 'best_v2.pth.tar'))
        
def load_checkpoint(model, optimizer = None, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Loads model parameters (state_dict) from file_path. If optimizer is provided, loads state_dict of
    optimizer assuming it is present in checkpoint.

    Args:
        checkpoint: (string) filename which needs to be loaded
        model: (torch.nn.Module) model for which the parameters are loaded
        optimizer: (torch.optim) optional: resume optimizer from checkpoint
    """
    if not os.path.exists(checkpoint):
        print("File doesn't exist {}".format(checkpoint))
        checkpoint = None
        return
    checkpoint = torch.load(checkpoint)
    model.load_state_dict(checkpoint['state_dict'])

    if optimizer:
        optimizer.load_state_dict(checkpoint['optim_dict'])

    return checkpoint


def train_model(model, train_loader, optimizer, criterion, USE_GPU, acc, tpr, tnr, train_loss, print_every=128):
  """ This method will train a model based on parameters above.
  model - nn.Module model
  train_loader - data loader to be trained on
  optimizer - optimizer e.g. SGD / Adam
  criterion - e.g. nn.BCEWithLogitsLoss
  USE_GPU - True / False, whether to use GPU during training / not
  acc, tpr, tnr - accuracy, true positive rate, true negative rate for metrics during training
  train_loss - a dictionary which stores loss during training"""
  model.train()
  for batch_idx, (image, label) in enumerate(train_loader):
    train(model, train_loader, optimizer, criterion, USE_GPU, acc, tpr, tnr, train_loss)
    if USE_GPU:
        data, target = image.cuda(), label.cuda()
    else:
        data, target = image, label
    # Zero the parameter gradients
    optimizer.zero_grad()
    # Forward pass
    output = model(data)
    # Update target to be the same dimensions as output
    target = target.view(output.shape[0], 1).float()
    # Get accuracy measurements
    acc, tpr, tnr = training_accuracy(output, target, batch_idx, acc, tpr, tnr)
    # Calculate the batch's loss
    curr_train_loss = criterion(output, target)
    # Update the training loss
    train_loss.append(curr_train_loss.item())
    # Backward pass
    curr_train_loss.backward()
    # Perform a single optimization step to update parameters
    optimizer.step()
  
  if (batch_idx) % print_every == 0:
      print('Epoch {}/{}; Iter {}/{}; Loss: {:.4f}; Acc: {:.3f}; True Pos: {:.3f}; True Neg: {:.3f}'
                   .format(curr_epoch, total_num_epochs, batch_idx + 1, len(train_loader), curr_train_loss.item(), acc, tpr, tnr))


def update_scores(loss_arr, acc_arr, tpr_arr, tnr_arr, curr_avg_loss, curr_acc, curr_tpr, curr_tnr):
  """This method gets scores / metrics arrays and parameters, and updates them accordingly"""
  loss_arr.append(curr_avg_loss)
  acc_arr.append(curr_acc)
  tpr_arr.append(curr_tpr)
  tnr_arr.append(curr_tnr)

# %% [markdown]
# ### Model, Optimizer, Parameters Instantiation

# %%
# Model Instantiation
USE_GPU = torch.cuda.is_available()

model = ModelCNN()
if (USE_GPU):
    model.cuda()

# Hyperparameters + Log
lr = 5e-4
wandb.config.learning_rate = lr

# Parameters
total_epochs = 0
num_epochs = 50
early_stop_limit = 15
bad_epoch_count = 0
stop = False
train_loss_min = np.Inf
dev_loss_min = np.Inf
dev_acc_max = 0

# Optimizer + Loss Function
optimizer = optim.Adam(model.parameters(), lr = lr) #TODO: Hyperparam tuning
# optimizer = optim.SGD(model.parameters(), lr = lr)
criterion = nn.BCEWithLogitsLoss() # Binary Cross Entropy for binary classification - malignant / benign

best_checkpoint = os.path.join(CHECKPOINT_DIR, 'best_v2.pth.tar') # For saving model

total_epochs = 0 # Used in training

# Initialize arrays for plot
train_loss_arr = []
train_acc_arr = []
train_tpr_arr = []
train_tnr_arr = []

dev_loss_arr = []
dev_acc_arr = []
dev_tpr_arr = []
dev_tnr_arr = []

# %% [markdown]
# ### Training + Evaluation model

# %%
# Loop over the dataset multiple times
total_num_epochs = total_epochs + num_epochs
for epoch in range(num_epochs):
    curr_epoch = total_epochs + epoch + 1
    # Keep track of training loss
    train_loss = []
    # Keep track of dev loss
    dev_loss = []
    # Keep track of accuracy measurements
    acc, tpr, tnr = 0.0, 0.0, 0.0

    # Train the model
    start_time = time.time()
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        if USE_GPU:
            data, target = image.cuda(), label.cuda()
        else:
            data, target = image, label
        # Zero the parameter gradients
        optimizer.zero_grad()
        # Forward pass
        output = model(data)
        # Update target to be the same dimensions as output
        target = target.view(output.shape[0], 1).float()
        # Get accuracy measurements
        acc, tpr, tnr = training_accuracy(output, target, batch_idx, acc, tpr, tnr)
        # Calculate the batch's loss
        curr_train_loss = criterion(output, target)
        # Update the training loss
        train_loss.append(curr_train_loss.item())
        # Backward pass
        curr_train_loss.backward()
        # Perform a single optimization step to update parameters
        optimizer.step()
        # Print debug info every 64 batches
        if (batch_idx) % 64 == 0:
            print('Epoch {}/{}; Iter {}/{}; Loss: {:.4f}; Acc: {:.3f}; True Pos: {:.3f}; True Neg: {:.3f}'
                   .format(curr_epoch, total_num_epochs, batch_idx + 1, len(train_loader), curr_train_loss.item(), acc, tpr, tnr))
            
    end_time = time.time()
    
    # Evaluate the model
    model.eval()
    with torch.no_grad():
        for batch_idx, (image, label) in enumerate(dev_loader):
            if USE_GPU:
                data, target = image.cuda(), label.cuda()
            else:
                data, target = image, label
            # Get predicted output
            output = model(data)
            # Update target to be the same dimensions as output
            target = target.view(output.shape[0], 1).float()
            # Get accuracy measurements
            dev_acc, dev_tpr, dev_tnr = dev_accuracy(output, target)
            # Calculate the batch's loss
            curr_dev_loss = criterion(output, target)
            # Update the dev loss
            dev_loss.append(curr_dev_loss.item())
    
    # Calculate average loss
    avg_train_loss = np.mean(np.array(train_loss))
    avg_dev_loss = np.mean(np.array(dev_loss))
    
    # Update dev loss arrays
    update_scores(dev_loss_arr, dev_acc_arr, dev_tpr_arr, dev_tnr_arr, avg_dev_loss, dev_acc, dev_tpr, dev_tnr)

    # Update training loss arrays
    update_scores(train_loss_arr, train_acc_arr, train_tpr_arr, train_tnr_arr, avg_train_loss, acc, tpr, tnr)

    print('Epoch {}/{}; Avg. Train Loss: {:.4f}; Train Acc: {:.3f}; Train TPR: {:.3f}; Train TNR: {:.3f}; Epoch Time: {} mins; \nAvg. Dev Loss: {:.4f}; Dev Acc: {:.3f}; Dev TPR: {:.3f}; Dev TNR: {:.3f}\n'
        .format(curr_epoch, total_num_epochs, avg_train_loss, acc, tpr, tnr, round((end_time - start_time)/ 60., 2), avg_dev_loss, dev_acc, dev_tpr, dev_tnr))
    
    wandb.log({'epoch': curr_epoch, 'loss': avg_train_loss, 'accuracy': acc, 'tpr': tpr, 'time_per_epoch_min': round((end_time - start_time)/ 60., 2)})

    if avg_dev_loss < dev_loss_min:
        print('Dev loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
              .format(dev_loss_min, avg_dev_loss))
        dev_loss_min = avg_dev_loss
        is_best = False
        if (dev_acc >= dev_acc_max):
            is_best = True
            dev_acc_max = dev_acc
        state = fetch_state(epoch = curr_epoch, model = model, optimizer = optimizer, 
                            dev_loss_min = dev_loss_min, 
                            dev_acc_max = dev_acc_max)
        save_checkpoint(state = state, is_best = is_best)
        bad_epoch_count = 0
    # If dev loss didn't improve, increase bad_epoch_count and stop if
    # bad_epoch_count >= early_stop_limit
    else:
        bad_epoch_count += 1
        print('{} epochs of increasing dev loss ({:.6f} --> {:.6f}).'
              .format(bad_epoch_count, dev_loss_min, avg_dev_loss))
        if (bad_epoch_count >= early_stop_limit):
            print('Stopping training')
            stop = True

    if (stop):
        break
# Out:
# Epoch 1/50; Iter 1/13108; Loss: 0.6598; Acc: 0.625; True Pos: 0.833; True Neg: 0.500
# Epoch 1/50; Iter 65/13108; Loss: 0.4767; Acc: 0.696; True Pos: 0.699; True Neg: 0.704
# Epoch 1/50; Iter 129/13108; Loss: 0.4361; Acc: 0.722; True Pos: 0.704; True Neg: 0.759
# Epoch 1/50; Iter 193/13108; Loss: 0.6972; Acc: 0.735; True Pos: 0.732; True Neg: 0.754
# Epoch 1/50; Iter 257/13108; Loss: 0.4483; Acc: 0.744; True Pos: 0.747; True Neg: 0.758
# Epoch 1/50; Iter 321/13108; Loss: 0.4322; Acc: 0.746; True Pos: 0.746; True Neg: 0.765
# Epoch 1/50; Iter 385/13108; Loss: 0.6098; Acc: 0.756; True Pos: 0.761; True Neg: 0.772
# Epoch 1/50; Iter 449/13108; Loss: 0.3277; Acc: 0.759; True Pos: 0.767; True Neg: 0.774
# Epoch 1/50; Iter 513/13108; Loss: 0.5338; Acc: 0.763; True Pos: 0.771; True Neg: 0.776
# Epoch 1/50; Iter 577/13108; Loss: 0.2572; Acc: 0.769; True Pos: 0.778; True Neg: 0.782
# Epoch 1/50; Iter 641/13108; Loss: 0.5899; Acc: 0.772; True Pos: 0.781; True Neg: 0.785
# Epoch 1/50; Iter 705/13108; Loss: 0.3710; Acc: 0.773; True Pos: 0.782; True Neg: 0.788
# Epoch 1/50; Iter 769/13108; Loss: 0.3496; Acc: 0.776; True Pos: 0.785; True Neg: 0.792
# Epoch 1/50; Iter 833/13108; Loss: 0.5076; Acc: 0.780; True Pos: 0.789; True Neg: 0.797
# Epoch 1/50; Iter 897/13108; Loss: 0.3710; Acc: 0.782; True Pos: 0.791; True Neg: 0.798
# Epoch 1/50; Iter 961/13108; Loss: 0.9565; Acc: 0.782; True Pos: 0.791; True Neg: 0.799
# Epoch 1/50; Iter 1025/13108; Loss: 0.3756; Acc: 0.784; True Pos: 0.795; True Neg: 0.800
# Epoch 1/50; Iter 1089/13108; Loss: 0.8155; Acc: 0.785; True Pos: 0.795; True Neg: 0.803
# Epoch 1/50; Iter 1153/13108; Loss: 0.4195; Acc: 0.787; True Pos: 0.798; True Neg: 0.802
# Epoch 1/50; Iter 1217/13108; Loss: 0.5035; Acc: 0.787; True Pos: 0.798; True Neg: 0.802
# Epoch 1/50; Iter 1281/13108; Loss: 0.4122; Acc: 0.789; True Pos: 0.801; True Neg: 0.803
# Epoch 1/50; Iter 1345/13108; Loss: 0.3872; Acc: 0.790; True Pos: 0.804; True Neg: 0.803
# Epoch 1/50; Iter 1409/13108; Loss: 0.2926; Acc: 0.792; True Pos: 0.805; True Neg: 0.805
# Epoch 1/50; Iter 1473/13108; Loss: 0.5377; Acc: 0.792; True Pos: 0.807; True Neg: 0.805
# Epoch 1/50; Iter 1537/13108; Loss: 0.6388; Acc: 0.793; True Pos: 0.808; True Neg: 0.805
# Epoch 1/50; Iter 1601/13108; Loss: 0.3357; Acc: 0.794; True Pos: 0.810; True Neg: 0.805
# Epoch 1/50; Iter 1665/13108; Loss: 0.2110; Acc: 0.796; True Pos: 0.813; True Neg: 0.806
# Epoch 1/50; Iter 1729/13108; Loss: 0.5905; Acc: 0.797; True Pos: 0.814; True Neg: 0.807
# Epoch 1/50; Iter 1793/13108; Loss: 0.3688; Acc: 0.797; True Pos: 0.814; True Neg: 0.808
# Epoch 1/50; Iter 1857/13108; Loss: 0.6109; Acc: 0.798; True Pos: 0.816; True Neg: 0.808
# Epoch 1/50; Iter 1921/13108; Loss: 0.4604; Acc: 0.799; True Pos: 0.817; True Neg: 0.807
# Epoch 1/50; Iter 1985/13108; Loss: 0.2917; Acc: 0.800; True Pos: 0.819; True Neg: 0.808
# Epoch 1/50; Iter 2049/13108; Loss: 0.3847; Acc: 0.800; True Pos: 0.820; True Neg: 0.808
# Epoch 1/50; Iter 2113/13108; Loss: 0.4696; Acc: 0.801; True Pos: 0.820; True Neg: 0.809
# Epoch 1/50; Iter 2177/13108; Loss: 0.1572; Acc: 0.802; True Pos: 0.821; True Neg: 0.809
# Epoch 1/50; Iter 2241/13108; Loss: 0.4780; Acc: 0.802; True Pos: 0.823; True Neg: 0.809
# Epoch 1/50; Iter 2305/13108; Loss: 0.4278; Acc: 0.803; True Pos: 0.824; True Neg: 0.810
# Epoch 1/50; Iter 2369/13108; Loss: 0.4441; Acc: 0.804; True Pos: 0.825; True Neg: 0.810
# Epoch 1/50; Iter 2433/13108; Loss: 0.3599; Acc: 0.804; True Pos: 0.826; True Neg: 0.811
# Epoch 1/50; Iter 2497/13108; Loss: 0.4180; Acc: 0.805; True Pos: 0.827; True Neg: 0.811
# Epoch 1/50; Iter 2561/13108; Loss: 0.2769; Acc: 0.805; True Pos: 0.827; True Neg: 0.811
# Epoch 1/50; Iter 2625/13108; Loss: 0.4889; Acc: 0.805; True Pos: 0.827; True Neg: 0.811
# Epoch 1/50; Iter 2689/13108; Loss: 0.2908; Acc: 0.806; True Pos: 0.828; True Neg: 0.812
# Epoch 1/50; Iter 2753/13108; Loss: 0.5482; Acc: 0.806; True Pos: 0.829; True Neg: 0.811
# Epoch 1/50; Iter 2817/13108; Loss: 0.4549; Acc: 0.807; True Pos: 0.830; True Neg: 0.812
# Epoch 1/50; Iter 2881/13108; Loss: 0.4823; Acc: 0.807; True Pos: 0.830; True Neg: 0.812
# Epoch 1/50; Iter 2945/13108; Loss: 0.6641; Acc: 0.807; True Pos: 0.830; True Neg: 0.813
# Epoch 1/50; Iter 3009/13108; Loss: 0.2011; Acc: 0.808; True Pos: 0.831; True Neg: 0.813
# Epoch 1/50; Iter 3073/13108; Loss: 0.3683; Acc: 0.808; True Pos: 0.832; True Neg: 0.814
# Epoch 1/50; Iter 3137/13108; Loss: 0.4497; Acc: 0.809; True Pos: 0.832; True Neg: 0.814
# Epoch 1/50; Iter 3201/13108; Loss: 0.5852; Acc: 0.809; True Pos: 0.833; True Neg: 0.814
# Epoch 1/50; Iter 3265/13108; Loss: 0.2551; Acc: 0.810; True Pos: 0.833; True Neg: 0.815
# Epoch 1/50; Iter 3329/13108; Loss: 0.3540; Acc: 0.810; True Pos: 0.834; True Neg: 0.815
# Epoch 1/50; Iter 3393/13108; Loss: 0.4533; Acc: 0.811; True Pos: 0.834; True Neg: 0.815
# Epoch 1/50; Iter 3457/13108; Loss: 0.4154; Acc: 0.811; True Pos: 0.835; True Neg: 0.816
# Epoch 1/50; Iter 3521/13108; Loss: 0.3046; Acc: 0.812; True Pos: 0.836; True Neg: 0.816
# Epoch 1/50; Iter 3585/13108; Loss: 0.4713; Acc: 0.812; True Pos: 0.836; True Neg: 0.817
# Epoch 1/50; Iter 3649/13108; Loss: 0.3849; Acc: 0.812; True Pos: 0.836; True Neg: 0.818
# Epoch 1/50; Iter 3713/13108; Loss: 0.3610; Acc: 0.813; True Pos: 0.836; True Neg: 0.818
# Epoch 1/50; Iter 3777/13108; Loss: 0.2759; Acc: 0.814; True Pos: 0.836; True Neg: 0.819
# Epoch 1/50; Iter 3841/13108; Loss: 0.2932; Acc: 0.814; True Pos: 0.837; True Neg: 0.820
# Epoch 1/50; Iter 3905/13108; Loss: 0.6996; Acc: 0.815; True Pos: 0.838; True Neg: 0.820
# Epoch 1/50; Iter 3969/13108; Loss: 0.2248; Acc: 0.815; True Pos: 0.838; True Neg: 0.821
# Epoch 1/50; Iter 4033/13108; Loss: 0.2056; Acc: 0.816; True Pos: 0.838; True Neg: 0.822
# Epoch 1/50; Iter 4097/13108; Loss: 0.4849; Acc: 0.816; True Pos: 0.839; True Neg: 0.822
# Epoch 1/50; Iter 4161/13108; Loss: 0.2943; Acc: 0.816; True Pos: 0.839; True Neg: 0.823
# Epoch 1/50; Iter 4225/13108; Loss: 0.2817; Acc: 0.817; True Pos: 0.839; True Neg: 0.824
# Epoch 1/50; Iter 4289/13108; Loss: 0.1583; Acc: 0.817; True Pos: 0.839; True Neg: 0.824
# Epoch 1/50; Iter 4353/13108; Loss: 0.5174; Acc: 0.818; True Pos: 0.839; True Neg: 0.824
# Epoch 1/50; Iter 4417/13108; Loss: 0.1942; Acc: 0.818; True Pos: 0.840; True Neg: 0.825
# Epoch 1/50; Iter 4481/13108; Loss: 0.2664; Acc: 0.818; True Pos: 0.840; True Neg: 0.825
# Epoch 1/50; Iter 4545/13108; Loss: 0.1627; Acc: 0.819; True Pos: 0.841; True Neg: 0.826
# Epoch 1/50; Iter 4609/13108; Loss: 0.2902; Acc: 0.819; True Pos: 0.842; True Neg: 0.826
# Epoch 1/50; Iter 4673/13108; Loss: 0.4202; Acc: 0.819; True Pos: 0.842; True Neg: 0.826
# Epoch 1/50; Iter 4737/13108; Loss: 0.3749; Acc: 0.820; True Pos: 0.842; True Neg: 0.826
# Epoch 1/50; Iter 4801/13108; Loss: 0.2521; Acc: 0.820; True Pos: 0.843; True Neg: 0.827
# Epoch 1/50; Iter 4865/13108; Loss: 0.6142; Acc: 0.821; True Pos: 0.843; True Neg: 0.827
# Epoch 1/50; Iter 4929/13108; Loss: 0.3220; Acc: 0.821; True Pos: 0.843; True Neg: 0.827
# Epoch 1/50; Iter 4993/13108; Loss: 0.4114; Acc: 0.821; True Pos: 0.844; True Neg: 0.828
# Epoch 1/50; Iter 5057/13108; Loss: 0.4093; Acc: 0.821; True Pos: 0.844; True Neg: 0.828
# Epoch 1/50; Iter 5121/13108; Loss: 0.4398; Acc: 0.822; True Pos: 0.845; True Neg: 0.828
# Epoch 1/50; Iter 5185/13108; Loss: 0.4893; Acc: 0.822; True Pos: 0.845; True Neg: 0.829
# Epoch 1/50; Iter 5249/13108; Loss: 0.4221; Acc: 0.823; True Pos: 0.845; True Neg: 0.829
# Epoch 1/50; Iter 5313/13108; Loss: 0.6425; Acc: 0.823; True Pos: 0.845; True Neg: 0.830
# Epoch 1/50; Iter 5377/13108; Loss: 0.4167; Acc: 0.823; True Pos: 0.846; True Neg: 0.830
# Epoch 1/50; Iter 5441/13108; Loss: 0.2413; Acc: 0.824; True Pos: 0.846; True Neg: 0.830
# Epoch 1/50; Iter 5505/13108; Loss: 0.5419; Acc: 0.824; True Pos: 0.846; True Neg: 0.831
# Epoch 1/50; Iter 5569/13108; Loss: 0.3382; Acc: 0.824; True Pos: 0.846; True Neg: 0.831
# Epoch 1/50; Iter 5633/13108; Loss: 0.1889; Acc: 0.824; True Pos: 0.846; True Neg: 0.831
# Epoch 1/50; Iter 5697/13108; Loss: 0.4469; Acc: 0.824; True Pos: 0.847; True Neg: 0.831
# Epoch 1/50; Iter 5761/13108; Loss: 0.2907; Acc: 0.825; True Pos: 0.847; True Neg: 0.831
# Epoch 1/50; Iter 5825/13108; Loss: 0.3416; Acc: 0.825; True Pos: 0.847; True Neg: 0.831
# Epoch 1/50; Iter 5889/13108; Loss: 0.4263; Acc: 0.825; True Pos: 0.847; True Neg: 0.832
# Epoch 1/50; Iter 5953/13108; Loss: 0.1663; Acc: 0.825; True Pos: 0.847; True Neg: 0.832
# Epoch 1/50; Iter 6017/13108; Loss: 0.3024; Acc: 0.826; True Pos: 0.848; True Neg: 0.832
# Epoch 1/50; Iter 6081/13108; Loss: 0.1819; Acc: 0.826; True Pos: 0.848; True Neg: 0.832
# Epoch 1/50; Iter 6145/13108; Loss: 0.2324; Acc: 0.826; True Pos: 0.848; True Neg: 0.833
# Epoch 1/50; Iter 6209/13108; Loss: 0.2845; Acc: 0.826; True Pos: 0.849; True Neg: 0.833
# Epoch 1/50; Iter 6273/13108; Loss: 0.4170; Acc: 0.827; True Pos: 0.849; True Neg: 0.834
# Epoch 1/50; Iter 6337/13108; Loss: 0.3990; Acc: 0.827; True Pos: 0.849; True Neg: 0.834
# Epoch 1/50; Iter 6401/13108; Loss: 0.2191; Acc: 0.828; True Pos: 0.849; True Neg: 0.835
# Epoch 1/50; Iter 6465/13108; Loss: 0.6636; Acc: 0.828; True Pos: 0.849; True Neg: 0.835
# Epoch 1/50; Iter 6529/13108; Loss: 0.3420; Acc: 0.828; True Pos: 0.849; True Neg: 0.835
# Epoch 1/50; Iter 6593/13108; Loss: 0.3976; Acc: 0.828; True Pos: 0.850; True Neg: 0.835
# Epoch 1/50; Iter 6657/13108; Loss: 0.1752; Acc: 0.829; True Pos: 0.850; True Neg: 0.836
# Epoch 1/50; Iter 6721/13108; Loss: 0.5978; Acc: 0.829; True Pos: 0.850; True Neg: 0.836
# Epoch 1/50; Iter 6785/13108; Loss: 0.5274; Acc: 0.829; True Pos: 0.851; True Neg: 0.836
# Epoch 1/50; Iter 6849/13108; Loss: 0.2551; Acc: 0.829; True Pos: 0.851; True Neg: 0.837
# Epoch 1/50; Iter 6913/13108; Loss: 0.4157; Acc: 0.830; True Pos: 0.851; True Neg: 0.837
# Epoch 1/50; Iter 6977/13108; Loss: 0.2433; Acc: 0.830; True Pos: 0.851; True Neg: 0.837
# Epoch 1/50; Iter 7041/13108; Loss: 0.4121; Acc: 0.830; True Pos: 0.851; True Neg: 0.837
# Epoch 1/50; Iter 7105/13108; Loss: 0.3569; Acc: 0.830; True Pos: 0.851; True Neg: 0.838
# Epoch 1/50; Iter 7169/13108; Loss: 0.2610; Acc: 0.831; True Pos: 0.852; True Neg: 0.838
# Epoch 1/50; Iter 7233/13108; Loss: 0.3619; Acc: 0.831; True Pos: 0.852; True Neg: 0.838
# Epoch 1/50; Iter 7297/13108; Loss: 0.1372; Acc: 0.831; True Pos: 0.852; True Neg: 0.838
# Epoch 1/50; Iter 7361/13108; Loss: 0.2148; Acc: 0.831; True Pos: 0.852; True Neg: 0.839
# Epoch 1/50; Iter 7425/13108; Loss: 0.2856; Acc: 0.832; True Pos: 0.852; True Neg: 0.839
# Epoch 1/50; Iter 7489/13108; Loss: 0.3179; Acc: 0.832; True Pos: 0.853; True Neg: 0.839
# Epoch 1/50; Iter 7553/13108; Loss: 0.2186; Acc: 0.832; True Pos: 0.853; True Neg: 0.840
# Epoch 1/50; Iter 7617/13108; Loss: 0.3382; Acc: 0.832; True Pos: 0.853; True Neg: 0.840
# Epoch 1/50; Iter 7681/13108; Loss: 0.2293; Acc: 0.833; True Pos: 0.853; True Neg: 0.841
# Epoch 1/50; Iter 7745/13108; Loss: 0.4656; Acc: 0.833; True Pos: 0.854; True Neg: 0.841
# Epoch 1/50; Iter 7809/13108; Loss: 0.2469; Acc: 0.833; True Pos: 0.854; True Neg: 0.841
# Epoch 1/50; Iter 7873/13108; Loss: 0.1376; Acc: 0.834; True Pos: 0.854; True Neg: 0.842
# Epoch 1/50; Iter 7937/13108; Loss: 0.4839; Acc: 0.834; True Pos: 0.854; True Neg: 0.842
# Epoch 1/50; Iter 8001/13108; Loss: 0.3977; Acc: 0.834; True Pos: 0.854; True Neg: 0.842
# Epoch 1/50; Iter 8065/13108; Loss: 0.4056; Acc: 0.834; True Pos: 0.854; True Neg: 0.843
# Epoch 1/50; Iter 8129/13108; Loss: 0.2178; Acc: 0.835; True Pos: 0.854; True Neg: 0.843
# Epoch 1/50; Iter 8193/13108; Loss: 0.5065; Acc: 0.835; True Pos: 0.855; True Neg: 0.843
# Epoch 1/50; Iter 8257/13108; Loss: 0.3340; Acc: 0.835; True Pos: 0.855; True Neg: 0.844
# Epoch 1/50; Iter 8321/13108; Loss: 0.3615; Acc: 0.836; True Pos: 0.855; True Neg: 0.844
# Epoch 1/50; Iter 8385/13108; Loss: 0.1579; Acc: 0.836; True Pos: 0.855; True Neg: 0.844
# Epoch 1/50; Iter 8449/13108; Loss: 0.4127; Acc: 0.836; True Pos: 0.856; True Neg: 0.845
# Epoch 1/50; Iter 8513/13108; Loss: 0.1499; Acc: 0.836; True Pos: 0.856; True Neg: 0.845
# Epoch 1/50; Iter 8577/13108; Loss: 0.3415; Acc: 0.836; True Pos: 0.856; True Neg: 0.845
# Epoch 1/50; Iter 8641/13108; Loss: 0.2387; Acc: 0.837; True Pos: 0.856; True Neg: 0.845
# Epoch 1/50; Iter 8705/13108; Loss: 0.5189; Acc: 0.837; True Pos: 0.856; True Neg: 0.846
# Epoch 1/50; Iter 8769/13108; Loss: 0.1532; Acc: 0.837; True Pos: 0.856; True Neg: 0.846
# Epoch 1/50; Iter 8833/13108; Loss: 0.1993; Acc: 0.837; True Pos: 0.856; True Neg: 0.846
# Epoch 1/50; Iter 8897/13108; Loss: 0.3806; Acc: 0.838; True Pos: 0.856; True Neg: 0.847
# Epoch 1/50; Iter 8961/13108; Loss: 0.3541; Acc: 0.838; True Pos: 0.857; True Neg: 0.847
# Epoch 1/50; Iter 9025/13108; Loss: 0.2166; Acc: 0.838; True Pos: 0.857; True Neg: 0.847
# Epoch 1/50; Iter 9089/13108; Loss: 0.5473; Acc: 0.838; True Pos: 0.857; True Neg: 0.847
# Epoch 1/50; Iter 9153/13108; Loss: 0.2060; Acc: 0.839; True Pos: 0.857; True Neg: 0.848
# Epoch 1/50; Iter 9217/13108; Loss: 0.2043; Acc: 0.839; True Pos: 0.857; True Neg: 0.848
# Epoch 1/50; Iter 9281/13108; Loss: 0.1077; Acc: 0.839; True Pos: 0.857; True Neg: 0.848
# Epoch 1/50; Iter 9345/13108; Loss: 0.3811; Acc: 0.839; True Pos: 0.858; True Neg: 0.849
# Epoch 1/50; Iter 9409/13108; Loss: 0.3153; Acc: 0.839; True Pos: 0.858; True Neg: 0.849
# Epoch 1/50; Iter 9473/13108; Loss: 0.2049; Acc: 0.840; True Pos: 0.858; True Neg: 0.849
# Epoch 1/50; Iter 9537/13108; Loss: 0.2967; Acc: 0.840; True Pos: 0.858; True Neg: 0.849
# Epoch 1/50; Iter 9601/13108; Loss: 0.2485; Acc: 0.840; True Pos: 0.858; True Neg: 0.850
# Epoch 1/50; Iter 9665/13108; Loss: 0.2358; Acc: 0.840; True Pos: 0.858; True Neg: 0.850
# Epoch 1/50; Iter 9729/13108; Loss: 0.7896; Acc: 0.841; True Pos: 0.859; True Neg: 0.850
# Epoch 1/50; Iter 9793/13108; Loss: 0.3962; Acc: 0.841; True Pos: 0.859; True Neg: 0.850
# Epoch 1/50; Iter 9857/13108; Loss: 0.1617; Acc: 0.841; True Pos: 0.859; True Neg: 0.851
# Epoch 1/50; Iter 9921/13108; Loss: 0.1466; Acc: 0.841; True Pos: 0.859; True Neg: 0.851
# Epoch 1/50; Iter 9985/13108; Loss: 0.5892; Acc: 0.841; True Pos: 0.859; True Neg: 0.851
# Epoch 1/50; Iter 10049/13108; Loss: 0.4783; Acc: 0.842; True Pos: 0.859; True Neg: 0.852
# Epoch 1/50; Iter 10113/13108; Loss: 0.7609; Acc: 0.842; True Pos: 0.859; True Neg: 0.852
# Epoch 1/50; Iter 10177/13108; Loss: 0.3914; Acc: 0.842; True Pos: 0.859; True Neg: 0.852
# Epoch 1/50; Iter 10241/13108; Loss: 0.1814; Acc: 0.842; True Pos: 0.859; True Neg: 0.852
# Epoch 1/50; Iter 10305/13108; Loss: 0.1123; Acc: 0.843; True Pos: 0.860; True Neg: 0.853
# Epoch 1/50; Iter 10369/13108; Loss: 0.7119; Acc: 0.843; True Pos: 0.860; True Neg: 0.853
# Epoch 1/50; Iter 10433/13108; Loss: 0.2123; Acc: 0.843; True Pos: 0.860; True Neg: 0.853
# Epoch 1/50; Iter 10497/13108; Loss: 0.2716; Acc: 0.843; True Pos: 0.860; True Neg: 0.854
# Epoch 1/50; Iter 10561/13108; Loss: 0.2106; Acc: 0.844; True Pos: 0.861; True Neg: 0.854
# Epoch 1/50; Iter 10625/13108; Loss: 0.4600; Acc: 0.844; True Pos: 0.861; True Neg: 0.854
# Epoch 1/50; Iter 10689/13108; Loss: 0.2922; Acc: 0.844; True Pos: 0.861; True Neg: 0.854
# Epoch 1/50; Iter 10753/13108; Loss: 0.6053; Acc: 0.844; True Pos: 0.861; True Neg: 0.855
# Epoch 1/50; Iter 10817/13108; Loss: 0.1227; Acc: 0.844; True Pos: 0.861; True Neg: 0.855
# Epoch 1/50; Iter 10881/13108; Loss: 0.1677; Acc: 0.845; True Pos: 0.861; True Neg: 0.855
# Epoch 1/50; Iter 10945/13108; Loss: 0.4941; Acc: 0.845; True Pos: 0.861; True Neg: 0.855
# Epoch 1/50; Iter 11009/13108; Loss: 0.6381; Acc: 0.845; True Pos: 0.861; True Neg: 0.856
# Epoch 1/50; Iter 11073/13108; Loss: 0.2919; Acc: 0.845; True Pos: 0.862; True Neg: 0.856
# Epoch 1/50; Iter 11137/13108; Loss: 0.4134; Acc: 0.845; True Pos: 0.862; True Neg: 0.856
# Epoch 1/50; Iter 11201/13108; Loss: 0.1961; Acc: 0.846; True Pos: 0.862; True Neg: 0.856
# Epoch 1/50; Iter 11265/13108; Loss: 0.1129; Acc: 0.846; True Pos: 0.862; True Neg: 0.857
# Epoch 1/50; Iter 11329/13108; Loss: 0.1251; Acc: 0.846; True Pos: 0.862; True Neg: 0.857
# Epoch 1/50; Iter 11393/13108; Loss: 0.1309; Acc: 0.846; True Pos: 0.862; True Neg: 0.857
# Epoch 1/50; Iter 11457/13108; Loss: 0.4354; Acc: 0.846; True Pos: 0.862; True Neg: 0.857
# Epoch 1/50; Iter 11521/13108; Loss: 0.1887; Acc: 0.846; True Pos: 0.863; True Neg: 0.857
# Epoch 1/50; Iter 11585/13108; Loss: 0.2138; Acc: 0.847; True Pos: 0.863; True Neg: 0.858
# Epoch 1/50; Iter 11649/13108; Loss: 0.6147; Acc: 0.847; True Pos: 0.863; True Neg: 0.858
# Epoch 1/50; Iter 11713/13108; Loss: 0.2887; Acc: 0.847; True Pos: 0.863; True Neg: 0.858
# Epoch 1/50; Iter 11777/13108; Loss: 0.2270; Acc: 0.847; True Pos: 0.863; True Neg: 0.858
# Epoch 1/50; Iter 11841/13108; Loss: 0.3338; Acc: 0.847; True Pos: 0.863; True Neg: 0.858
# Epoch 1/50; Iter 11905/13108; Loss: 0.2993; Acc: 0.847; True Pos: 0.864; True Neg: 0.859
# Epoch 1/50; Iter 11969/13108; Loss: 0.2368; Acc: 0.848; True Pos: 0.864; True Neg: 0.859
# Epoch 1/50; Iter 12033/13108; Loss: 0.1523; Acc: 0.848; True Pos: 0.864; True Neg: 0.859
# Epoch 1/50; Iter 12097/13108; Loss: 0.3102; Acc: 0.848; True Pos: 0.864; True Neg: 0.859
# Epoch 1/50; Iter 12161/13108; Loss: 0.5974; Acc: 0.848; True Pos: 0.864; True Neg: 0.860
# Epoch 1/50; Iter 12225/13108; Loss: 0.5852; Acc: 0.849; True Pos: 0.864; True Neg: 0.860
# Epoch 1/50; Iter 12289/13108; Loss: 0.2765; Acc: 0.849; True Pos: 0.864; True Neg: 0.860
# Epoch 1/50; Iter 12353/13108; Loss: 0.3333; Acc: 0.849; True Pos: 0.865; True Neg: 0.860
# Epoch 1/50; Iter 12417/13108; Loss: 0.4296; Acc: 0.849; True Pos: 0.865; True Neg: 0.860
# Epoch 1/50; Iter 12481/13108; Loss: 0.3795; Acc: 0.849; True Pos: 0.865; True Neg: 0.861
# Epoch 1/50; Iter 12545/13108; Loss: 0.4876; Acc: 0.850; True Pos: 0.865; True Neg: 0.861
# Epoch 1/50; Iter 12609/13108; Loss: 0.1832; Acc: 0.850; True Pos: 0.865; True Neg: 0.861
# Epoch 1/50; Iter 12673/13108; Loss: 0.2894; Acc: 0.850; True Pos: 0.865; True Neg: 0.861
# Epoch 1/50; Iter 12737/13108; Loss: 0.1467; Acc: 0.850; True Pos: 0.866; True Neg: 0.862
# Epoch 1/50; Iter 12801/13108; Loss: 0.2186; Acc: 0.850; True Pos: 0.866; True Neg: 0.862
# Epoch 1/50; Iter 12865/13108; Loss: 0.0618; Acc: 0.851; True Pos: 0.866; True Neg: 0.862
# Epoch 1/50; Iter 12929/13108; Loss: 0.2278; Acc: 0.851; True Pos: 0.866; True Neg: 0.862
# Epoch 1/50; Iter 12993/13108; Loss: 0.1648; Acc: 0.851; True Pos: 0.866; True Neg: 0.862
# Epoch 1/50; Iter 13057/13108; Loss: 0.2236; Acc: 0.851; True Pos: 0.866; True Neg: 0.863
# Epoch 1/50; Avg. Train Loss: 0.3546; Train Acc: 0.851; Train TPR: 0.866; Train TNR: 0.863; Epoch Time: 5.78 mins;
# Avg. Dev Loss: 0.2302; Dev Acc: 1.000; Dev TPR: 1.000; Dev TNR: 1.000
#
# Dev loss decreased (inf --> 0.230227).  Saving model ...
# Checkpoint Directory exists!
# Epoch 2/50; Iter 1/13108; Loss: 0.1758; Acc: 0.938; True Pos: 0.900; True Neg: 1.000
# Epoch 2/50; Iter 65/13108; Loss: 0.3546; Acc: 0.849; True Pos: 0.837; True Neg: 0.890
# Epoch 2/50; Iter 129/13108; Loss: 0.1959; Acc: 0.847; True Pos: 0.829; True Neg: 0.893
# Epoch 2/50; Iter 193/13108; Loss: 0.1797; Acc: 0.857; True Pos: 0.848; True Neg: 0.893
# Epoch 2/50; Iter 257/13108; Loss: 0.1722; Acc: 0.862; True Pos: 0.858; True Neg: 0.895
# Epoch 2/50; Iter 321/13108; Loss: 0.0972; Acc: 0.867; True Pos: 0.869; True Neg: 0.894
# Epoch 2/50; Iter 385/13108; Loss: 0.1585; Acc: 0.869; True Pos: 0.872; True Neg: 0.898
# Epoch 2/50; Iter 449/13108; Loss: 0.3982; Acc: 0.872; True Pos: 0.874; True Neg: 0.900
# Epoch 2/50; Iter 513/13108; Loss: 0.1923; Acc: 0.873; True Pos: 0.873; True Neg: 0.903
# Epoch 2/50; Iter 577/13108; Loss: 0.1907; Acc: 0.875; True Pos: 0.876; True Neg: 0.903
# Epoch 2/50; Iter 641/13108; Loss: 0.4008; Acc: 0.876; True Pos: 0.877; True Neg: 0.904
# Epoch 2/50; Iter 705/13108; Loss: 0.2542; Acc: 0.878; True Pos: 0.878; True Neg: 0.905
# Epoch 2/50; Iter 769/13108; Loss: 0.5159; Acc: 0.879; True Pos: 0.879; True Neg: 0.907
# Epoch 2/50; Iter 833/13108; Loss: 0.2890; Acc: 0.879; True Pos: 0.880; True Neg: 0.906
# Epoch 2/50; Iter 897/13108; Loss: 0.4207; Acc: 0.880; True Pos: 0.881; True Neg: 0.906
# Epoch 2/50; Iter 961/13108; Loss: 0.1493; Acc: 0.881; True Pos: 0.883; True Neg: 0.907
# Epoch 2/50; Iter 1025/13108; Loss: 0.2742; Acc: 0.882; True Pos: 0.884; True Neg: 0.908
# Epoch 2/50; Iter 1089/13108; Loss: 0.6586; Acc: 0.883; True Pos: 0.884; True Neg: 0.908
# Epoch 2/50; Iter 1153/13108; Loss: 0.3207; Acc: 0.884; True Pos: 0.885; True Neg: 0.909
# Epoch 2/50; Iter 1217/13108; Loss: 0.1316; Acc: 0.885; True Pos: 0.886; True Neg: 0.909
# Epoch 2/50; Iter 1281/13108; Loss: 0.4180; Acc: 0.886; True Pos: 0.887; True Neg: 0.910
# Epoch 2/50; Iter 1345/13108; Loss: 0.2725; Acc: 0.886; True Pos: 0.887; True Neg: 0.910
# Epoch 2/50; Iter 1409/13108; Loss: 0.3110; Acc: 0.886; True Pos: 0.887; True Neg: 0.910
# Epoch 2/50; Iter 1473/13108; Loss: 0.1149; Acc: 0.886; True Pos: 0.888; True Neg: 0.910
# Epoch 2/50; Iter 1537/13108; Loss: 0.2293; Acc: 0.887; True Pos: 0.890; True Neg: 0.910
# Epoch 2/50; Iter 1601/13108; Loss: 0.1063; Acc: 0.887; True Pos: 0.890; True Neg: 0.909
# Epoch 2/50; Iter 1665/13108; Loss: 0.2758; Acc: 0.887; True Pos: 0.890; True Neg: 0.909
# Epoch 2/50; Iter 1729/13108; Loss: 0.2679; Acc: 0.887; True Pos: 0.890; True Neg: 0.909
# Epoch 2/50; Iter 1793/13108; Loss: 0.0951; Acc: 0.887; True Pos: 0.890; True Neg: 0.908
# Epoch 2/50; Iter 1857/13108; Loss: 0.3542; Acc: 0.887; True Pos: 0.890; True Neg: 0.908
# Epoch 2/50; Iter 1921/13108; Loss: 0.8007; Acc: 0.887; True Pos: 0.891; True Neg: 0.908
# Epoch 2/50; Iter 1985/13108; Loss: 0.2702; Acc: 0.887; True Pos: 0.890; True Neg: 0.909
# Epoch 2/50; Iter 2049/13108; Loss: 0.1118; Acc: 0.887; True Pos: 0.890; True Neg: 0.909
# Epoch 2/50; Iter 2113/13108; Loss: 0.2135; Acc: 0.888; True Pos: 0.891; True Neg: 0.909
# Epoch 2/50; Iter 2177/13108; Loss: 0.1951; Acc: 0.888; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2241/13108; Loss: 0.3213; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2305/13108; Loss: 0.3667; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2369/13108; Loss: 0.5848; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2433/13108; Loss: 0.1803; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2497/13108; Loss: 0.3397; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2561/13108; Loss: 0.3206; Acc: 0.889; True Pos: 0.891; True Neg: 0.910
# Epoch 2/50; Iter 2625/13108; Loss: 0.1761; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 2689/13108; Loss: 0.1801; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 2753/13108; Loss: 0.1454; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 2817/13108; Loss: 0.2540; Acc: 0.889; True Pos: 0.892; True Neg: 0.911
# Epoch 2/50; Iter 2881/13108; Loss: 0.4539; Acc: 0.889; True Pos: 0.892; True Neg: 0.911
# Epoch 2/50; Iter 2945/13108; Loss: 0.2081; Acc: 0.889; True Pos: 0.891; True Neg: 0.911
# Epoch 2/50; Iter 3009/13108; Loss: 0.2190; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3073/13108; Loss: 0.5072; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3137/13108; Loss: 0.1920; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3201/13108; Loss: 0.2465; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3265/13108; Loss: 0.2225; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3329/13108; Loss: 0.1324; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3393/13108; Loss: 0.3143; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3457/13108; Loss: 0.1913; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3521/13108; Loss: 0.3797; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3585/13108; Loss: 0.2626; Acc: 0.889; True Pos: 0.892; True Neg: 0.910
# Epoch 2/50; Iter 3649/13108; Loss: 0.2722; Acc: 0.890; True Pos: 0.893; True Neg: 0.910
# Epoch 2/50; Iter 3713/13108; Loss: 0.1112; Acc: 0.889; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 3777/13108; Loss: 0.3403; Acc: 0.889; True Pos: 0.892; True Neg: 0.909
# Epoch 2/50; Iter 3841/13108; Loss: 0.7087; Acc: 0.889; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 3905/13108; Loss: 0.1020; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 3969/13108; Loss: 0.3171; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4033/13108; Loss: 0.4011; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4097/13108; Loss: 0.0710; Acc: 0.890; True Pos: 0.893; True Neg: 0.910
# Epoch 2/50; Iter 4161/13108; Loss: 0.2546; Acc: 0.890; True Pos: 0.893; True Neg: 0.910
# Epoch 2/50; Iter 4225/13108; Loss: 0.1745; Acc: 0.890; True Pos: 0.893; True Neg: 0.910
# Epoch 2/50; Iter 4289/13108; Loss: 0.6015; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4353/13108; Loss: 0.1826; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4417/13108; Loss: 0.5136; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4481/13108; Loss: 0.1151; Acc: 0.890; True Pos: 0.893; True Neg: 0.909
# Epoch 2/50; Iter 4545/13108; Loss: 0.2145; Acc: 0.890; True Pos: 0.894; True Neg: 0.909
# Epoch 2/50; Iter 4609/13108; Loss: 0.1466; Acc: 0.890; True Pos: 0.894; True Neg: 0.909
# Epoch 2/50; Iter 4673/13108; Loss: 0.1465; Acc: 0.890; True Pos: 0.894; True Neg: 0.909
# Epoch 2/50; Iter 4737/13108; Loss: 0.1696; Acc: 0.891; True Pos: 0.894; True Neg: 0.909
# Epoch 2/50; Iter 4801/13108; Loss: 0.2821; Acc: 0.891; True Pos: 0.895; True Neg: 0.909
# Epoch 2/50; Iter 4865/13108; Loss: 0.2126; Acc: 0.891; True Pos: 0.895; True Neg: 0.909
# Epoch 2/50; Iter 4929/13108; Loss: 0.1791; Acc: 0.891; True Pos: 0.895; True Neg: 0.909
# Epoch 2/50; Iter 4993/13108; Loss: 0.2679; Acc: 0.891; True Pos: 0.895; True Neg: 0.910
# Epoch 2/50; Iter 5057/13108; Loss: 0.0805; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5121/13108; Loss: 0.0993; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5185/13108; Loss: 0.1936; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5249/13108; Loss: 0.3384; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5313/13108; Loss: 0.2328; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5377/13108; Loss: 0.2300; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5441/13108; Loss: 0.0788; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5505/13108; Loss: 0.2820; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5569/13108; Loss: 0.3546; Acc: 0.892; True Pos: 0.896; True Neg: 0.910
# Epoch 2/50; Iter 5633/13108; Loss: 0.1154; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5697/13108; Loss: 0.3985; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5761/13108; Loss: 0.1918; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5825/13108; Loss: 0.1494; Acc: 0.892; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5889/13108; Loss: 0.2918; Acc: 0.893; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 5953/13108; Loss: 0.4260; Acc: 0.893; True Pos: 0.897; True Neg: 0.910
# Epoch 2/50; Iter 6017/13108; Loss: 0.1746; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6081/13108; Loss: 0.1793; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6145/13108; Loss: 0.1217; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6209/13108; Loss: 0.0731; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6273/13108; Loss: 0.0521; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6337/13108; Loss: 0.2326; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6401/13108; Loss: 0.2241; Acc: 0.893; True Pos: 0.897; True Neg: 0.911
# Epoch 2/50; Iter 6465/13108; Loss: 0.2561; Acc: 0.894; True Pos: 0.898; True Neg: 0.911
# Epoch 2/50; Iter 6529/13108; Loss: 0.0890; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6593/13108; Loss: 0.1206; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6657/13108; Loss: 0.1499; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6721/13108; Loss: 0.1390; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6785/13108; Loss: 0.1009; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6849/13108; Loss: 0.2520; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6913/13108; Loss: 0.2381; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 6977/13108; Loss: 0.0843; Acc: 0.894; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7041/13108; Loss: 0.4687; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7105/13108; Loss: 0.2853; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7169/13108; Loss: 0.0941; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7233/13108; Loss: 0.3374; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7297/13108; Loss: 0.1057; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7361/13108; Loss: 0.1145; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7425/13108; Loss: 0.2190; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7489/13108; Loss: 0.3220; Acc: 0.895; True Pos: 0.898; True Neg: 0.912
# Epoch 2/50; Iter 7553/13108; Loss: 0.3330; Acc: 0.895; True Pos: 0.899; True Neg: 0.912
# Epoch 2/50; Iter 7617/13108; Loss: 0.3147; Acc: 0.895; True Pos: 0.899; True Neg: 0.912
# Epoch 2/50; Iter 7681/13108; Loss: 0.1788; Acc: 0.895; True Pos: 0.899; True Neg: 0.912
# Epoch 2/50; Iter 7745/13108; Loss: 0.3154; Acc: 0.895; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 7809/13108; Loss: 0.1274; Acc: 0.895; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 7873/13108; Loss: 0.0992; Acc: 0.895; True Pos: 0.899; True Neg: 0.912
# Epoch 2/50; Iter 7937/13108; Loss: 0.2104; Acc: 0.895; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8001/13108; Loss: 0.1413; Acc: 0.895; True Pos: 0.899; True Neg: 0.912
# Epoch 2/50; Iter 8065/13108; Loss: 0.0893; Acc: 0.895; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8129/13108; Loss: 0.1417; Acc: 0.895; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8193/13108; Loss: 0.1324; Acc: 0.896; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8257/13108; Loss: 0.2649; Acc: 0.896; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8321/13108; Loss: 0.2342; Acc: 0.896; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8385/13108; Loss: 0.5824; Acc: 0.896; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8449/13108; Loss: 0.1108; Acc: 0.896; True Pos: 0.899; True Neg: 0.913
# Epoch 2/50; Iter 8513/13108; Loss: 0.2280; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8577/13108; Loss: 0.5041; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8641/13108; Loss: 0.3390; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8705/13108; Loss: 0.2221; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8769/13108; Loss: 0.2792; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8833/13108; Loss: 0.1272; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8897/13108; Loss: 0.2950; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 8961/13108; Loss: 0.3808; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9025/13108; Loss: 0.1610; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9089/13108; Loss: 0.1120; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9153/13108; Loss: 0.4568; Acc: 0.896; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9217/13108; Loss: 0.1320; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9281/13108; Loss: 0.4513; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9345/13108; Loss: 0.1950; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9409/13108; Loss: 0.2274; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9473/13108; Loss: 0.1378; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9537/13108; Loss: 0.2623; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9601/13108; Loss: 0.2338; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9665/13108; Loss: 0.4724; Acc: 0.897; True Pos: 0.900; True Neg: 0.913
# Epoch 2/50; Iter 9729/13108; Loss: 0.3631; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 9793/13108; Loss: 0.2417; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 9857/13108; Loss: 0.2682; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 9921/13108; Loss: 0.2751; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 9985/13108; Loss: 0.1925; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 10049/13108; Loss: 0.1938; Acc: 0.897; True Pos: 0.900; True Neg: 0.914
# Epoch 2/50; Iter 10113/13108; Loss: 0.4684; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10177/13108; Loss: 0.2195; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10241/13108; Loss: 0.3551; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10305/13108; Loss: 0.8468; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10369/13108; Loss: 0.1766; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10433/13108; Loss: 0.1818; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10497/13108; Loss: 0.1407; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10561/13108; Loss: 0.2481; Acc: 0.897; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10625/13108; Loss: 0.0921; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10689/13108; Loss: 0.1901; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10753/13108; Loss: 0.2714; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10817/13108; Loss: 0.2195; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10881/13108; Loss: 0.2806; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 10945/13108; Loss: 0.0916; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11009/13108; Loss: 0.2198; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11073/13108; Loss: 0.3692; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11137/13108; Loss: 0.1043; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11201/13108; Loss: 0.1690; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11265/13108; Loss: 0.2867; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11329/13108; Loss: 0.1034; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11393/13108; Loss: 0.1008; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11457/13108; Loss: 0.0915; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11521/13108; Loss: 0.1077; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11585/13108; Loss: 0.1737; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11649/13108; Loss: 0.0984; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11713/13108; Loss: 0.1368; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11777/13108; Loss: 0.8226; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11841/13108; Loss: 0.6716; Acc: 0.898; True Pos: 0.901; True Neg: 0.914
# Epoch 2/50; Iter 11905/13108; Loss: 0.4139; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 11969/13108; Loss: 0.7392; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12033/13108; Loss: 0.1468; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12097/13108; Loss: 0.2750; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12161/13108; Loss: 0.1356; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12225/13108; Loss: 0.1871; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12289/13108; Loss: 0.5151; Acc: 0.898; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12353/13108; Loss: 0.2226; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12417/13108; Loss: 0.2989; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12481/13108; Loss: 0.3035; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12545/13108; Loss: 0.1460; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12609/13108; Loss: 0.4371; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12673/13108; Loss: 0.1909; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12737/13108; Loss: 0.1974; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12801/13108; Loss: 0.3473; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12865/13108; Loss: 0.2026; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12929/13108; Loss: 0.8290; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 12993/13108; Loss: 0.1250; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Iter 13057/13108; Loss: 0.2665; Acc: 0.899; True Pos: 0.902; True Neg: 0.915
# Epoch 2/50; Avg. Train Loss: 0.2629; Train Acc: 0.899; Train TPR: 0.902; Train TNR: 0.915; Epoch Time: 6.09 mins;
# Avg. Dev Loss: 0.2051; Dev Acc: 0.846; Dev TPR: 0.857; Dev TNR: 0.833
#
# Dev loss decreased (0.230227 --> 0.205067).  Saving model ...
# Checkpoint Directory exists!
# Epoch 3/50; Iter 1/13108; Loss: 0.6194; Acc: 0.812; True Pos: 0.900; True Neg: 0.667
# Epoch 3/50; Iter 65/13108; Loss: 0.2014; Acc: 0.910; True Pos: 0.929; True Neg: 0.914
# Epoch 3/50; Iter 129/13108; Loss: 0.0673; Acc: 0.912; True Pos: 0.922; True Neg: 0.917
# Epoch 3/50; Iter 193/13108; Loss: 0.1573; Acc: 0.909; True Pos: 0.911; True Neg: 0.923
# Epoch 3/50; Iter 257/13108; Loss: 0.2228; Acc: 0.910; True Pos: 0.911; True Neg: 0.924
# Epoch 3/50; Iter 321/13108; Loss: 0.0459; Acc: 0.909; True Pos: 0.908; True Neg: 0.925
# Epoch 3/50; Iter 385/13108; Loss: 0.2081; Acc: 0.913; True Pos: 0.912; True Neg: 0.928
# Epoch 3/50; Iter 449/13108; Loss: 0.0777; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 513/13108; Loss: 0.1134; Acc: 0.912; True Pos: 0.915; True Neg: 0.925
# Epoch 3/50; Iter 577/13108; Loss: 0.3029; Acc: 0.912; True Pos: 0.913; True Neg: 0.926
# Epoch 3/50; Iter 641/13108; Loss: 0.3329; Acc: 0.914; True Pos: 0.915; True Neg: 0.927
# Epoch 3/50; Iter 705/13108; Loss: 0.2041; Acc: 0.915; True Pos: 0.916; True Neg: 0.929
# Epoch 3/50; Iter 769/13108; Loss: 0.1157; Acc: 0.914; True Pos: 0.914; True Neg: 0.930
# Epoch 3/50; Iter 833/13108; Loss: 0.2997; Acc: 0.915; True Pos: 0.915; True Neg: 0.930
# Epoch 3/50; Iter 897/13108; Loss: 0.0720; Acc: 0.914; True Pos: 0.913; True Neg: 0.929
# Epoch 3/50; Iter 961/13108; Loss: 0.0512; Acc: 0.914; True Pos: 0.914; True Neg: 0.929
# Epoch 3/50; Iter 1025/13108; Loss: 0.0544; Acc: 0.914; True Pos: 0.913; True Neg: 0.928
# Epoch 3/50; Iter 1089/13108; Loss: 0.3928; Acc: 0.914; True Pos: 0.913; True Neg: 0.929
# Epoch 3/50; Iter 1153/13108; Loss: 0.2668; Acc: 0.914; True Pos: 0.913; True Neg: 0.928
# Epoch 3/50; Iter 1217/13108; Loss: 0.6753; Acc: 0.913; True Pos: 0.913; True Neg: 0.927
# Epoch 3/50; Iter 1281/13108; Loss: 0.1885; Acc: 0.913; True Pos: 0.913; True Neg: 0.927
# Epoch 3/50; Iter 1345/13108; Loss: 0.2693; Acc: 0.913; True Pos: 0.913; True Neg: 0.927
# Epoch 3/50; Iter 1409/13108; Loss: 0.0585; Acc: 0.913; True Pos: 0.914; True Neg: 0.927
# Epoch 3/50; Iter 1473/13108; Loss: 0.0985; Acc: 0.913; True Pos: 0.914; True Neg: 0.927
# Epoch 3/50; Iter 1537/13108; Loss: 0.3739; Acc: 0.913; True Pos: 0.914; True Neg: 0.927
# Epoch 3/50; Iter 1601/13108; Loss: 0.4258; Acc: 0.913; True Pos: 0.913; True Neg: 0.926
# Epoch 3/50; Iter 1665/13108; Loss: 0.1925; Acc: 0.913; True Pos: 0.913; True Neg: 0.927
# Epoch 3/50; Iter 1729/13108; Loss: 0.2103; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 1793/13108; Loss: 0.2498; Acc: 0.912; True Pos: 0.913; True Neg: 0.926
# Epoch 3/50; Iter 1857/13108; Loss: 0.1549; Acc: 0.911; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 1921/13108; Loss: 0.1181; Acc: 0.911; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 1985/13108; Loss: 0.0940; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 2049/13108; Loss: 0.2296; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 2113/13108; Loss: 0.6584; Acc: 0.911; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 2177/13108; Loss: 0.1838; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2241/13108; Loss: 0.0508; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2305/13108; Loss: 0.2543; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2369/13108; Loss: 0.1247; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 2433/13108; Loss: 0.1913; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2497/13108; Loss: 0.2336; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2561/13108; Loss: 0.2968; Acc: 0.911; True Pos: 0.912; True Neg: 0.924
# Epoch 3/50; Iter 2625/13108; Loss: 0.4674; Acc: 0.911; True Pos: 0.912; True Neg: 0.924
# Epoch 3/50; Iter 2689/13108; Loss: 0.0777; Acc: 0.911; True Pos: 0.912; True Neg: 0.924
# Epoch 3/50; Iter 2753/13108; Loss: 0.1186; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 2817/13108; Loss: 0.0959; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 2881/13108; Loss: 0.1447; Acc: 0.912; True Pos: 0.913; True Neg: 0.925
# Epoch 3/50; Iter 2945/13108; Loss: 0.0773; Acc: 0.911; True Pos: 0.913; True Neg: 0.925
# Epoch 3/50; Iter 3009/13108; Loss: 0.2345; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3073/13108; Loss: 0.1370; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3137/13108; Loss: 0.2998; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3201/13108; Loss: 0.1469; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3265/13108; Loss: 0.0580; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3329/13108; Loss: 0.1583; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3393/13108; Loss: 0.2191; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 3457/13108; Loss: 0.2334; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3521/13108; Loss: 0.0714; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3585/13108; Loss: 0.2390; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3649/13108; Loss: 0.0910; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3713/13108; Loss: 0.1142; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3777/13108; Loss: 0.2643; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 3841/13108; Loss: 0.2050; Acc: 0.911; True Pos: 0.910; True Neg: 0.925
# Epoch 3/50; Iter 3905/13108; Loss: 0.4478; Acc: 0.911; True Pos: 0.910; True Neg: 0.925
# Epoch 3/50; Iter 3969/13108; Loss: 0.1676; Acc: 0.910; True Pos: 0.910; True Neg: 0.925
# Epoch 3/50; Iter 4033/13108; Loss: 0.1160; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4097/13108; Loss: 0.1037; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4161/13108; Loss: 0.3363; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4225/13108; Loss: 0.1769; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4289/13108; Loss: 1.0689; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4353/13108; Loss: 0.1156; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4417/13108; Loss: 0.2009; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4481/13108; Loss: 0.4989; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4545/13108; Loss: 0.2717; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4609/13108; Loss: 0.0717; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 4673/13108; Loss: 0.1499; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 4737/13108; Loss: 0.3403; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 4801/13108; Loss: 0.0599; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 4865/13108; Loss: 0.1242; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 4929/13108; Loss: 0.0928; Acc: 0.911; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 4993/13108; Loss: 0.1590; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5057/13108; Loss: 0.0469; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5121/13108; Loss: 0.1561; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5185/13108; Loss: 0.2388; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5249/13108; Loss: 0.6863; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5313/13108; Loss: 0.1394; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5377/13108; Loss: 0.0415; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5441/13108; Loss: 0.0639; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5505/13108; Loss: 0.1146; Acc: 0.911; True Pos: 0.911; True Neg: 0.925
# Epoch 3/50; Iter 5569/13108; Loss: 0.0492; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5633/13108; Loss: 0.2378; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5697/13108; Loss: 0.0477; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5761/13108; Loss: 0.1445; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5825/13108; Loss: 1.0290; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5889/13108; Loss: 0.2389; Acc: 0.912; True Pos: 0.912; True Neg: 0.925
# Epoch 3/50; Iter 5953/13108; Loss: 0.0596; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6017/13108; Loss: 0.2057; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6081/13108; Loss: 0.1751; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6145/13108; Loss: 0.2538; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6209/13108; Loss: 0.1633; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6273/13108; Loss: 0.0609; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6337/13108; Loss: 0.0385; Acc: 0.912; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6401/13108; Loss: 0.0790; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6465/13108; Loss: 0.0864; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6529/13108; Loss: 0.1901; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6593/13108; Loss: 0.1758; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6657/13108; Loss: 0.0464; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6721/13108; Loss: 0.0716; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6785/13108; Loss: 0.2246; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6849/13108; Loss: 0.1567; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6913/13108; Loss: 0.0875; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 6977/13108; Loss: 0.2387; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 7041/13108; Loss: 0.1958; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 7105/13108; Loss: 0.4377; Acc: 0.913; True Pos: 0.912; True Neg: 0.926
# Epoch 3/50; Iter 7169/13108; Loss: 0.2318; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7233/13108; Loss: 0.1544; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7297/13108; Loss: 0.1785; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7361/13108; Loss: 0.2169; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7425/13108; Loss: 0.2121; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7489/13108; Loss: 0.1692; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7553/13108; Loss: 0.1099; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7617/13108; Loss: 0.3015; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7681/13108; Loss: 0.1868; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7745/13108; Loss: 0.1058; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7809/13108; Loss: 0.5712; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7873/13108; Loss: 0.2369; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 7937/13108; Loss: 0.4533; Acc: 0.913; True Pos: 0.912; True Neg: 0.927
# Epoch 3/50; Iter 8001/13108; Loss: 0.6294; Acc: 0.913; True Pos: 0.912; True Neg: 0.928
# Epoch 3/50; Iter 8065/13108; Loss: 0.1757; Acc: 0.914; True Pos: 0.912; True Neg: 0.928
# Epoch 3/50; Iter 8129/13108; Loss: 0.2158; Acc: 0.914; True Pos: 0.912; True Neg: 0.928
# ...
# Epoch 50/50; Iter 1857/13108; Loss: 0.0184; Acc: 0.970; True Pos: 0.967; True Neg: 0.974
# Epoch 50/50; Iter 1921/13108; Loss: 0.0181; Acc: 0.970; True Pos: 0.968; True Neg: 0.974
# Epoch 50/50; Iter 1985/13108; Loss: 0.0531; Acc: 0.970; True Pos: 0.968; True Neg: 0.974
# Epoch 50/50; Iter 2049/13108; Loss: 0.0027; Acc: 0.970; True Pos: 0.968; True Neg: 0.974
# Epoch 50/50; Iter 2113/13108; Loss: 0.0089; Acc: 0.971; True Pos: 0.968; True Neg: 0.974
# Epoch 50/50; Iter 2177/13108; Loss: 0.1773; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2241/13108; Loss: 0.0649; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2305/13108; Loss: 0.1128; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2369/13108; Loss: 0.1448; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2433/13108; Loss: 0.0137; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2497/13108; Loss: 0.0976; Acc: 0.971; True Pos: 0.969; True Neg: 0.974
# Epoch 50/50; Iter 2561/13108; Loss: 0.1005; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2625/13108; Loss: 0.1726; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2689/13108; Loss: 0.1079; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2753/13108; Loss: 0.1110; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2817/13108; Loss: 0.0244; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2881/13108; Loss: 0.1412; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 2945/13108; Loss: 0.0135; Acc: 0.971; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 3009/13108; Loss: 0.0713; Acc: 0.972; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 3073/13108; Loss: 0.0066; Acc: 0.972; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 3137/13108; Loss: 0.5682; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3201/13108; Loss: 0.0080; Acc: 0.972; True Pos: 0.970; True Neg: 0.974
# Epoch 50/50; Iter 3265/13108; Loss: 0.1353; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3329/13108; Loss: 0.0342; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3393/13108; Loss: 0.1686; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3457/13108; Loss: 0.0771; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3521/13108; Loss: 0.0165; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3585/13108; Loss: 0.1265; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3649/13108; Loss: 0.0923; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3713/13108; Loss: 0.3467; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3777/13108; Loss: 0.0620; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3841/13108; Loss: 0.0397; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3905/13108; Loss: 0.0291; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 3969/13108; Loss: 0.0074; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4033/13108; Loss: 0.3362; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4097/13108; Loss: 0.0134; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4161/13108; Loss: 0.0354; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4225/13108; Loss: 0.0064; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4289/13108; Loss: 0.0109; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4353/13108; Loss: 0.0095; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4417/13108; Loss: 0.0325; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4481/13108; Loss: 0.0038; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 4545/13108; Loss: 0.0314; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4609/13108; Loss: 0.0546; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4673/13108; Loss: 0.0094; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4737/13108; Loss: 0.0163; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4801/13108; Loss: 0.1690; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4865/13108; Loss: 0.2018; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4929/13108; Loss: 0.1208; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 4993/13108; Loss: 0.0226; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5057/13108; Loss: 0.0752; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5121/13108; Loss: 0.0905; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5185/13108; Loss: 0.0050; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5249/13108; Loss: 0.0520; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5313/13108; Loss: 0.1309; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5377/13108; Loss: 0.0409; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5441/13108; Loss: 0.0661; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5505/13108; Loss: 0.0051; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5569/13108; Loss: 0.5313; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5633/13108; Loss: 0.0127; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5697/13108; Loss: 0.2051; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 5761/13108; Loss: 0.0445; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5825/13108; Loss: 0.0121; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5889/13108; Loss: 0.0085; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 5953/13108; Loss: 0.0811; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6017/13108; Loss: 0.0256; Acc: 0.971; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6081/13108; Loss: 0.0774; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6145/13108; Loss: 0.0984; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6209/13108; Loss: 0.0110; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6273/13108; Loss: 0.0254; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6337/13108; Loss: 0.1506; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6401/13108; Loss: 0.0105; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6465/13108; Loss: 0.0086; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 6529/13108; Loss: 0.0050; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6593/13108; Loss: 0.3637; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6657/13108; Loss: 0.0062; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6721/13108; Loss: 0.0358; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6785/13108; Loss: 0.1402; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 6849/13108; Loss: 0.0069; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 6913/13108; Loss: 0.0199; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 6977/13108; Loss: 0.0109; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7041/13108; Loss: 0.1074; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7105/13108; Loss: 0.0122; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7169/13108; Loss: 0.0353; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 7233/13108; Loss: 0.0907; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7297/13108; Loss: 0.2608; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 7361/13108; Loss: 0.0344; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7425/13108; Loss: 0.2461; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 7489/13108; Loss: 0.0574; Acc: 0.972; True Pos: 0.970; True Neg: 0.976
# Epoch 50/50; Iter 7553/13108; Loss: 0.0248; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 7617/13108; Loss: 0.1735; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 7681/13108; Loss: 0.0102; Acc: 0.972; True Pos: 0.970; True Neg: 0.975
# Epoch 50/50; Iter 7745/13108; Loss: 0.0134; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 7809/13108; Loss: 0.0555; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 7873/13108; Loss: 0.0673; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 7937/13108; Loss: 0.1464; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8001/13108; Loss: 0.0421; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8065/13108; Loss: 0.1307; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8129/13108; Loss: 0.1164; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8193/13108; Loss: 0.2764; Acc: 0.972; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8257/13108; Loss: 0.0706; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8321/13108; Loss: 0.1858; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8385/13108; Loss: 0.0054; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8449/13108; Loss: 0.1813; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8513/13108; Loss: 0.0812; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8577/13108; Loss: 0.0406; Acc: 0.972; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8641/13108; Loss: 0.2463; Acc: 0.971; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8705/13108; Loss: 0.0263; Acc: 0.971; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8769/13108; Loss: 0.1619; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8833/13108; Loss: 0.0632; Acc: 0.971; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 8897/13108; Loss: 0.0389; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 8961/13108; Loss: 0.0295; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9025/13108; Loss: 1.1346; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9089/13108; Loss: 0.0641; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9153/13108; Loss: 0.1340; Acc: 0.971; True Pos: 0.969; True Neg: 0.976
# Epoch 50/50; Iter 9217/13108; Loss: 0.0091; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9281/13108; Loss: 0.0313; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9345/13108; Loss: 0.0122; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9409/13108; Loss: 0.0167; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9473/13108; Loss: 0.0133; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9537/13108; Loss: 0.0352; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9601/13108; Loss: 0.0052; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9665/13108; Loss: 0.1292; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9729/13108; Loss: 0.0131; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9793/13108; Loss: 0.1451; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9857/13108; Loss: 0.3726; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9921/13108; Loss: 0.4296; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 9985/13108; Loss: 0.0474; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10049/13108; Loss: 0.0222; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10113/13108; Loss: 0.0089; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10177/13108; Loss: 0.2948; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10241/13108; Loss: 0.0283; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10305/13108; Loss: 0.1319; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10369/13108; Loss: 0.0987; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10433/13108; Loss: 0.0113; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10497/13108; Loss: 0.0319; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10561/13108; Loss: 0.2295; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10625/13108; Loss: 0.0167; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10689/13108; Loss: 0.0162; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10753/13108; Loss: 0.0193; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10817/13108; Loss: 0.0101; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10881/13108; Loss: 0.0152; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 10945/13108; Loss: 0.0326; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11009/13108; Loss: 0.1225; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11073/13108; Loss: 0.0322; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11137/13108; Loss: 0.0354; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11201/13108; Loss: 0.0302; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11265/13108; Loss: 0.0147; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11329/13108; Loss: 0.0769; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11393/13108; Loss: 0.0578; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11457/13108; Loss: 0.0168; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11521/13108; Loss: 0.0431; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11585/13108; Loss: 0.0079; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11649/13108; Loss: 0.0273; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11713/13108; Loss: 0.0133; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11777/13108; Loss: 0.4563; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11841/13108; Loss: 0.0268; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11905/13108; Loss: 0.0312; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 11969/13108; Loss: 0.1549; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12033/13108; Loss: 0.0704; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12097/13108; Loss: 0.0497; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12161/13108; Loss: 0.0243; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12225/13108; Loss: 0.0184; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12289/13108; Loss: 0.1567; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12353/13108; Loss: 0.1842; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12417/13108; Loss: 0.1484; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12481/13108; Loss: 0.0330; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12545/13108; Loss: 0.0277; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12609/13108; Loss: 0.2291; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12673/13108; Loss: 0.0353; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12737/13108; Loss: 0.3979; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12801/13108; Loss: 0.0339; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12865/13108; Loss: 0.0189; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12929/13108; Loss: 0.0451; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 12993/13108; Loss: 0.0663; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Iter 13057/13108; Loss: 0.0376; Acc: 0.971; True Pos: 0.969; True Neg: 0.975
# Epoch 50/50; Avg. Train Loss: 0.0857; Train Acc: 0.971; Train TPR: nan; Train TNR: 0.975; Epoch Time: 6.0 mins;
# Avg. Dev Loss: 0.0976; Dev Acc: 1.000; Dev TPR: 1.000; Dev TNR: 1.000
#
# 4 epochs of increasing dev loss (0.095477 --> 0.097635).

# %%
# hyperparameter_defaults = dict(
#     dropout = 0.5,
#     learning_rate = 0.001
#     )

# wandb.init(config=hyperparameter_defaults)
# config = wandb.config
# Out:
# Finishing last run (ID:1xi9owbx) before initializing another...
# <br/>Waiting for W&B process to finish, PID 667<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210417_081057-1xi9owbx/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210417_081057-1xi9owbx/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">avid-galaxy-17</strong>: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/1xi9owbx" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/1xi9owbx</a><br/>
# ...Successfully finished last run (ID:1xi9owbx). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.26<br/>
#                 Syncing run <strong style="color:#cdcd00">ancient-tree-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/daniel8hen/uncategorized" target="_blank">https://wandb.ai/daniel8hen/uncategorized</a><br/>
#                 Run page: <a href="https://wandb.ai/daniel8hen/uncategorized/runs/1fkyfm2b" target="_blank">https://wandb.ai/daniel8hen/uncategorized/runs/1fkyfm2b</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210417_081153-1fkyfm2b</code><br/><br/>

# %%
# !wandb sweep --update daniel8hen/pcam-pytorch-training/6vohza8u sweep.yaml
# Out:
# wandb: Updating sweep from: sweep.yaml
# wandb: Updated sweep with ID: 6vohza8u
# wandb: View sweep at: https://wandb.ai/daniel8hen/pcam-pytorch-training/sweeps/6vohza8u
# wandb: Run sweep agent with: wandb agent daniel8hen/pcam-pytorch-training/6vohza8u

# %% [markdown]
# ### Model Saving + Loading (fot future use, API)
# This should be sent to Server Side (which hosts it via torchserve)

# %%
# generate a dummy input
example_input = torch.rand(1, 3, 96, 96).to(torch.device("cuda"))

# Store the existing model using torch.jit
traced_script_module = torch.jit.trace(model, example_input)

full_filename = "pcam_cnn.pt"
# Save the script module under pcam_cnn.pt
traced_script_module.save(full_filename)

new_model = torch.jit.load(full_filename)
