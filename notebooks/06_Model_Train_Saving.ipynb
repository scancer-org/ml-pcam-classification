# %% [markdown]
# <a href="https://colab.research.google.com/github/scancer-org/ml-pcam-classification/blob/main/PCAM_Model_Saving_April_17th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [PCAM Classification](https://github.com/basveeling/pcam) Project
# ## FSDL Online Course - Spring 2021
# ## Daniel Hen, Harish Narayanan

# %%
### TODO:
# 1. Test on test dataloader (final results)
# 4. Study how to save after training in torch-serve-archiver file (.mar file)
# 5. Clean + Document code and have a train for at least 50 epochs

# %% [markdown]
# ### Installing Required Packages

# %%
# %%capture
# !pip install -qqq wandb

# %% [markdown]
# ### Libraries + Functions import

# %%
import h5py
import numpy as np
import torch
import wandb
import os
import pandas as pd
import PIL.Image
import matplotlib.pyplot as plt
import shutil
import time
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from google.colab import drive
from torch.utils import data
from os import listdir
from pathlib import Path
from PIL import Image
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms, datasets

# %% [markdown]
# ### Weights & Biases parameters

# %%
wandb.login()
wandb.init(project="pcam-pytorch-training")
wandb.run.name = "pcam-pytorch-experiment#-" + wandb.run.id
print("Staring experiment: ", wandb.run.name)
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: daniel8hen (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.26<br/>
#                 Syncing run <strong style="color:#cdcd00">wild-dew-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training</a><br/>
#                 Run page: <a href="https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/1tlhdqoz" target="_blank">https://wandb.ai/daniel8hen/pcam-pytorch-training/runs/1tlhdqoz</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210416_153910-1tlhdqoz</code><br/><br/>
# Staring experiment:  pcam-pytorch-experiment#-1tlhdqoz

# %% [markdown]
# ### Google Drive Mounting - for being able to easily read the data

# %%
drive.mount('/content/gdrive/')
# !ls gdrive/MyDrive/pcamv1
# Out:
# Mounted at /content/gdrive/
# camelyonpatch_level_2_split_test_meta.csv
# camelyonpatch_level_2_split_test_x.h5
# camelyonpatch_level_2_split_test_y.h5
# camelyonpatch_level_2_split_train_mask.h5
# camelyonpatch_level_2_split_train_meta.csv
# camelyonpatch_level_2_split_train_x.h5
# camelyonpatch_level_2_split_train_y.h5
# camelyonpatch_level_2_split_valid_meta.csv
# camelyonpatch_level_2_split_valid_x.h5
# camelyonpatch_level_2_split_valid_y.h5

# %% [markdown]
# ### Class H5Dataset:
# Defines our dataset class in which we will load data from.
# <br>
# Also, deals with hdfs file format, which requires a customized reference in PyTorch

# %%
class H5Dataset(Dataset):
    def __init__(self, path, transform=None):
        self.file_path = path
        self.dataset_x = None
        self.dataset_y = None
        self.transform = transform
        ### Reading X part of HDF5
        with h5py.File(self.file_path + '_x.h5', 'r') as filex:
            self.dataset_x_len = len(filex['x'])

        ### Reading Y part of HDF5
        with h5py.File(self.file_path + '_y.h5', 'r') as filey:
            self.dataset_y_len = len(filey['y'])

    def __len__(self):
        assert self.dataset_x_len == self.dataset_y_len # Since we are reading from different sources, validating we are good in terms of size both X, Y
        return self.dataset_x_len

    def __getitem__(self, index):
        imgs_path = self.file_path + '_x.h5'
        labels_path = self.file_path + '_y.h5'

        if self.dataset_x is None:
            self.dataset_x = h5py.File(imgs_path, 'r')['x']
        if self.dataset_y is None:
            self.dataset_y = h5py.File(labels_path, 'r')['y']

        # get one pair of X, Y and return them, transform if needed
        image = self.dataset_x[index]
        label = self.dataset_y[index]

        if self.transform:
            image = self.transform(image)

        return (image, label)

# %% [markdown]
# ### Configurations params, Dataset + Dataloader Instantiation

# %%
CHECKPOINT_DIR = 'checkpoint'
drive_base_path = 'gdrive/MyDrive/pcamv1/'
BATCH_SIZE = 16
dataloader_params = {'batch_size': BATCH_SIZE, 'num_workers': 2}

train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


### For now, I'm using the train_dataset + train_loader only, splitting it to train and validation by 80% - 20%, accordingly
train_path = drive_base_path + 'camelyonpatch_level_2_split_train'
# val_path = drive_base_path + 'camelyonpatch_level_2_split_valid'
# test_path = drive_base_path + 'camelyonpatch_level_2_split_test'

# test_dataset = H5Dataset(test_path, transform=test_transforms)
# test_loader = DataLoader(test_dataset, **dataloader_params)

# val_dataset = H5Dataset(val_path, transform=test_transforms)
# dev_loader = DataLoader(val_dataset, **dataloader_params)

train_dataset = H5Dataset(train_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, **dataloader_params)

# %%
from torch.utils.data import SubsetRandomSampler

validation_split = 0.8
dataset_size = len(train_dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
# print(split)
# print(dataset_size)

train_indices, valid_indices = indices[:split], indices[split:]
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

val_dataset = H5Dataset(train_path, transform=test_transforms)
dev_loader = DataLoader(val_dataset, **dataloader_params, sampler=valid_sampler)

train_dataset = H5Dataset(train_path, transform=train_transforms)
train_loader = DataLoader(train_dataset, **dataloader_params, sampler=train_sampler)
# Out:
# 209715
# 262144

# %%
# Code that generates examples and saves on disk. Change if label > 0 to get one sample of class=0 if needed
# import matplotlib.pyplot as plt
# from PIL import Image
# from torchvision import transforms

# harish_data = H5Dataset(test_path)
# harish_loader = DataLoader(harish_data)
# for batch_x, batch_y in harish_loader:
#   label = batch_y[i].numpy()[0][0][0]
#   if label > 0:
#     print("label:", label)
#     # plt.imshow(x[i])
#     t = batch_x[i].permute(2, 0, 1)
#     print(t.shape)
#     print("t is: ", t.size())
#     im = transforms.ToPILImage()(t).convert("RGB")
#     display(im)
#     im.save('{0}.png'.format(label))
#     break

# %% [markdown]
# ### Model Architecture Class Definition

# %%
class CNN_V2(nn.Module):
    """Implemented by paper: http://cs230.stanford.edu/projects_winter_2019/posters/15813053.pdf"""
    def __init__(self, p = 0.5):
        # log dropout parameter
        wandb.config.dropout = p
        """Init method for initializaing the CNN model"""
        super(CNN_V2, self).__init__()
        # 1. Convolutional layers
        # Single image is in shape: 3x96x96 (CxHxW, H==W), RGB images
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 16, kernel_size = 3, stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, stride = 1, padding = 1)
        self.bn4 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 0)
        
        self.dropout = nn.Dropout(p = p)
        
        # 2. FC layers to final output
        self.fc1 = nn.Linear(in_features = 128*6*6, out_features = 512)
        self.fc_bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(in_features = 512, out_features = 256)
        self.fc_bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(in_features = 256, out_features = 128)
        self.fc_bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(in_features = 128, out_features = 1)

    def forward(self, x):
        # Convolution Layers, followed by Batch Normalizations, Maxpool, and ReLU
        x = self.bn1(self.conv1(x))                      # batch_size x 96 x 96 x 16
        x = self.pool(F.relu(x))                         # batch_size x 48 x 48 x 16
        x = self.bn2(self.conv2(x))                      # batch_size x 48 x 48 x 32
        x = self.pool(F.relu(x))                         # batch_size x 24 x 24 x 32
        x = self.bn3(self.conv3(x))                      # batch_size x 24 x 24 x 64
        x = self.pool(F.relu(x))                         # batch_size x 12 x 12 x 64
        x = self.bn4(self.conv4(x))                      # batch_size x 12 x 12 x 128
        x = self.pool(F.relu(x))                         # batch_size x  6 x  6 x 128
        # Flatten the output for each image
        x = x.reshape(-1, self.num_flat_features(x))        # batch_size x 6*6*128
        
        # Apply 4 FC Layers
        x = self.fc1(x)
        x = self.fc_bn1(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc2(x)
        x = self.fc_bn2(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc3(x)
        x = self.fc_bn3(x)
        x = F.relu(x)
        x = self.dropout(x)
        
        x = self.fc4(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %% [markdown]
# ### Helper Functions

# %%
def sigmoid(x):
    """This method calculates the sigmoid function"""
    return 1.0/(1.0 + np.exp(-x))

def training_accuracy(predicted, true, i, acc, tpr, tnr):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu() # Taking the predictions, why cpu and not device?
    true = true.cpu() # Taking the labels, why cpu and not device?
    
    predicted = (sigmoid(predicted.data.numpy()) > 0.5) # Using sigmoid above, if prediction > 0.5 it is 1
    true = true.data.numpy()
    accuracy = np.sum(predicted == true) / true.shape[0] # Accuracy is: (TP + TN)/(TP + TN + FN + FP)
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1) # TPR: TP / (TP + FN) aka Recall
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0) # TNR: TN / (FP + TN)
    acc = acc * (i) / (i + 1) + accuracy / (i + 1)
    tpr = tpr * (i) / (i + 1) + true_positive_rate / (i + 1)
    tnr = tnr * (i) / (i + 1) + true_negative_rate / (i + 1)
    return acc, tpr, tnr

def dev_accuracy(predicted, target):
    """Taken from https://www.kaggle.com/krishanudb/cancer-detection-deep-learning-model-using-pytorch"""
    predicted = predicted.cpu()
    target = target.cpu()
    predicted = (sigmoid(predicted.data.numpy()) > 0.5)
    true = target.data.numpy()
    accuracy = np.sum(predicted == true) / true.shape[0]
    true_positive_rate = np.sum((predicted == 1) * (true == 1)) / np.sum(true == 1)
    true_negative_rate = np.sum((predicted == 0) * (true == 0)) / np.sum(true == 0)
    return accuracy, true_positive_rate, true_negative_rate

def fetch_state(epoch, model, optimizer, dev_loss_min, dev_acc_max):
    """Returns the state dictionary for a model and optimizer"""
    state = {
        'epoch': epoch,
        'dev_loss_min': dev_loss_min,
        'dev_acc_max': dev_acc_max,
        'state_dict': model.state_dict(),
        'optim_dict': optimizer.state_dict()
    }
    return state

def save_checkpoint(state, is_best = False, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Saves model and training parameters at checkpoint + 'last.pth.tar'. If is_best==True, also saves
    checkpoint + 'best.pth.tar'

    Args:
        state: (dict) contains model's state_dict, may contain other keys such as epoch, optimizer state_dict
        is_best: (bool) True if it is the best model seen till now
        checkpoint: (string) folder where parameters are to be saved
    """
    filepath = os.path.join(checkpoint, 'last_v2.pth.tar')
    if (not os.path.exists(checkpoint)):
        print("Checkpoint Directory does not exist! Making directory {}".format(checkpoint))
        os.mkdir(checkpoint)
    else:
        print("Checkpoint Directory exists! ")
    torch.save(state, filepath)
    if (is_best):
        shutil.copyfile(filepath, os.path.join(checkpoint, 'best_v2.pth.tar'))
        
def load_checkpoint(model, optimizer = None, checkpoint = CHECKPOINT_DIR):
    """Taken from CS230 PyTorch Code Examples"""
    """Loads model parameters (state_dict) from file_path. If optimizer is provided, loads state_dict of
    optimizer assuming it is present in checkpoint.

    Args:
        checkpoint: (string) filename which needs to be loaded
        model: (torch.nn.Module) model for which the parameters are loaded
        optimizer: (torch.optim) optional: resume optimizer from checkpoint
    """
    if not os.path.exists(checkpoint):
        print("File doesn't exist {}".format(checkpoint))
        checkpoint = None
        return
    checkpoint = torch.load(checkpoint)
    model.load_state_dict(checkpoint['state_dict'])

    if optimizer:
        optimizer.load_state_dict(checkpoint['optim_dict'])

    return checkpoint

# %% [markdown]
# ### Model, Optimizer, Parameters Instantiation

# %%
# Model Instantiation
USE_GPU = torch.cuda.is_available()

model = CNN_V2()
if (USE_GPU):
    model.cuda()

# Hyperparameters + Log
lr = 5e-4
wandb.config.learning_rate = lr

# Parameters
num_workers = 0
total_epochs = 0
num_epochs = 50
early_stop_limit = 15
bad_epoch_count = 0
stop = False
train_loss_min = np.Inf
dev_loss_min = np.Inf
dev_acc_max = 0

# Optimizer + Loss Function
#optimizer = optim.Adam(model.parameters(), lr = lr) #TODO: Hyperparam tuning
optimizer = optim.SGD(model.parameters(), lr = lr)
criterion = nn.BCEWithLogitsLoss() # Binary Cross Entropy for binary classification - malignant / benign

best_checkpoint = os.path.join(CHECKPOINT_DIR, 'best_v2.pth.tar') # For saving model

total_epochs = 0 # Used in training

# Initialize arrays for plot
train_loss_arr = []
train_acc_arr = []
train_tpr_arr = []
train_tnr_arr = []

dev_loss_arr = []
dev_acc_arr = []
dev_tpr_arr = []
dev_tnr_arr = []

# %% [markdown]
# ### Training + Evaluation model

# %%
# Loop over the dataset multiple times
total_num_epochs = total_epochs + num_epochs
for epoch in range(num_epochs):
    curr_epoch = total_epochs + epoch + 1
    # Keep track of training loss
    train_loss = []
    # Keep track of dev loss
    dev_loss = []
    # Keep track of accuracy measurements
    acc, tpr, tnr = 0.0, 0.0, 0.0

    # Train the model
    start_time = time.time()
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        if USE_GPU:
            data, target = image.cuda(), label.cuda()
        else:
            data, target = image, label
        # Zero the parameter gradients
        optimizer.zero_grad()
        # Forward pass
        output = model(data)
        # Update target to be the same dimensions as output
        target = target.view(output.shape[0], 1).float()
        # Get accuracy measurements
        acc, tpr, tnr = training_accuracy(output, target, batch_idx, acc, tpr, tnr)
        # Calculate the batch's loss
        curr_train_loss = criterion(output, target)
        # Update the training loss
        train_loss.append(curr_train_loss.item())
        # Backward pass
        curr_train_loss.backward()
        # Perform a single optimization step to update parameters
        optimizer.step()
        # Print debug info every 64 batches
        if (batch_idx) % 64 == 0:
            print('Epoch {}/{}; Iter {}/{}; Loss: {:.4f}; Acc: {:.3f}; True Pos: {:.3f}; True Neg: {:.3f}'
                   .format(curr_epoch, total_num_epochs, batch_idx + 1, len(train_loader), curr_train_loss.item(), acc, tpr, tnr))
            
    end_time = time.time()
    
    # Evaluate the model
    model.eval()
    with torch.no_grad():
        for batch_idx, (image, label) in enumerate(dev_loader):
            if USE_GPU:
                data, target = image.cuda(), label.cuda()
            else:
                data, target = image, label
            # Get predicted output
            output = model(data)
            # Update target to be the same dimensions as output
            target = target.view(output.shape[0], 1).float()
            # Get accuracy measurements
            dev_acc, dev_tpr, dev_tnr = dev_accuracy(output, target)
            # Calculate the batch's loss
            curr_dev_loss = criterion(output, target)
            # Update the dev loss
            dev_loss.append(curr_dev_loss.item())
    
    # Calculate average loss
    avg_train_loss = np.mean(np.array(train_loss))
    avg_dev_loss = np.mean(np.array(dev_loss))
    
    # Update dev loss arrays
    dev_loss_arr.append(avg_dev_loss)
    dev_acc_arr.append(dev_acc)
    dev_tpr_arr.append(dev_tpr)
    dev_tnr_arr.append(dev_tnr)

    # Update training loss arrays
    train_loss_arr.append(avg_train_loss)
    train_acc_arr.append(acc)
    train_tpr_arr.append(tpr)
    train_tnr_arr.append(tnr)

    print('Epoch {}/{}; Avg. Train Loss: {:.4f}; Train Acc: {:.3f}; Train TPR: {:.3f}; Train TNR: {:.3f}; Epoch Time: {} mins; \nAvg. Dev Loss: {:.4f}; Dev Acc: {:.3f}; Dev TPR: {:.3f}; Dev TNR: {:.3f}\n'
        .format(curr_epoch, total_num_epochs, avg_train_loss, acc, tpr, tnr, round((end_time - start_time)/ 60., 2), avg_dev_loss, dev_acc, dev_tpr, dev_tnr))
    
    wandb.log({'epoch': curr_epoch, 'loss': avg_train_loss, 'accuracy': acc, 'tpr': tpr, 'time_per_epoch_min': round((end_time - start_time)/ 60., 2)})

    if avg_dev_loss < dev_loss_min:
        print('Dev loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
              .format(dev_loss_min, avg_dev_loss))
        dev_loss_min = avg_dev_loss
        is_best = False
        if (dev_acc >= dev_acc_max):
            is_best = True
            dev_acc_max = dev_acc
        state = fetch_state(epoch = curr_epoch, model = model, optimizer = optimizer, 
                            dev_loss_min = dev_loss_min, 
                            dev_acc_max = dev_acc_max)
        save_checkpoint(state = state, is_best = is_best)
        bad_epoch_count = 0
    # If dev loss didn't improve, increase bad_epoch_count and stop if
    # bad_epoch_count >= early_stop_limit
    else:
        bad_epoch_count += 1
        print('{} epochs of increasing dev loss ({:.6f} --> {:.6f}).'
              .format(bad_epoch_count, dev_loss_min, avg_dev_loss))
        if (bad_epoch_count >= early_stop_limit):
            print('Stopping training')
            stop = True

    if (stop):
        break
# Out:
# Epoch 1/50; Iter 1/13108; Loss: 0.4165; Acc: 0.688; True Pos: 0.857; True Neg: 0.556
# Epoch 1/50; Iter 65/13108; Loss: 0.5592; Acc: 0.789; True Pos: 0.800; True Neg: 0.813
# Epoch 1/50; Iter 129/13108; Loss: 0.3692; Acc: 0.801; True Pos: 0.810; True Neg: 0.821
# Epoch 1/50; Iter 193/13108; Loss: 0.3219; Acc: 0.806; True Pos: 0.820; True Neg: 0.819
# Epoch 1/50; Iter 257/13108; Loss: 0.4010; Acc: 0.808; True Pos: 0.821; True Neg: 0.821
# Epoch 1/50; Iter 321/13108; Loss: 0.4641; Acc: 0.808; True Pos: 0.819; True Neg: 0.826
# Epoch 1/50; Iter 385/13108; Loss: 0.6377; Acc: 0.808; True Pos: 0.816; True Neg: 0.826
# Epoch 1/50; Iter 449/13108; Loss: 0.3201; Acc: 0.807; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 513/13108; Loss: 0.4844; Acc: 0.806; True Pos: 0.818; True Neg: 0.822
# Epoch 1/50; Iter 577/13108; Loss: 0.2631; Acc: 0.805; True Pos: 0.818; True Neg: 0.820
# Epoch 1/50; Iter 641/13108; Loss: 0.1584; Acc: 0.805; True Pos: 0.818; True Neg: 0.821
# Epoch 1/50; Iter 705/13108; Loss: 0.5573; Acc: 0.805; True Pos: 0.815; True Neg: 0.823
# Epoch 1/50; Iter 769/13108; Loss: 0.5636; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 833/13108; Loss: 0.3408; Acc: 0.807; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 897/13108; Loss: 0.5569; Acc: 0.805; True Pos: 0.813; True Neg: 0.826
# Epoch 1/50; Iter 961/13108; Loss: 0.5111; Acc: 0.804; True Pos: 0.813; True Neg: 0.824
# Epoch 1/50; Iter 1025/13108; Loss: 0.4743; Acc: 0.805; True Pos: 0.814; True Neg: 0.824
# Epoch 1/50; Iter 1089/13108; Loss: 0.4998; Acc: 0.806; True Pos: 0.815; True Neg: 0.824
# Epoch 1/50; Iter 1153/13108; Loss: 0.5142; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 1217/13108; Loss: 0.3350; Acc: 0.807; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 1281/13108; Loss: 0.2637; Acc: 0.807; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 1345/13108; Loss: 0.2549; Acc: 0.807; True Pos: 0.816; True Neg: 0.825
# Epoch 1/50; Iter 1409/13108; Loss: 0.9064; Acc: 0.807; True Pos: 0.816; True Neg: 0.825
# Epoch 1/50; Iter 1473/13108; Loss: 0.7376; Acc: 0.807; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 1537/13108; Loss: 0.4403; Acc: 0.807; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 1601/13108; Loss: 0.2474; Acc: 0.806; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 1665/13108; Loss: 0.4070; Acc: 0.806; True Pos: 0.815; True Neg: 0.824
# Epoch 1/50; Iter 1729/13108; Loss: 0.7498; Acc: 0.806; True Pos: 0.815; True Neg: 0.824
# Epoch 1/50; Iter 1793/13108; Loss: 0.3652; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 1857/13108; Loss: 0.3407; Acc: 0.806; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 1921/13108; Loss: 0.4195; Acc: 0.806; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 1985/13108; Loss: 0.1786; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 2049/13108; Loss: 0.4481; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 2113/13108; Loss: 0.4787; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 2177/13108; Loss: 0.4990; Acc: 0.806; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 2241/13108; Loss: 0.4967; Acc: 0.806; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 2305/13108; Loss: 0.5449; Acc: 0.805; True Pos: 0.813; True Neg: 0.824
# Epoch 1/50; Iter 2369/13108; Loss: 0.5723; Acc: 0.805; True Pos: 0.813; True Neg: 0.825
# Epoch 1/50; Iter 2433/13108; Loss: 0.2587; Acc: 0.805; True Pos: 0.813; True Neg: 0.825
# Epoch 1/50; Iter 2497/13108; Loss: 0.1781; Acc: 0.805; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 2561/13108; Loss: 0.6040; Acc: 0.805; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 2625/13108; Loss: 0.4941; Acc: 0.805; True Pos: 0.815; True Neg: 0.824
# Epoch 1/50; Iter 2689/13108; Loss: 0.3587; Acc: 0.805; True Pos: 0.814; True Neg: 0.824
# Epoch 1/50; Iter 2753/13108; Loss: 0.4359; Acc: 0.805; True Pos: 0.814; True Neg: 0.824
# Epoch 1/50; Iter 2817/13108; Loss: 0.3893; Acc: 0.805; True Pos: 0.814; True Neg: 0.825
# Epoch 1/50; Iter 2881/13108; Loss: 0.2933; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 2945/13108; Loss: 0.4162; Acc: 0.806; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 3009/13108; Loss: 0.4026; Acc: 0.806; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 3073/13108; Loss: 0.4632; Acc: 0.806; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 3137/13108; Loss: 0.2783; Acc: 0.806; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 3201/13108; Loss: 0.5782; Acc: 0.806; True Pos: 0.815; True Neg: 0.825
# Epoch 1/50; Iter 3265/13108; Loss: 0.5664; Acc: 0.806; True Pos: 0.815; True Neg: 0.826
# Epoch 1/50; Iter 3329/13108; Loss: 0.2063; Acc: 0.806; True Pos: 0.816; True Neg: 0.825
# Epoch 1/50; Iter 3393/13108; Loss: 0.3001; Acc: 0.806; True Pos: 0.816; True Neg: 0.825
# Epoch 1/50; Iter 3457/13108; Loss: 0.4200; Acc: 0.806; True Pos: 0.816; True Neg: 0.825
# Epoch 1/50; Iter 3521/13108; Loss: 0.3907; Acc: 0.806; True Pos: 0.817; True Neg: 0.825
# Epoch 1/50; Iter 3585/13108; Loss: 0.5043; Acc: 0.806; True Pos: 0.817; True Neg: 0.825
# Epoch 1/50; Iter 3649/13108; Loss: 0.2279; Acc: 0.806; True Pos: 0.817; True Neg: 0.825
# Epoch 1/50; Iter 3713/13108; Loss: 0.4824; Acc: 0.806; True Pos: 0.817; True Neg: 0.825
# Epoch 1/50; Iter 3777/13108; Loss: 0.2894; Acc: 0.806; True Pos: 0.817; True Neg: 0.825
# Epoch 1/50; Iter 3841/13108; Loss: 0.4586; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 3905/13108; Loss: 0.2713; Acc: 0.805; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 3969/13108; Loss: 0.5113; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4033/13108; Loss: 0.5249; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4097/13108; Loss: 0.3403; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4161/13108; Loss: 0.5127; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4225/13108; Loss: 0.4392; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4289/13108; Loss: 0.8269; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4353/13108; Loss: 0.5498; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4417/13108; Loss: 0.3824; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4481/13108; Loss: 0.5615; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4545/13108; Loss: 0.3507; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4609/13108; Loss: 0.2209; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4673/13108; Loss: 0.3693; Acc: 0.806; True Pos: 0.816; True Neg: 0.824
# Epoch 1/50; Iter 4737/13108; Loss: 0.2879; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4801/13108; Loss: 0.6727; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4865/13108; Loss: 0.6374; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4929/13108; Loss: 0.4004; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 4993/13108; Loss: 0.3478; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 5057/13108; Loss: 0.3809; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 5121/13108; Loss: 0.3543; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 5185/13108; Loss: 0.4085; Acc: 0.806; True Pos: 0.817; True Neg: 0.824
# Epoch 1/50; Iter 5249/13108; Loss: 0.4800; Acc: 0.806; True Pos: 0.818; True Neg: 0.824
# Epoch 1/50; Iter 5313/13108; Loss: 0.3086; Acc: 0.806; True Pos: 0.818; True Neg: 0.824
# Epoch 1/50; Iter 5377/13108; Loss: 0.4190; Acc: 0.806; True Pos: 0.818; True Neg: 0.824
# Epoch 1/50; Iter 5441/13108; Loss: 0.3119; Acc: 0.806; True Pos: 0.818; True Neg: 0.824
# Epoch 1/50; Iter 5505/13108; Loss: 0.6221; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5569/13108; Loss: 0.4407; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5633/13108; Loss: 0.6479; Acc: 0.807; True Pos: 0.818; True Neg: 0.824
# Epoch 1/50; Iter 5697/13108; Loss: 0.4769; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5761/13108; Loss: 0.5000; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5825/13108; Loss: 0.3486; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5889/13108; Loss: 0.3673; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 5953/13108; Loss: 0.4179; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6017/13108; Loss: 0.3887; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6081/13108; Loss: 0.2670; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6145/13108; Loss: 0.4836; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6209/13108; Loss: 0.2760; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6273/13108; Loss: 0.4384; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6337/13108; Loss: 0.8573; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6401/13108; Loss: 0.6747; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6465/13108; Loss: 0.4849; Acc: 0.807; True Pos: 0.818; True Neg: 0.825
# Epoch 1/50; Iter 6529/13108; Loss: 0.3112; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6593/13108; Loss: 0.2907; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6657/13108; Loss: 0.3859; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6721/13108; Loss: 0.3870; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6785/13108; Loss: 0.7034; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6849/13108; Loss: 0.3106; Acc: 0.807; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6913/13108; Loss: 0.2693; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 6977/13108; Loss: 0.3182; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7041/13108; Loss: 0.5065; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7105/13108; Loss: 0.3704; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7169/13108; Loss: 0.3739; Acc: 0.808; True Pos: 0.819; True Neg: 0.826
# Epoch 1/50; Iter 7233/13108; Loss: 0.3771; Acc: 0.808; True Pos: 0.819; True Neg: 0.826
# Epoch 1/50; Iter 7297/13108; Loss: 0.1958; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7361/13108; Loss: 0.8978; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7425/13108; Loss: 0.5699; Acc: 0.808; True Pos: 0.819; True Neg: 0.825
# Epoch 1/50; Iter 7489/13108; Loss: 0.6153; Acc: 0.808; True Pos: 0.820; True Neg: 0.825
# Epoch 1/50; Iter 7553/13108; Loss: 0.3531; Acc: 0.808; True Pos: 0.820; True Neg: 0.825
# Epoch 1/50; Iter 7617/13108; Loss: 0.3719; Acc: 0.808; True Pos: 0.820; True Neg: 0.825
# Epoch 1/50; Iter 7681/13108; Loss: 0.4474; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 7745/13108; Loss: 0.2805; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 7809/13108; Loss: 0.7145; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 7873/13108; Loss: 0.4257; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 7937/13108; Loss: 0.1944; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8001/13108; Loss: 0.3301; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8065/13108; Loss: 0.5531; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8129/13108; Loss: 0.2436; Acc: 0.808; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8193/13108; Loss: 0.6314; Acc: 0.809; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8257/13108; Loss: 0.3222; Acc: 0.809; True Pos: 0.820; True Neg: 0.826
# Epoch 1/50; Iter 8321/13108; Loss: 0.3310; Acc: 0.809; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8385/13108; Loss: 0.6571; Acc: 0.809; True Pos: 0.821; True Neg: 0.826
# Epoch 1/50; Iter 8449/13108; Loss: 0.2921; Acc: 0.809; True Pos: 0.821; True Neg: 0.826
# Epoch 1/50; Iter 8513/13108; Loss: 0.2613; Acc: 0.809; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8577/13108; Loss: 0.2249; Acc: 0.809; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8641/13108; Loss: 0.2929; Acc: 0.809; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8705/13108; Loss: 0.2450; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8769/13108; Loss: 0.2449; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8833/13108; Loss: 0.3141; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8897/13108; Loss: 0.2555; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 8961/13108; Loss: 0.3236; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 9025/13108; Loss: 0.3323; Acc: 0.810; True Pos: 0.821; True Neg: 0.827
# Epoch 1/50; Iter 9089/13108; Loss: 0.3883; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9153/13108; Loss: 0.3127; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9217/13108; Loss: 0.5248; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9281/13108; Loss: 0.4852; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9345/13108; Loss: 0.6023; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9409/13108; Loss: 0.7163; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9473/13108; Loss: 0.4435; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9537/13108; Loss: 0.2978; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9601/13108; Loss: 0.3476; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9665/13108; Loss: 0.5390; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9729/13108; Loss: 0.2835; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9793/13108; Loss: 0.6633; Acc: 0.810; True Pos: 0.822; True Neg: 0.827
# Epoch 1/50; Iter 9857/13108; Loss: 0.4092; Acc: 0.810; True Pos: 0.822; True Neg: 0.828
# Epoch 1/50; Iter 9921/13108; Loss: 0.2616; Acc: 0.810; True Pos: 0.822; True Neg: 0.828
# Epoch 1/50; Iter 9985/13108; Loss: 0.2724; Acc: 0.810; True Pos: 0.822; True Neg: 0.828
# Epoch 1/50; Iter 10049/13108; Loss: 0.2926; Acc: 0.810; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10113/13108; Loss: 0.4541; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10177/13108; Loss: 0.3448; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10241/13108; Loss: 0.3558; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10305/13108; Loss: 0.7936; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10369/13108; Loss: 0.4810; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10433/13108; Loss: 0.4877; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10497/13108; Loss: 0.2187; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10561/13108; Loss: 0.2572; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10625/13108; Loss: 0.3329; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10689/13108; Loss: 0.6289; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10753/13108; Loss: 0.4130; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10817/13108; Loss: 0.3397; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10881/13108; Loss: 0.4123; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 10945/13108; Loss: 0.5313; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 11009/13108; Loss: 0.1477; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 11073/13108; Loss: 0.4587; Acc: 0.811; True Pos: 0.823; True Neg: 0.828
# Epoch 1/50; Iter 11137/13108; Loss: 0.2016; Acc: 0.811; True Pos: 0.824; True Neg: 0.828
# Epoch 1/50; Iter 11201/13108; Loss: 0.3491; Acc: 0.811; True Pos: 0.823; True Neg: 0.829
# Epoch 1/50; Iter 11265/13108; Loss: 0.3326; Acc: 0.811; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11329/13108; Loss: 0.3239; Acc: 0.811; True Pos: 0.824; True Neg: 0.828
# Epoch 1/50; Iter 11393/13108; Loss: 0.3593; Acc: 0.811; True Pos: 0.824; True Neg: 0.828
# Epoch 1/50; Iter 11457/13108; Loss: 0.4915; Acc: 0.812; True Pos: 0.824; True Neg: 0.828
# Epoch 1/50; Iter 11521/13108; Loss: 0.8863; Acc: 0.812; True Pos: 0.824; True Neg: 0.828
# Epoch 1/50; Iter 11585/13108; Loss: 0.3314; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11649/13108; Loss: 0.4578; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11713/13108; Loss: 0.3131; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11777/13108; Loss: 0.3413; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11841/13108; Loss: 0.5155; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11905/13108; Loss: 0.4726; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 11969/13108; Loss: 0.7214; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12033/13108; Loss: 0.2848; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12097/13108; Loss: 0.5364; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12161/13108; Loss: 0.3206; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12225/13108; Loss: 0.3974; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12289/13108; Loss: 0.2579; Acc: 0.812; True Pos: 0.824; True Neg: 0.829
# Epoch 1/50; Iter 12353/13108; Loss: 0.2416; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12417/13108; Loss: 0.3824; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12481/13108; Loss: 0.2569; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12545/13108; Loss: 0.3265; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12609/13108; Loss: 0.3397; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12673/13108; Loss: 0.4042; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12737/13108; Loss: 0.2313; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12801/13108; Loss: 0.3187; Acc: 0.812; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12865/13108; Loss: 0.2597; Acc: 0.813; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12929/13108; Loss: 0.7071; Acc: 0.813; True Pos: 0.825; True Neg: 0.829
# Epoch 1/50; Iter 12993/13108; Loss: 0.4361; Acc: 0.813; True Pos: 0.826; True Neg: 0.829
# Epoch 1/50; Iter 13057/13108; Loss: 0.3689; Acc: 0.813; True Pos: 0.826; True Neg: 0.829
# Epoch 1/50; Avg. Train Loss: 0.4221; Train Acc: 0.813; Train TPR: 0.826; Train TNR: 0.829; Epoch Time: 6.41 mins;
# Avg. Dev Loss: 0.4263; Dev Acc: 0.846; Dev TPR: 0.800; Dev TNR: 0.875
#
# Dev loss decreased (inf --> 0.426313).  Saving model ...
# Checkpoint Directory does not exist! Making directory checkpoint
# Epoch 2/50; Iter 1/13108; Loss: 0.5610; Acc: 0.688; True Pos: 0.800; True Neg: 0.500
# Epoch 2/50; Iter 65/13108; Loss: 0.6170; Acc: 0.835; True Pos: 0.848; True Neg: 0.850
# Epoch 2/50; Iter 129/13108; Loss: 0.3537; Acc: 0.829; True Pos: 0.846; True Neg: 0.841
# Epoch 2/50; Iter 193/13108; Loss: 0.2846; Acc: 0.828; True Pos: 0.845; True Neg: 0.838
# Epoch 2/50; Iter 257/13108; Loss: 0.4680; Acc: 0.828; True Pos: 0.845; True Neg: 0.840
# Epoch 2/50; Iter 321/13108; Loss: 0.4137; Acc: 0.824; True Pos: 0.842; True Neg: 0.831
# Epoch 2/50; Iter 385/13108; Loss: 0.6405; Acc: 0.826; True Pos: 0.845; True Neg: 0.833
# Epoch 2/50; Iter 449/13108; Loss: 0.3647; Acc: 0.824; True Pos: 0.839; True Neg: 0.836
# Epoch 2/50; Iter 513/13108; Loss: 0.5223; Acc: 0.824; True Pos: 0.842; True Neg: 0.833
# Epoch 2/50; Iter 577/13108; Loss: 0.2833; Acc: 0.825; True Pos: 0.843; True Neg: 0.834
# Epoch 2/50; Iter 641/13108; Loss: 0.4735; Acc: 0.825; True Pos: 0.843; True Neg: 0.833
# Epoch 2/50; Iter 705/13108; Loss: 0.2424; Acc: 0.825; True Pos: 0.844; True Neg: 0.833
# Epoch 2/50; Iter 769/13108; Loss: 0.2393; Acc: 0.825; True Pos: 0.843; True Neg: 0.834
# Epoch 2/50; Iter 833/13108; Loss: 0.6134; Acc: 0.824; True Pos: 0.842; True Neg: 0.834
# Epoch 2/50; Iter 897/13108; Loss: 0.4724; Acc: 0.824; True Pos: 0.841; True Neg: 0.834
# Epoch 2/50; Iter 961/13108; Loss: 0.1586; Acc: 0.824; True Pos: 0.840; True Neg: 0.835
# Epoch 2/50; Iter 1025/13108; Loss: 0.3629; Acc: 0.825; True Pos: 0.840; True Neg: 0.836
# Epoch 2/50; Iter 1089/13108; Loss: 0.6347; Acc: 0.825; True Pos: 0.840; True Neg: 0.836
# Epoch 2/50; Iter 1153/13108; Loss: 0.3093; Acc: 0.824; True Pos: 0.839; True Neg: 0.836
# Epoch 2/50; Iter 1217/13108; Loss: 0.7452; Acc: 0.825; True Pos: 0.841; True Neg: 0.836
# Epoch 2/50; Iter 1281/13108; Loss: 0.4150; Acc: 0.826; True Pos: 0.842; True Neg: 0.837
# Epoch 2/50; Iter 1345/13108; Loss: 0.3125; Acc: 0.826; True Pos: 0.841; True Neg: 0.837
# Epoch 2/50; Iter 1409/13108; Loss: 0.6417; Acc: 0.826; True Pos: 0.841; True Neg: 0.837
# Epoch 2/50; Iter 1473/13108; Loss: 0.4613; Acc: 0.825; True Pos: 0.840; True Neg: 0.837
# Epoch 2/50; Iter 1537/13108; Loss: 0.2627; Acc: 0.825; True Pos: 0.840; True Neg: 0.837
# Epoch 2/50; Iter 1601/13108; Loss: 0.6550; Acc: 0.825; True Pos: 0.841; True Neg: 0.836
# Epoch 2/50; Iter 1665/13108; Loss: 0.4759; Acc: 0.824; True Pos: 0.840; True Neg: 0.836
# Epoch 2/50; Iter 1729/13108; Loss: 0.3702; Acc: 0.825; True Pos: 0.840; True Neg: 0.837
# Epoch 2/50; Iter 1793/13108; Loss: 0.2272; Acc: 0.824; True Pos: 0.840; True Neg: 0.836
# Epoch 2/50; Iter 1857/13108; Loss: 0.5723; Acc: 0.825; True Pos: 0.841; True Neg: 0.836
# Epoch 2/50; Iter 1921/13108; Loss: 0.6127; Acc: 0.825; True Pos: 0.842; True Neg: 0.836
# Epoch 2/50; Iter 1985/13108; Loss: 0.4364; Acc: 0.824; True Pos: 0.841; True Neg: 0.835
# Epoch 2/50; Iter 2049/13108; Loss: 0.2400; Acc: 0.824; True Pos: 0.841; True Neg: 0.835
# Epoch 2/50; Iter 2113/13108; Loss: 0.5156; Acc: 0.824; True Pos: 0.841; True Neg: 0.836
# Epoch 2/50; Iter 2177/13108; Loss: 0.3310; Acc: 0.825; True Pos: 0.842; True Neg: 0.835
# Epoch 2/50; Iter 2241/13108; Loss: 0.5022; Acc: 0.824; True Pos: 0.841; True Neg: 0.835
# Epoch 2/50; Iter 2305/13108; Loss: 0.3126; Acc: 0.825; True Pos: 0.842; True Neg: 0.835
# Epoch 2/50; Iter 2369/13108; Loss: 0.3690; Acc: 0.825; True Pos: 0.843; True Neg: 0.834
# Epoch 2/50; Iter 2433/13108; Loss: 0.2821; Acc: 0.825; True Pos: 0.843; True Neg: 0.835
# Epoch 2/50; Iter 2497/13108; Loss: 0.4518; Acc: 0.826; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 2561/13108; Loss: 0.5071; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 2625/13108; Loss: 0.4605; Acc: 0.826; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 2689/13108; Loss: 0.2628; Acc: 0.826; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 2753/13108; Loss: 0.2711; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 2817/13108; Loss: 0.3031; Acc: 0.826; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 2881/13108; Loss: 0.2578; Acc: 0.826; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 2945/13108; Loss: 0.2436; Acc: 0.826; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3009/13108; Loss: 0.4655; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3073/13108; Loss: 0.6375; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3137/13108; Loss: 0.3530; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3201/13108; Loss: 0.3555; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3265/13108; Loss: 0.4644; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 3329/13108; Loss: 0.2761; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 3393/13108; Loss: 0.3256; Acc: 0.826; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 3457/13108; Loss: 0.5094; Acc: 0.825; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 3521/13108; Loss: 0.3111; Acc: 0.825; True Pos: 0.844; True Neg: 0.835
# Epoch 2/50; Iter 3585/13108; Loss: 0.2266; Acc: 0.825; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 3649/13108; Loss: 0.2804; Acc: 0.826; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 3713/13108; Loss: 0.4160; Acc: 0.825; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 3777/13108; Loss: 0.2158; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 3841/13108; Loss: 0.6033; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 3905/13108; Loss: 0.2202; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 3969/13108; Loss: 0.5467; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 4033/13108; Loss: 0.2073; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 4097/13108; Loss: 0.3519; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 4161/13108; Loss: 0.3211; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4225/13108; Loss: 0.3706; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4289/13108; Loss: 0.3157; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4353/13108; Loss: 0.7513; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4417/13108; Loss: 0.2773; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4481/13108; Loss: 0.8802; Acc: 0.824; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4545/13108; Loss: 0.4271; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4609/13108; Loss: 0.3034; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 4673/13108; Loss: 0.5165; Acc: 0.825; True Pos: 0.844; True Neg: 0.834
# Epoch 2/50; Iter 4737/13108; Loss: 0.8797; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4801/13108; Loss: 0.4801; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4865/13108; Loss: 0.2791; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4929/13108; Loss: 0.2650; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 4993/13108; Loss: 0.2929; Acc: 0.825; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5057/13108; Loss: 0.4179; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 5121/13108; Loss: 0.3940; Acc: 0.825; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 5185/13108; Loss: 0.4027; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 5249/13108; Loss: 0.4271; Acc: 0.825; True Pos: 0.845; True Neg: 0.834
# Epoch 2/50; Iter 5313/13108; Loss: 0.3750; Acc: 0.825; True Pos: 0.845; True Neg: 0.835
# Epoch 2/50; Iter 5377/13108; Loss: 0.2235; Acc: 0.826; True Pos: 0.846; True Neg: 0.835
# Epoch 2/50; Iter 5441/13108; Loss: 0.4323; Acc: 0.826; True Pos: 0.846; True Neg: 0.835
# Epoch 2/50; Iter 5505/13108; Loss: 0.2075; Acc: 0.826; True Pos: 0.846; True Neg: 0.835
# Epoch 2/50; Iter 5569/13108; Loss: 0.5734; Acc: 0.826; True Pos: 0.846; True Neg: 0.835
# Epoch 2/50; Iter 5633/13108; Loss: 0.3539; Acc: 0.826; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5697/13108; Loss: 0.3512; Acc: 0.825; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5761/13108; Loss: 0.2401; Acc: 0.826; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5825/13108; Loss: 0.3953; Acc: 0.825; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5889/13108; Loss: 0.8780; Acc: 0.825; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 5953/13108; Loss: 0.2986; Acc: 0.825; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 6017/13108; Loss: 0.1750; Acc: 0.826; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 6081/13108; Loss: 0.2305; Acc: 0.826; True Pos: 0.846; True Neg: 0.834
# Epoch 2/50; Iter 6145/13108; Loss: 0.6768; Acc: 0.826; True Pos: 0.847; True Neg: 0.834
# Epoch 2/50; Iter 6209/13108; Loss: 0.8545; Acc: 0.826; True Pos: 0.847; True Neg: 0.835
# Epoch 2/50; Iter 6273/13108; Loss: 0.3694; Acc: 0.826; True Pos: 0.847; True Neg: 0.835
# Epoch 2/50; Iter 6337/13108; Loss: 0.3055; Acc: 0.826; True Pos: 0.847; True Neg: 0.834
# Epoch 2/50; Iter 6401/13108; Loss: 0.4888; Acc: 0.826; True Pos: 0.847; True Neg: 0.835
# Epoch 2/50; Iter 6465/13108; Loss: 0.2896; Acc: 0.826; True Pos: 0.847; True Neg: 0.834
# Epoch 2/50; Iter 6529/13108; Loss: 0.2860; Acc: 0.826; True Pos: 0.848; True Neg: 0.834
# Epoch 2/50; Iter 6593/13108; Loss: 0.2757; Acc: 0.826; True Pos: 0.847; True Neg: 0.835
# Epoch 2/50; Iter 6657/13108; Loss: 0.4310; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 6721/13108; Loss: 0.3001; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 6785/13108; Loss: 0.6389; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 6849/13108; Loss: 0.3599; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 6913/13108; Loss: 1.0160; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 6977/13108; Loss: 0.3267; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 7041/13108; Loss: 0.4585; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 7105/13108; Loss: 0.5599; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 7169/13108; Loss: 0.4787; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 7233/13108; Loss: 0.3786; Acc: 0.827; True Pos: 0.848; True Neg: 0.835
# Epoch 2/50; Iter 7297/13108; Loss: 0.6731; Acc: 0.827; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7361/13108; Loss: 0.3410; Acc: 0.827; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7425/13108; Loss: 0.6763; Acc: 0.827; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7489/13108; Loss: 0.2558; Acc: 0.827; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7553/13108; Loss: 0.4481; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7617/13108; Loss: 0.3161; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7681/13108; Loss: 0.3825; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 7745/13108; Loss: 0.4539; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7809/13108; Loss: 0.3500; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7873/13108; Loss: 0.3439; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 7937/13108; Loss: 0.4729; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8001/13108; Loss: 0.9440; Acc: 0.827; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8065/13108; Loss: 0.4204; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8129/13108; Loss: 0.1630; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8193/13108; Loss: 0.1981; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8257/13108; Loss: 0.2105; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8321/13108; Loss: 0.6139; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8385/13108; Loss: 0.4637; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8449/13108; Loss: 0.1865; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8513/13108; Loss: 0.3545; Acc: 0.828; True Pos: 0.849; True Neg: 0.836
# Epoch 2/50; Iter 8577/13108; Loss: 0.1606; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8641/13108; Loss: 0.6062; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 8705/13108; Loss: 0.3061; Acc: 0.828; True Pos: 0.848; True Neg: 0.836
# Epoch 2/50; Iter 8769/13108; Loss: 0.5140; Acc: 0.828; True Pos: 0.849; True Neg: 0.837
# Epoch 2/50; Iter 8833/13108; Loss: 0.3768; Acc: 0.828; True Pos: 0.849; True Neg: 0.837
# Epoch 2/50; Iter 8897/13108; Loss: 0.6551; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 8961/13108; Loss: 0.2985; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9025/13108; Loss: 0.2433; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9089/13108; Loss: 0.3533; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9153/13108; Loss: 0.3277; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9217/13108; Loss: 0.3358; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9281/13108; Loss: 0.4392; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9345/13108; Loss: 0.8294; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9409/13108; Loss: 0.2708; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9473/13108; Loss: 0.5470; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9537/13108; Loss: 0.5158; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9601/13108; Loss: 0.3863; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9665/13108; Loss: 0.6449; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9729/13108; Loss: 0.4708; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9793/13108; Loss: 0.2837; Acc: 0.828; True Pos: 0.849; True Neg: 0.837
# Epoch 2/50; Iter 9857/13108; Loss: 0.3316; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9921/13108; Loss: 0.2088; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 9985/13108; Loss: 0.6455; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 10049/13108; Loss: 0.5653; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 10113/13108; Loss: 0.4840; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 10177/13108; Loss: 0.4154; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 10241/13108; Loss: 0.2884; Acc: 0.828; True Pos: 0.848; True Neg: 0.837
# Epoch 2/50; Iter 10305/13108; Loss: 0.4022; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10369/13108; Loss: 0.2732; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10433/13108; Loss: 0.3826; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10497/13108; Loss: 0.2746; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10561/13108; Loss: 0.3387; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10625/13108; Loss: 0.4711; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10689/13108; Loss: 0.3104; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10753/13108; Loss: 0.2828; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10817/13108; Loss: 0.3871; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10881/13108; Loss: 0.4938; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 10945/13108; Loss: 0.4884; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11009/13108; Loss: 0.2866; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11073/13108; Loss: 0.3914; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11137/13108; Loss: 0.6400; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11201/13108; Loss: 0.2446; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11265/13108; Loss: 0.6518; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11329/13108; Loss: 0.4668; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11393/13108; Loss: 0.2509; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11457/13108; Loss: 0.2748; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11521/13108; Loss: 0.4705; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11585/13108; Loss: 0.2625; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11649/13108; Loss: 0.4730; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11713/13108; Loss: 0.2587; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11777/13108; Loss: 0.3199; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11841/13108; Loss: 1.0867; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11905/13108; Loss: 0.2689; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 11969/13108; Loss: 0.4223; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12033/13108; Loss: 0.3738; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12097/13108; Loss: 0.2884; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12161/13108; Loss: 0.9286; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12225/13108; Loss: 0.7132; Acc: 0.828; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12289/13108; Loss: 0.5339; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12353/13108; Loss: 0.3411; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12417/13108; Loss: 0.2702; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12481/13108; Loss: 0.3184; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12545/13108; Loss: 0.5804; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12609/13108; Loss: 0.5797; Acc: 0.829; True Pos: 0.848; True Neg: 0.838
# Epoch 2/50; Iter 12673/13108; Loss: 0.2471; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 12737/13108; Loss: 0.3199; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 12801/13108; Loss: 0.1896; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 12865/13108; Loss: 0.3411; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 12929/13108; Loss: 0.4620; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 12993/13108; Loss: 0.1614; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# Epoch 2/50; Iter 13057/13108; Loss: 0.3385; Acc: 0.829; True Pos: 0.849; True Neg: 0.838
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   del sys.path[0]
# Epoch 2/50; Avg. Train Loss: 0.3965; Train Acc: 0.829; Train TPR: nan; Train TNR: 0.838; Epoch Time: 6.22 mins;
# Avg. Dev Loss: 0.8368; Dev Acc: 0.615; Dev TPR: 1.000; Dev TNR: 0.286
#
# 1 epochs of increasing dev loss (0.426313 --> 0.836766).
# Epoch 3/50; Iter 1/13108; Loss: 0.6737; Acc: 0.812; True Pos: 0.727; True Neg: 1.000
# Epoch 3/50; Iter 65/13108; Loss: 0.4073; Acc: 0.833; True Pos: 0.857; True Neg: 0.837
# Epoch 3/50; Iter 129/13108; Loss: 0.6675; Acc: 0.836; True Pos: 0.856; True Neg: 0.847
# Epoch 3/50; Iter 193/13108; Loss: 0.2934; Acc: 0.839; True Pos: 0.862; True Neg: 0.845
# Epoch 3/50; Iter 257/13108; Loss: 0.5249; Acc: 0.836; True Pos: 0.859; True Neg: 0.843
# Epoch 3/50; Iter 321/13108; Loss: 0.2163; Acc: 0.840; True Pos: 0.863; True Neg: 0.845
# Epoch 3/50; Iter 385/13108; Loss: 0.2935; Acc: 0.838; True Pos: 0.858; True Neg: 0.848
# Epoch 3/50; Iter 449/13108; Loss: 0.3517; Acc: 0.836; True Pos: 0.854; True Neg: 0.849
# Epoch 3/50; Iter 513/13108; Loss: 0.5753; Acc: 0.836; True Pos: 0.854; True Neg: 0.850
# Epoch 3/50; Iter 577/13108; Loss: 0.3401; Acc: 0.838; True Pos: 0.855; True Neg: 0.851
# Epoch 3/50; Iter 641/13108; Loss: 0.6540; Acc: 0.835; True Pos: 0.854; True Neg: 0.847
# Epoch 3/50; Iter 705/13108; Loss: 0.3175; Acc: 0.834; True Pos: 0.852; True Neg: 0.847
# Epoch 3/50; Iter 769/13108; Loss: 0.3623; Acc: 0.834; True Pos: 0.853; True Neg: 0.845
# Epoch 3/50; Iter 833/13108; Loss: 0.3388; Acc: 0.834; True Pos: 0.854; True Neg: 0.845
# Epoch 3/50; Iter 897/13108; Loss: 0.3669; Acc: 0.834; True Pos: 0.855; True Neg: 0.845
# Epoch 3/50; Iter 961/13108; Loss: 0.3479; Acc: 0.834; True Pos: 0.856; True Neg: 0.843
# Epoch 3/50; Iter 1025/13108; Loss: 0.4646; Acc: 0.834; True Pos: 0.857; True Neg: 0.843
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in long_scalars
# Epoch 3/50; Iter 1089/13108; Loss: 0.2658; Acc: 0.834; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 1153/13108; Loss: 0.6090; Acc: 0.835; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 1217/13108; Loss: 0.3790; Acc: 0.835; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 1281/13108; Loss: 0.6512; Acc: 0.835; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 1345/13108; Loss: 0.6249; Acc: 0.835; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 1409/13108; Loss: 0.2811; Acc: 0.835; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 1473/13108; Loss: 0.5289; Acc: 0.834; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 1537/13108; Loss: 0.2607; Acc: 0.834; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 1601/13108; Loss: 0.3914; Acc: 0.834; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 1665/13108; Loss: 0.2872; Acc: 0.834; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 1729/13108; Loss: 0.6351; Acc: 0.834; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 1793/13108; Loss: 0.3181; Acc: 0.834; True Pos: 0.856; True Neg: nan
# Epoch 3/50; Iter 1857/13108; Loss: 0.2650; Acc: 0.834; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 1921/13108; Loss: 0.2778; Acc: 0.835; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 1985/13108; Loss: 0.4488; Acc: 0.835; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2049/13108; Loss: 0.4209; Acc: 0.835; True Pos: 0.856; True Neg: nan
# Epoch 3/50; Iter 2113/13108; Loss: 0.3780; Acc: 0.834; True Pos: 0.856; True Neg: nan
# Epoch 3/50; Iter 2177/13108; Loss: 0.2943; Acc: 0.835; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2241/13108; Loss: 0.2539; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2305/13108; Loss: 0.3307; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2369/13108; Loss: 0.5396; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2433/13108; Loss: 0.3980; Acc: 0.835; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2497/13108; Loss: 0.2791; Acc: 0.835; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2561/13108; Loss: 0.4171; Acc: 0.835; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2625/13108; Loss: 0.6368; Acc: 0.835; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2689/13108; Loss: 0.4501; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2753/13108; Loss: 0.4077; Acc: 0.835; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2817/13108; Loss: 0.3366; Acc: 0.835; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 2881/13108; Loss: 0.5414; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 2945/13108; Loss: 0.2622; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3009/13108; Loss: 0.3637; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3073/13108; Loss: 0.3027; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3137/13108; Loss: 0.4772; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3201/13108; Loss: 0.3458; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3265/13108; Loss: 0.2818; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3329/13108; Loss: 0.3741; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3393/13108; Loss: 0.3322; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3457/13108; Loss: 0.2528; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3521/13108; Loss: 0.3272; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3585/13108; Loss: 0.3476; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 3649/13108; Loss: 0.6024; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3713/13108; Loss: 0.4481; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3777/13108; Loss: 0.2815; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3841/13108; Loss: 0.5464; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3905/13108; Loss: 0.3446; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 3969/13108; Loss: 0.6363; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 4033/13108; Loss: 0.6317; Acc: 0.836; True Pos: 0.857; True Neg: nan
# Epoch 3/50; Iter 4097/13108; Loss: 0.2548; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4161/13108; Loss: 0.2011; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4225/13108; Loss: 0.4173; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4289/13108; Loss: 0.2835; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4353/13108; Loss: 0.2260; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4417/13108; Loss: 0.4738; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4481/13108; Loss: 0.3506; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4545/13108; Loss: 0.4320; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4609/13108; Loss: 0.6617; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4673/13108; Loss: 0.4153; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4737/13108; Loss: 0.2844; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4801/13108; Loss: 0.3220; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4865/13108; Loss: 0.1843; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4929/13108; Loss: 0.3396; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 4993/13108; Loss: 0.2539; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5057/13108; Loss: 0.4497; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5121/13108; Loss: 0.2594; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5185/13108; Loss: 0.2497; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 5249/13108; Loss: 0.3317; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 5313/13108; Loss: 0.4563; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 5377/13108; Loss: 0.3906; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 5441/13108; Loss: 0.5402; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5505/13108; Loss: 0.1784; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5569/13108; Loss: 0.3127; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 5633/13108; Loss: 0.7224; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5697/13108; Loss: 0.2041; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5761/13108; Loss: 0.5411; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5825/13108; Loss: 0.3519; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5889/13108; Loss: 0.3216; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 5953/13108; Loss: 0.4048; Acc: 0.836; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6017/13108; Loss: 0.3576; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6081/13108; Loss: 0.3684; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6145/13108; Loss: 0.2339; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6209/13108; Loss: 0.9114; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6273/13108; Loss: 0.3270; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6337/13108; Loss: 0.3794; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6401/13108; Loss: 0.2875; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6465/13108; Loss: 0.2749; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6529/13108; Loss: 0.5923; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6593/13108; Loss: 0.3363; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6657/13108; Loss: 0.7936; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6721/13108; Loss: 0.3489; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6785/13108; Loss: 0.2061; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6849/13108; Loss: 0.2850; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 6913/13108; Loss: 0.2575; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 6977/13108; Loss: 0.6493; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 7041/13108; Loss: 0.4653; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 7105/13108; Loss: 0.3151; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7169/13108; Loss: 0.4081; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7233/13108; Loss: 0.1631; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7297/13108; Loss: 0.2413; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7361/13108; Loss: 0.1664; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7425/13108; Loss: 0.2398; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7489/13108; Loss: 0.4603; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7553/13108; Loss: 0.3500; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7617/13108; Loss: 0.3839; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7681/13108; Loss: 0.3199; Acc: 0.837; True Pos: 0.859; True Neg: nan
# Epoch 3/50; Iter 7745/13108; Loss: 0.3447; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 7809/13108; Loss: 0.3554; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 7873/13108; Loss: 0.5297; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 7937/13108; Loss: 0.5154; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 8001/13108; Loss: 0.3673; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 8065/13108; Loss: 0.1952; Acc: 0.837; True Pos: 0.858; True Neg: nan
# Epoch 3/50; Iter 8129/13108; Loss: 0.3696; Acc: 0.837; True Pos: 0.858; True Neg: nan
# ...
# Epoch 50/50; Iter 1857/13108; Loss: 0.2063; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 1921/13108; Loss: 0.1257; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 1985/13108; Loss: 0.1535; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2049/13108; Loss: 0.1644; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2113/13108; Loss: 0.4633; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2177/13108; Loss: 0.0376; Acc: 0.931; True Pos: 0.931; True Neg: 0.946
# Epoch 50/50; Iter 2241/13108; Loss: 0.1123; Acc: 0.931; True Pos: 0.931; True Neg: 0.946
# Epoch 50/50; Iter 2305/13108; Loss: 0.2089; Acc: 0.931; True Pos: 0.931; True Neg: 0.946
# Epoch 50/50; Iter 2369/13108; Loss: 0.1730; Acc: 0.931; True Pos: 0.931; True Neg: 0.946
# Epoch 50/50; Iter 2433/13108; Loss: 0.1120; Acc: 0.931; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2497/13108; Loss: 0.1335; Acc: 0.931; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2561/13108; Loss: 0.1139; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2625/13108; Loss: 0.2429; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2689/13108; Loss: 0.5646; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2753/13108; Loss: 0.0494; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2817/13108; Loss: 0.0595; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 2881/13108; Loss: 0.1719; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 2945/13108; Loss: 0.1077; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3009/13108; Loss: 0.1062; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3073/13108; Loss: 0.6760; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3137/13108; Loss: 0.1609; Acc: 0.932; True Pos: 0.932; True Neg: 0.947
# Epoch 50/50; Iter 3201/13108; Loss: 0.1342; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3265/13108; Loss: 0.0331; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3329/13108; Loss: 0.2614; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3393/13108; Loss: 0.1035; Acc: 0.932; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 3457/13108; Loss: 0.0452; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3521/13108; Loss: 0.1180; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3585/13108; Loss: 0.0735; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3649/13108; Loss: 0.1234; Acc: 0.932; True Pos: 0.932; True Neg: 0.946
# Epoch 50/50; Iter 3713/13108; Loss: 0.0853; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 3777/13108; Loss: 0.0921; Acc: 0.932; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 3841/13108; Loss: 0.1834; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 3905/13108; Loss: 0.2045; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 3969/13108; Loss: 0.1360; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4033/13108; Loss: 0.0822; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4097/13108; Loss: 0.1960; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4161/13108; Loss: 0.1153; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4225/13108; Loss: 0.0835; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4289/13108; Loss: 0.0572; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4353/13108; Loss: 0.0913; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4417/13108; Loss: 0.1971; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 4481/13108; Loss: 0.1355; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4545/13108; Loss: 0.0789; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4609/13108; Loss: 0.0347; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4673/13108; Loss: 0.0644; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4737/13108; Loss: 0.1294; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4801/13108; Loss: 0.3022; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4865/13108; Loss: 0.0700; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4929/13108; Loss: 0.0282; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 4993/13108; Loss: 0.1301; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5057/13108; Loss: 0.3827; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5121/13108; Loss: 0.0776; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5185/13108; Loss: 0.2961; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5249/13108; Loss: 0.9030; Acc: 0.932; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5313/13108; Loss: 0.4552; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5377/13108; Loss: 0.1428; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5441/13108; Loss: 0.3704; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5505/13108; Loss: 0.2541; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 5569/13108; Loss: 0.1172; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5633/13108; Loss: 0.2078; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 5697/13108; Loss: 0.1031; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 5761/13108; Loss: 0.0504; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5825/13108; Loss: 0.0700; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5889/13108; Loss: 0.3748; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 5953/13108; Loss: 0.1440; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6017/13108; Loss: 0.2093; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6081/13108; Loss: 0.3298; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6145/13108; Loss: 0.1292; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6209/13108; Loss: 0.2436; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6273/13108; Loss: 0.1317; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6337/13108; Loss: 0.2986; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6401/13108; Loss: 0.4422; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6465/13108; Loss: 0.0471; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6529/13108; Loss: 0.1996; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6593/13108; Loss: 0.5042; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6657/13108; Loss: 0.1916; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6721/13108; Loss: 0.0745; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 6785/13108; Loss: 0.1190; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6849/13108; Loss: 0.1259; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6913/13108; Loss: 0.2617; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 6977/13108; Loss: 0.3143; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7041/13108; Loss: 0.1171; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7105/13108; Loss: 0.0639; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7169/13108; Loss: 0.0418; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7233/13108; Loss: 0.0821; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7297/13108; Loss: 0.8642; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7361/13108; Loss: 0.4084; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7425/13108; Loss: 0.0593; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7489/13108; Loss: 0.0638; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7553/13108; Loss: 0.1348; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7617/13108; Loss: 0.1212; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7681/13108; Loss: 0.1839; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7745/13108; Loss: 0.0548; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7809/13108; Loss: 0.1998; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7873/13108; Loss: 0.0534; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 7937/13108; Loss: 0.0485; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 8001/13108; Loss: 0.1611; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 8065/13108; Loss: 0.1350; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 8129/13108; Loss: 0.2403; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8193/13108; Loss: 0.0479; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8257/13108; Loss: 0.2472; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8321/13108; Loss: 0.2683; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8385/13108; Loss: 0.0415; Acc: 0.933; True Pos: 0.934; True Neg: 0.947
# Epoch 50/50; Iter 8449/13108; Loss: 0.0476; Acc: 0.933; True Pos: 0.934; True Neg: 0.947
# Epoch 50/50; Iter 8513/13108; Loss: 0.4212; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8577/13108; Loss: 0.1775; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8641/13108; Loss: 0.0569; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8705/13108; Loss: 0.4276; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8769/13108; Loss: 0.3696; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8833/13108; Loss: 0.1032; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8897/13108; Loss: 0.0551; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 8961/13108; Loss: 0.2123; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 9025/13108; Loss: 0.4003; Acc: 0.933; True Pos: 0.933; True Neg: 0.947
# Epoch 50/50; Iter 9089/13108; Loss: 0.2152; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9153/13108; Loss: 0.2186; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9217/13108; Loss: 0.0934; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9281/13108; Loss: 0.9375; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9345/13108; Loss: 0.2933; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9409/13108; Loss: 0.2392; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9473/13108; Loss: 0.1012; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9537/13108; Loss: 0.1625; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9601/13108; Loss: 0.1981; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9665/13108; Loss: 0.1549; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9729/13108; Loss: 0.1089; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9793/13108; Loss: 0.1630; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9857/13108; Loss: 0.0599; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9921/13108; Loss: 0.0585; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 9985/13108; Loss: 0.1668; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10049/13108; Loss: 0.0794; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10113/13108; Loss: 0.1072; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10177/13108; Loss: 0.5219; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10241/13108; Loss: 0.2256; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10305/13108; Loss: 0.1308; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10369/13108; Loss: 0.3125; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10433/13108; Loss: 0.0935; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10497/13108; Loss: 0.1775; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10561/13108; Loss: 0.5080; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10625/13108; Loss: 0.2126; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10689/13108; Loss: 0.1591; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10753/13108; Loss: 0.2554; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10817/13108; Loss: 0.0634; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10881/13108; Loss: 0.1047; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 10945/13108; Loss: 0.0875; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11009/13108; Loss: 0.4913; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11073/13108; Loss: 0.2622; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11137/13108; Loss: 0.3526; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11201/13108; Loss: 0.1313; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11265/13108; Loss: 0.0965; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11329/13108; Loss: 0.0668; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11393/13108; Loss: 0.1620; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11457/13108; Loss: 0.1843; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11521/13108; Loss: 0.0626; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11585/13108; Loss: 0.1687; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11649/13108; Loss: 0.0900; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11713/13108; Loss: 0.1749; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11777/13108; Loss: 0.1321; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11841/13108; Loss: 0.1004; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11905/13108; Loss: 0.3515; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 11969/13108; Loss: 0.1831; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12033/13108; Loss: 0.1232; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12097/13108; Loss: 0.0909; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12161/13108; Loss: 0.4121; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12225/13108; Loss: 0.1278; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12289/13108; Loss: 0.0840; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12353/13108; Loss: 0.0929; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12417/13108; Loss: 0.0888; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12481/13108; Loss: 0.1737; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12545/13108; Loss: 0.1024; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12609/13108; Loss: 0.3189; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12673/13108; Loss: 0.3779; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12737/13108; Loss: 0.2193; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12801/13108; Loss: 0.0288; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12865/13108; Loss: 0.4733; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12929/13108; Loss: 0.1064; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 12993/13108; Loss: 0.1228; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Iter 13057/13108; Loss: 0.0991; Acc: 0.933; True Pos: 0.933; True Neg: 0.946
# Epoch 50/50; Avg. Train Loss: 0.1855; Train Acc: 0.933; Train TPR: 0.933; Train TNR: 0.946; Epoch Time: 7.04 mins;
# Avg. Dev Loss: 0.1648; Dev Acc: 0.923; Dev TPR: 0.833; Dev TNR: 1.000
#
# 7 epochs of increasing dev loss (0.154788 --> 0.164809).

# %% [markdown]
# ### Model Saving + Loading (fot future use, API)
# This should be sent to Server Side (which hosts it via torchserve)

# %%
# generate a dummy input
example_input = torch.rand(1, 3, 96, 96).to(torch.device("cuda"))

# Store the existing model using torch.jit
traced_script_module = torch.jit.trace(model, example_input)

full_filename = "pcam_cnn.pt"
# Save the script module under pcam_cnn.pt
traced_script_module.save(full_filename)

new_model = torch.jit.load(full_filename)

# %%
# from google.colab import files
# files.download(full_filename)

# %%
# from torchvision import transforms
# from ts.torch_handler.image_classifier import ImageClassifier
# import torch


# class MNISTDigitClassifier(ImageClassifier):
#     """
#     MNISTDigitClassifier handler class. This handler extends class ImageClassifier from image_classifier.py, a
#     default handler. This handler takes an image and returns the number in that image.
#     Here method postprocess() has been overridden while others are reused from parent class.
#     """

#     image_processing = transforms.Compose([
#       # transforms.ToPILImage(),
#       transforms.ToTensor(),
#       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
#     ])

#     def postprocess(self, data):
#         """The post process of MNIST converts the predicted output response to a label.
#         Args:
#             data (list): The predicted output from the Inference with probabilities is passed
#             to the post-process function
#         Returns:
#             list : A list of dictionary with predictons and explanations are returned.
#         """
#         return data.argmax(1).tolist()

# %%
# # some_model = torch.load('checkpoint/best_v2.pth.tar')
# # best_model = CNN_V2()
# # best_model.load_state_dict(some_model.items()['state_dict'])

# # Specify a path for saving the weights and the model (as opposed to what is done during training above, where a dict is being stored)
# PATH = "checkpoint/trained_model.pth"

# # Save - model weights
# torch.save(model.state_dict(), PATH)

# # Load - same model weights
# # Instantiating the model from above
# loaded_same_model = CNN_V2()
# if (USE_GPU):
#     loaded_same_model.cuda()

# # Loading state dict (weights) of model 
# loaded_same_model.load_state_dict(torch.load(PATH))
# loaded_same_model.eval() # https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch#:~:text=answer%20was%20accepted%E2%80%A6-,model.,will%20do%20it%20for%20you
